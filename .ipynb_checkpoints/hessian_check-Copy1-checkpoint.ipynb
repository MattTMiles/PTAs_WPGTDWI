# %%
import os
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"
os.environ["XLA_PYTHON_CLIENT_ALLOCATOR"] = "platform"

import discovery as ds
import json
import numpy as np
import jax.numpy as jnp
import glob
import matplotlib.pyplot as plt
import jax
jax.config.update('jax_enable_x64', True)
import argparse
from functools import partial
import json
import discovery.samplers.numpyro as ds_numpyro
from pathlib import Path
import pickle
import corner
import inspect
import typing

# %%
feather_dir = "./from_polina/"

# %%
psrs = [ds.Pulsar.read_feather(psrfile) for psrfile in sorted(glob.glob(feather_dir+'*.feather'))]

# %% [markdown]
# ## Psr signal injection as follows:
# - gwtheta=1.0471975511965979
# - gwphi=3.141592653589793
# - dist=69.75
# - log10_mc=9
# - fgw=2e-08
# - inc=0
# - rzn=0
# - curn
#
# ### Truth values of the pulsar distances are contained in psr.pdist
#
# The contention is that the hessian of the lnL should be greatly maximised where the psr distance search values are at the true values

# %% [markdown]
# ### Set up signal model below:

# %%
# Custom function to use the p_dist rather than p_phase

def makefourier_binary_pdist(pulsarterm=True):
    def fourier_binary_pdist(f, df, mintoa, pos, log10_h0, log10_f0, ra, sindec, cosinc, psi, phi_earth, psr_dist):
        """BBH residuals from Ellis et. al 2012, 2013"""

        h0 = 10**log10_h0
        f0 = 10**log10_f0

        dec, inc = jnp.arcsin(sindec), jnp.arccos(cosinc)

        # calculate antenna pattern (note: pos is pulsar sky position unit vector)
        fplus, fcross = fpc_fast(pos, 0.5 * jnp.pi - dec, ra)  # careful with dec -> gwtheta conversion


        
        cosgwtheta, cosgwphi = np.cos(gwtheta), np.cos(gwphi)
        singwtheta, singwphi = np.sin(gwtheta), np.sin(gwphi)
        
        omhat = jnp.array([-singwtheta * cosgwphi, -singwtheta * singwphi, -cosgwtheta])
        
        cosMu = -jnp.dot(omhat, phat)
        
        if pulsarterm:
            phi_psr = psr_dist * (2 * np.pi * f0 * (1 - cosMu)) * eu.KPC2S
            phi_avg  = 0.5 * (phi_earth + phi_psr)
        else:
            phi_avg = phi_earth

        tref = 86400.0 * 51544.5  # MJD J2000 in seconds

        cphase = cos2comp(f, df, 1.0, f0, phi_avg - 2.0 * jnp.pi * f0 * tref, mintoa)
        sphase = cos2comp(f, df, 1.0, f0, phi_avg - 2.0 * jnp.pi * f0 * tref - 0.5*jnp.pi, mintoa)

        # fix this for no pulsarterm

        if pulsarterm:
            phi_diff = 0.5 * (phi_earth - phi_psr)
            sin_diff = jnp.sin(phi_diff)

            delta_sin =  2.0 * cphase * sin_diff
            delta_cos = -2.0 * sphase * sin_diff
        else:
            delta_sin = sphase
            delta_cos = cphase

        At = -1.0 * (1.0 + jnp.cos(inc)**2) * delta_sin
        Bt =  2.0 * jnp.cos(inc) * delta_cos

        alpha = h0 / (2 * jnp.pi * f0)

        # calculate rplus and rcross
        rplus  = alpha * (-At * jnp.cos(2 * psi) + Bt * jnp.sin(2 * psi))
        rcross = alpha * ( At * jnp.sin(2 * psi) + Bt * jnp.cos(2 * psi))

        # calculate residuals
        res = -fplus * rplus - fcross * rcross

        return res

    if not pulsarterm:
        fourier_binary = functools.partial(fourier_binary, phi_psr=jnp.nan)

    return fourier_binary

def cos2comp(f, df, A, f0, phi, t0):
    """Project signal A * cos(2pi f t + phi) onto Fourier basis
    cos(2pi k t/T), sin(2pi k t/T) for t in [t0, t0+T]."""

    T = 1.0 / df[0]

    Delta_omega = 2.0 * jnp.pi * (f0 - f[::2])
    Sigma_omega = 2.0 * jnp.pi * (f0 + f[::2])

    phase_Delta_start = phi + Delta_omega * t0
    phase_Delta_end   = phi + Delta_omega * (t0 + T)

    phase_Sigma_start = phi + Sigma_omega * t0
    phase_Sigma_end   = phi + Sigma_omega * (t0 + T)

    ck = (A / T) * (
        (jnp.sin(phase_Delta_end) - jnp.sin(phase_Delta_start)) / Delta_omega +
        (jnp.sin(phase_Sigma_end) - jnp.sin(phase_Sigma_start)) / Sigma_omega
    )

    sk = (A / T) * (
        (jnp.cos(phase_Delta_end) - jnp.cos(phase_Delta_start)) / Delta_omega -
        (jnp.cos(phase_Sigma_end) - jnp.cos(phase_Sigma_start)) / Sigma_omega
    )

    return jnp.stack((sk, ck), axis=1).reshape(-1)



def makefourier_binary(pulsarterm=True):
    def fourier_binary(f, df, mintoa, pos, log10_h0, log10_f0, ra, sindec, cosinc, psi, phi_earth, L_psr):
        h0 = 10**log10_h0
        f0 = 10**log10_f0

        dec, inc = jnp.arcsin(sindec), jnp.arccos(cosinc)

        # calculate antenna pattern
        fplus, fcross = fpc_fast(pos, 0.5 * jnp.pi - dec, ra)

        c = 2.99792458e8 
        omega_hat = jnp.array([ -jnp.cos(dec) * jnp.cos(ra), 
                                -jnp.cos(dec) * jnp.sin(ra),
                                -jnp.sin(dec)
                              ])

        phi_psr = phi_earth - 2.0 * jnp.pi * f0 * L_psr / c * (1.0 + jnp.dot(omega_hat, pos))

        if pulsarterm:
            phi_avg = 0.5 * (phi_earth + phi_psr)
        else:
            phi_avg = phi_earth

        tref = 86400.0 * 51544.5  # MJD J2000 in seconds

        cphase = cos2comp(f, df, 1.0, f0, phi_avg - 2.0 * jnp.pi * f0 * tref, mintoa)
        sphase = cos2comp(f, df, 1.0, f0, phi_avg - 2.0 * jnp.pi * f0 * tref - 0.5 * jnp.pi, mintoa)

        if pulsarterm:
            phi_diff = 0.5 * (phi_earth - phi_psr)
            sin_diff = jnp.sin(phi_diff)

            delta_sin =  2.0 * cphase * sin_diff
            delta_cos = -2.0 * sphase * sin_diff
        else:
            delta_sin = sphase
            delta_cos = cphase

        At = -1.0 * (1.0 + jnp.cos(inc)**2) * delta_sin
        Bt =  2.0 * jnp.cos(inc) * delta_cos

        alpha = h0 / (2 * jnp.pi * f0)

        rplus  = alpha * (-At * jnp.cos(2 * psi) + Bt * jnp.sin(2 * psi))
        rcross = alpha * ( At * jnp.sin(2 * psi) + Bt * jnp.cos(2 * psi))

        res = -fplus * rplus - fcross * rcross

        return res

    if not pulsarterm:
        fourier_binary = functools.partial(fourier_binary, L_psr=jnp.nan)

    return fourier_binary

# %%
# Injected with effectively no WN

noisedict = {}
for psr in psrs:
    noisedict[psr.name+"_KAT_MKBF_efac"] = 1 # EFAC=1 means no EFAC
    noisedict[psr.name+"_KAT_MKBF_log10_ecorr"] = -19 # Bringing these down to effectively 0
    noisedict[psr.name+"_KAT_MKBF_log10_t2equad"] = -19

# %%
# Fourier based CW delay
fourdelay = ds.makefourier_binary(pulsarterm=True)
cwcommon = ['cw_sindec', 'cw_cosinc', 'cw_log10_f0', 'cw_log10_h0', 'cw_phi_earth', 'cw_psi', 'cw_ra']

T = ds.getspan(psrs)
fml = ds.ArrayLikelihood([ds.PulsarLikelihood([psr.residuals,
                                               ds.makenoise_measurement(psr, noisedict=noisedict),
                                               ds.makegp_timing(psr, svd=True),
                                              ]) for psr in psrs],
                         commongp = ds.makecommongp_fourier(psrs, ds.makepowerlaw_crn(14), 30, T, means=fourdelay,
                                                            common=['crn_gamma', 'crn_log10_A'] + cwcommon, name='rednoise', meansname='cw'))

# %%
logl = fml.logL

# %%
logl
# Out:
# <function discovery.matrix.VectorWoodburyKernel_varP.make_kernelproduct.<locals>.kernelproduct(params)>

# %%
## Params the likelihood expects
logl.params
# Out:
# ['B1855+09_cw_phi_psr',
#  'B1855+09_rednoise_gamma',
#  'B1855+09_rednoise_log10_A',
#  'B1937+21_cw_phi_psr',
#  'B1937+21_rednoise_gamma',
#  'B1937+21_rednoise_log10_A',
#  'B1953+29_cw_phi_psr',
#  'B1953+29_rednoise_gamma',
#  'B1953+29_rednoise_log10_A',
#  'J0023+0923_cw_phi_psr',
#  'J0023+0923_rednoise_gamma',
#  'J0023+0923_rednoise_log10_A',
#  'J0030+0451_cw_phi_psr',
#  'J0030+0451_rednoise_gamma',
#  'J0030+0451_rednoise_log10_A',
#  'J0125-2327_cw_phi_psr',
#  'J0125-2327_rednoise_gamma',
#  'J0125-2327_rednoise_log10_A',
#  'J0340+4130_cw_phi_psr',
#  'J0340+4130_rednoise_gamma',
#  'J0340+4130_rednoise_log10_A',
#  'J0406+3039_cw_phi_psr',
#  'J0406+3039_rednoise_gamma',
#  'J0406+3039_rednoise_log10_A',
#  'J0437-4715_cw_phi_psr',
#  'J0437-4715_rednoise_gamma',
#  'J0437-4715_rednoise_log10_A',
#  'J0509+0856_cw_phi_psr',
#  'J0509+0856_rednoise_gamma',
#  'J0509+0856_rednoise_log10_A',
#  'J0557+1551_cw_phi_psr',
#  'J0557+1551_rednoise_gamma',
#  'J0557+1551_rednoise_log10_A',
#  'J0605+3757_cw_phi_psr',
#  'J0605+3757_rednoise_gamma',
#  'J0605+3757_rednoise_log10_A',
#  'J0610-2100_cw_phi_psr',
#  'J0610-2100_rednoise_gamma',
#  'J0610-2100_rednoise_log10_A',
#  'J0613-0200_cw_phi_psr',
#  'J0613-0200_rednoise_gamma',
#  'J0613-0200_rednoise_log10_A',
#  'J0614-3329_cw_phi_psr',
#  'J0614-3329_rednoise_gamma',
#  'J0614-3329_rednoise_log10_A',
#  'J0636+5128_cw_phi_psr',
#  'J0636+5128_rednoise_gamma',
#  'J0636+5128_rednoise_log10_A',
#  'J0636-3044_cw_phi_psr',
#  'J0636-3044_rednoise_gamma',
#  'J0636-3044_rednoise_log10_A',
#  'J0645+5158_cw_phi_psr',
#  'J0645+5158_rednoise_gamma',
#  'J0645+5158_rednoise_log10_A',
#  'J0709+0458_cw_phi_psr',
#  'J0709+0458_rednoise_gamma',
#  'J0709+0458_rednoise_log10_A',
#  'J0711-6830_cw_phi_psr',
#  'J0711-6830_rednoise_gamma',
#  'J0711-6830_rednoise_log10_A',
#  'J0740+6620_cw_phi_psr',
#  'J0740+6620_rednoise_gamma',
#  'J0740+6620_rednoise_log10_A',
#  'J0751+1807_cw_phi_psr',
#  'J0751+1807_rednoise_gamma',
#  'J0751+1807_rednoise_log10_A',
#  'J0900-3144_cw_phi_psr',
#  'J0900-3144_rednoise_gamma',
#  'J0900-3144_rednoise_log10_A',
#  'J0931-1902_cw_phi_psr',
#  'J0931-1902_rednoise_gamma',
#  'J0931-1902_rednoise_log10_A',
#  'J0955-6150_cw_phi_psr',
#  'J0955-6150_rednoise_gamma',
#  'J0955-6150_rednoise_log10_A',
#  'J1012+5307_cw_phi_psr',
#  'J1012+5307_rednoise_gamma',
#  'J1012+5307_rednoise_log10_A',
#  'J1012-4235_cw_phi_psr',
#  'J1012-4235_rednoise_gamma',
#  'J1012-4235_rednoise_log10_A',
#  'J1017-7156_cw_phi_psr',
#  'J1017-7156_rednoise_gamma',
#  'J1017-7156_rednoise_log10_A',
#  'J1022+1001_cw_phi_psr',
#  'J1022+1001_rednoise_gamma',
#  'J1022+1001_rednoise_log10_A',
#  'J1024-0719_cw_phi_psr',
#  'J1024-0719_rednoise_gamma',
#  'J1024-0719_rednoise_log10_A',
#  'J1036-8317_cw_phi_psr',
#  'J1036-8317_rednoise_gamma',
#  'J1036-8317_rednoise_log10_A',
#  'J1045-4509_cw_phi_psr',
#  'J1045-4509_rednoise_gamma',
#  'J1045-4509_rednoise_log10_A',
#  'J1101-6424_cw_phi_psr',
#  'J1101-6424_rednoise_gamma',
#  'J1101-6424_rednoise_log10_A',
#  'J1103-5403_cw_phi_psr',
#  'J1103-5403_rednoise_gamma',
#  'J1103-5403_rednoise_log10_A',
#  'J1125+7819_cw_phi_psr',
#  'J1125+7819_rednoise_gamma',
#  'J1125+7819_rednoise_log10_A',
#  'J1125-5825_cw_phi_psr',
#  'J1125-5825_rednoise_gamma',
#  'J1125-5825_rednoise_log10_A',
#  'J1125-6014_cw_phi_psr',
#  'J1125-6014_rednoise_gamma',
#  'J1125-6014_rednoise_log10_A',
#  'J1216-6410_cw_phi_psr',
#  'J1216-6410_rednoise_gamma',
#  'J1216-6410_rednoise_log10_A',
#  'J1312+0051_cw_phi_psr',
#  'J1312+0051_rednoise_gamma',
#  'J1312+0051_rednoise_log10_A',
#  'J1327-0755_cw_phi_psr',
#  'J1327-0755_rednoise_gamma',
#  'J1327-0755_rednoise_log10_A',
#  'J1421-4409_cw_phi_psr',
#  'J1421-4409_rednoise_gamma',
#  'J1421-4409_rednoise_log10_A',
#  'J1431-5740_cw_phi_psr',
#  'J1431-5740_rednoise_gamma',
#  'J1431-5740_rednoise_log10_A',
#  'J1435-6100_cw_phi_psr',
#  'J1435-6100_rednoise_gamma',
#  'J1435-6100_rednoise_log10_A',
#  'J1446-4701_cw_phi_psr',
#  'J1446-4701_rednoise_gamma',
#  'J1446-4701_rednoise_log10_A',
#  'J1453+1902_cw_phi_psr',
#  'J1453+1902_rednoise_gamma',
#  'J1453+1902_rednoise_log10_A',
#  'J1455-3330_cw_phi_psr',
#  'J1455-3330_rednoise_gamma',
#  'J1455-3330_rednoise_log10_A',
#  'J1525-5545_cw_phi_psr',
#  'J1525-5545_rednoise_gamma',
#  'J1525-5545_rednoise_log10_A',
#  'J1543-5149_cw_phi_psr',
#  'J1543-5149_rednoise_gamma',
#  'J1543-5149_rednoise_log10_A',
#  'J1545-4550_cw_phi_psr',
#  'J1545-4550_rednoise_gamma',
#  'J1545-4550_rednoise_log10_A',
#  'J1547-5709_cw_phi_psr',
#  'J1547-5709_rednoise_gamma',
#  'J1547-5709_rednoise_log10_A',
#  'J1600-3053_cw_phi_psr',
#  'J1600-3053_rednoise_gamma',
#  'J1600-3053_rednoise_log10_A',
#  'J1603-7202_cw_phi_psr',
#  'J1603-7202_rednoise_gamma',
#  'J1603-7202_rednoise_log10_A',
#  'J1614-2230_cw_phi_psr',
#  'J1614-2230_rednoise_gamma',
#  'J1614-2230_rednoise_log10_A',
#  'J1629-6902_cw_phi_psr',
#  'J1629-6902_rednoise_gamma',
#  'J1629-6902_rednoise_log10_A',
#  'J1630+3734_cw_phi_psr',
#  'J1630+3734_rednoise_gamma',
#  'J1630+3734_rednoise_log10_A',
#  'J1640+2224_cw_phi_psr',
#  'J1640+2224_rednoise_gamma',
#  'J1640+2224_rednoise_log10_A',
#  'J1643-1224_cw_phi_psr',
#  'J1643-1224_rednoise_gamma',
#  'J1643-1224_rednoise_log10_A',
#  'J1652-4838_cw_phi_psr',
#  'J1652-4838_rednoise_gamma',
#  'J1652-4838_rednoise_log10_A',
#  'J1653-2054_cw_phi_psr',
#  'J1653-2054_rednoise_gamma',
#  'J1653-2054_rednoise_log10_A',
#  'J1658-5324_cw_phi_psr',
#  'J1658-5324_rednoise_gamma',
#  'J1658-5324_rednoise_log10_A',
#  'J1705-1903_cw_phi_psr',
#  'J1705-1903_rednoise_gamma',
#  'J1705-1903_rednoise_log10_A',
#  'J1708-3506_cw_phi_psr',
#  'J1708-3506_rednoise_gamma',
#  'J1708-3506_rednoise_log10_A',
#  'J1713+0747_cw_phi_psr',
#  'J1713+0747_rednoise_gamma',
#  'J1713+0747_rednoise_log10_A',
#  'J1719-1438_cw_phi_psr',
#  'J1719-1438_rednoise_gamma',
#  'J1719-1438_rednoise_log10_A',
#  'J1721-2457_cw_phi_psr',
#  'J1721-2457_rednoise_gamma',
#  'J1721-2457_rednoise_log10_A',
#  'J1730-2304_cw_phi_psr',
#  'J1730-2304_rednoise_gamma',
#  'J1730-2304_rednoise_log10_A',
#  'J1732-5049_cw_phi_psr',
#  'J1732-5049_rednoise_gamma',
#  'J1732-5049_rednoise_log10_A',
#  'J1737-0811_cw_phi_psr',
#  'J1737-0811_rednoise_gamma',
#  'J1737-0811_rednoise_log10_A',
#  'J1738+0333_cw_phi_psr',
#  'J1738+0333_rednoise_gamma',
#  'J1738+0333_rednoise_log10_A',
#  'J1741+1351_cw_phi_psr',
#  'J1741+1351_rednoise_gamma',
#  'J1741+1351_rednoise_log10_A',
#  'J1744-1134_cw_phi_psr',
#  'J1744-1134_rednoise_gamma',
#  'J1744-1134_rednoise_log10_A',
#  'J1745+1017_cw_phi_psr',
#  'J1745+1017_rednoise_gamma',
#  'J1745+1017_rednoise_log10_A',
#  'J1747-4036_cw_phi_psr',
#  'J1747-4036_rednoise_gamma',
#  'J1747-4036_rednoise_log10_A',
#  'J1751-2857_cw_phi_psr',
#  'J1751-2857_rednoise_gamma',
#  'J1751-2857_rednoise_log10_A',
#  'J1756-2251_cw_phi_psr',
#  'J1756-2251_rednoise_gamma',
#  'J1756-2251_rednoise_log10_A',
#  'J1757-5322_cw_phi_psr',
#  'J1757-5322_rednoise_gamma',
#  'J1757-5322_rednoise_log10_A',
#  'J1801-1417_cw_phi_psr',
#  'J1801-1417_rednoise_gamma',
#  'J1801-1417_rednoise_log10_A',
#  'J1802-2124_cw_phi_psr',
#  'J1802-2124_rednoise_gamma',
#  'J1802-2124_rednoise_log10_A',
#  'J1804-2717_cw_phi_psr',
#  'J1804-2717_rednoise_gamma',
#  'J1804-2717_rednoise_log10_A',
#  'J1811-2405_cw_phi_psr',
#  'J1811-2405_rednoise_gamma',
#  'J1811-2405_rednoise_log10_A',
#  'J1824-2452A_cw_phi_psr',
#  'J1824-2452A_rednoise_gamma',
#  'J1824-2452A_rednoise_log10_A',
#  'J1825-0319_cw_phi_psr',
#  'J1825-0319_rednoise_gamma',
#  'J1825-0319_rednoise_log10_A',
#  'J1832-0836_cw_phi_psr',
#  'J1832-0836_rednoise_gamma',
#  'J1832-0836_rednoise_log10_A',
#  'J1843-1113_cw_phi_psr',
#  'J1843-1113_rednoise_gamma',
#  'J1843-1113_rednoise_log10_A',
#  'J1853+1303_cw_phi_psr',
#  'J1853+1303_rednoise_gamma',
#  'J1853+1303_rednoise_log10_A',
#  'J1902-5105_cw_phi_psr',
#  'J1902-5105_rednoise_gamma',
#  'J1902-5105_rednoise_log10_A',
#  'J1903+0327_cw_phi_psr',
#  'J1903+0327_rednoise_gamma',
#  'J1903+0327_rednoise_log10_A',
#  'J1903-7051_cw_phi_psr',
#  'J1903-7051_rednoise_gamma',
#  'J1903-7051_rednoise_log10_A',
#  'J1909-3744_cw_phi_psr',
#  'J1909-3744_rednoise_gamma',
#  'J1909-3744_rednoise_log10_A',
#  'J1910+1256_cw_phi_psr',
#  'J1910+1256_rednoise_gamma',
#  'J1910+1256_rednoise_log10_A',
#  'J1911+1347_cw_phi_psr',
#  'J1911+1347_rednoise_gamma',
#  'J1911+1347_rednoise_log10_A',
#  'J1918-0642_cw_phi_psr',
#  'J1918-0642_rednoise_gamma',
#  'J1918-0642_rednoise_log10_A',
#  'J1923+2515_cw_phi_psr',
#  'J1923+2515_rednoise_gamma',
#  'J1923+2515_rednoise_log10_A',
#  'J1933-6211_cw_phi_psr',
#  'J1933-6211_rednoise_gamma',
#  'J1933-6211_rednoise_log10_A',
#  'J1944+0907_cw_phi_psr',
#  'J1944+0907_rednoise_gamma',
#  'J1944+0907_rednoise_log10_A',
#  'J1946+3417_cw_phi_psr',
#  'J1946+3417_rednoise_gamma',
#  'J1946+3417_rednoise_log10_A',
#  'J1946-5403_cw_phi_psr',
#  'J1946-5403_rednoise_gamma',
#  'J1946-5403_rednoise_log10_A',
#  'J2010-1323_cw_phi_psr',
#  'J2010-1323_rednoise_gamma',
#  'J2010-1323_rednoise_log10_A',
#  'J2017+0603_cw_phi_psr',
#  'J2017+0603_rednoise_gamma',
#  'J2017+0603_rednoise_log10_A',
#  'J2033+1734_cw_phi_psr',
#  'J2033+1734_rednoise_gamma',
#  'J2033+1734_rednoise_log10_A',
#  'J2039-3616_cw_phi_psr',
#  'J2039-3616_rednoise_gamma',
#  'J2039-3616_rednoise_log10_A',
#  'J2043+1711_cw_phi_psr',
#  'J2043+1711_rednoise_gamma',
#  'J2043+1711_rednoise_log10_A',
#  'J2124-3358_cw_phi_psr',
#  'J2124-3358_rednoise_gamma',
#  'J2124-3358_rednoise_log10_A',
#  'J2129-5721_cw_phi_psr',
#  'J2129-5721_rednoise_gamma',
#  'J2129-5721_rednoise_log10_A',
#  'J2145-0750_cw_phi_psr',
#  'J2145-0750_rednoise_gamma',
#  'J2145-0750_rednoise_log10_A',
#  'J2150-0326_cw_phi_psr',
#  'J2150-0326_rednoise_gamma',
#  'J2150-0326_rednoise_log10_A',
#  'J2214+3000_cw_phi_psr',
#  'J2214+3000_rednoise_gamma',
#  'J2214+3000_rednoise_log10_A',
#  'J2222-0137_cw_phi_psr',
#  'J2222-0137_rednoise_gamma',
#  'J2222-0137_rednoise_log10_A',
#  'J2229+2643_cw_phi_psr',
#  'J2229+2643_rednoise_gamma',
#  'J2229+2643_rednoise_log10_A',
#  'J2234+0611_cw_phi_psr',
#  'J2234+0611_rednoise_gamma',
#  'J2234+0611_rednoise_log10_A',
#  'J2234+0944_cw_phi_psr',
#  'J2234+0944_rednoise_gamma',
#  'J2234+0944_rednoise_log10_A',
#  'J2241-5236_cw_phi_psr',
#  'J2241-5236_rednoise_gamma',
#  'J2241-5236_rednoise_log10_A',
#  'J2302+4442_cw_phi_psr',
#  'J2302+4442_rednoise_gamma',
#  'J2302+4442_rednoise_log10_A',
#  'J2317+1439_cw_phi_psr',
#  'J2317+1439_rednoise_gamma',
#  'J2317+1439_rednoise_log10_A',
#  'J2322+2057_cw_phi_psr',
#  'J2322+2057_rednoise_gamma',
#  'J2322+2057_rednoise_log10_A',
#  'J2322-2650_cw_phi_psr',
#  'J2322-2650_rednoise_gamma',
#  'J2322-2650_rednoise_log10_A',
#  'crn_gamma',
#  'crn_log10_A',
#  'cw_cosinc',
#  'cw_log10_f0',
#  'cw_log10_h0',
#  'cw_phi_earth',
#  'cw_psi',
#  'cw_ra',
#  'cw_sindec']

# %%
phi_psr = psr_dist * (2 * np.pi * f0 * (1 - cosMu)) * eu.KPC2S

# %%
np.log(2e-08)
# Out:
# np.float64(-17.72753356339242)

# %%
10**-17.72753356339242
# Out:
# 1.8726923509527988e-18

# %%
10**-14
# Out:
# 1e-14

# %%
# Out:
# np.float64(-17.72753356339242)
