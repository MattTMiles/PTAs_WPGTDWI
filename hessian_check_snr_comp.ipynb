# %%
import os
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"
os.environ["XLA_PYTHON_CLIENT_ALLOCATOR"] = "platform"

import discovery as ds
import json
import numpy as np
import jax.numpy as jnp
import glob
import matplotlib.pyplot as plt
import jax
jax.config.update('jax_enable_x64', True)
import argparse
from functools import partial
import json
import discovery.samplers.numpyro as ds_numpyro
from pathlib import Path
import pickle
import corner
import inspect
import typing
import copy
import random

# %% [markdown]
# ### Simulation and recovery code for pulsar distance estimates
#
# This notebook, in essence, does the following:
# - Simulates pulsar timing residuals assuming user input noise and a user input deteministic continuous wave signal
# - Builds a differentiable lnL function that can be used for our experimentation
# - Contains basic code to evaluate the lnL at changing pulsar distances in a vectorised form.
#
# #### This code may require a GPU to run

# %%
# Set data product directory. The simulation code requires pulsar timing models and data to initialise. 
# In this directory, we have stored these files for a set of pulsars (mimicking the IPTA DR2 dataset, but nonetheless synthetic).

feather_dir = "./data_products/"

# %% [markdown]
# #### Simulation code
#
# - This uses the enterprise pulsar timing array modeling software (https://github.com/nanograv/enterprise)
# - It works by realizing the signal properties described by the "pta" object using parameter values supplied in the "params" dictionary over Gaussian residual data made from the data products loaded earlier.

# %%
from enterprise.signals import signal_base

import numpy as np
import scipy.linalg as sl
import scipy.sparse as ss
from sksparse.cholmod import cholesky
from enterprise.signals import signal_base
from enterprise.signals.gp_signals import get_timing_model_basis, BasisGP
from enterprise.signals.parameter import function
from enterprise_extensions import load_feathers


def simulate(pta, params, sparse_cholesky=True):
    """Simulate code with enterprise (instead of libstempo/PINT)"""
    delays, ndiags, fmats, phis = (pta.get_delay(params=params),
                                   pta.get_ndiag(params=params),
                                   pta.get_basis(params=params),
                                   pta.get_phi(params=params))

    gpresiduals = []
    if pta._commonsignals:
        if sparse_cholesky:
            cf = cholesky(ss.csc_matrix(phis))
            gp = np.zeros(phis.shape[0])
            gp[cf.P()] = np.dot(cf.L().toarray(), np.random.randn(phis.shape[0]))
        else:
            gp = np.dot(sl.cholesky(phis, lower=True), np.random.randn(phis.shape[0]))

        i = 0
        for fmat in fmats:
            j = i + fmat.shape[1]
            gpresiduals.append(np.dot(fmat, gp[i:j]))
            i = j

        assert len(gp) == i
    else:
        for fmat, phi in zip(fmats, phis):
            if phi is None:
                gpresiduals.append(0)
            elif phi.ndim == 1:
                gpresiduals.append(np.dot(fmat, np.sqrt(phi) * np.random.randn(phi.shape[0])))
            else:
                raise NotImplementedError

    whiteresiduals = []
    for delay, ndiag in zip(delays, ndiags):
        if ndiag is None:
            whiteresiduals.append(0)
        elif isinstance(ndiag, signal_base.ShermanMorrison):
            # this code is very slow...
            n = np.diag(ndiag._nvec)
            for j,s in zip(ndiag._jvec, ndiag._slices):
                n[s,s] += j
            whiteresiduals.append(delay + np.dot(sl.cholesky(n, lower=True), np.random.randn(n.shape[0])))
        elif ndiag.ndim == 1:
            whiteresiduals.append(delay + np.sqrt(ndiag) * np.random.randn(ndiag.shape[0]))
        else:
            raise NotImplementedError

    return [np.array(g + w) for g, w in zip(gpresiduals, whiteresiduals)]

def set_residuals(psr, y):
    psr._residuals[psr._isort] = y

@function
def tm_prior(weights, toas, variance=1e40):
    return weights * variance * len(toas)

def TimingModel(coefficients=False, name="linear_timing_model",
                use_svd=False, normed=True, prior_variance=1e40):
    """Class factory for marginalized linear timing model signals."""

    basis = get_timing_model_basis(use_svd, normed)
    prior = tm_prior(variance=prior_variance)

    BaseClass = BasisGP(prior, basis, coefficients=coefficients, name=name)

    class TimingModel(BaseClass):
        signal_type = "basis"
        signal_name = "linear timing model"
        signal_id = name + "_svd" if use_svd else name

    return TimingModel

# %%
# Load the pulsars data products as Enterprise Pulsar objects
psrs = load_feathers.load_feathers_from_folder(feather_dir)
# Out:
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/B1855+09.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/B1855+09.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/B1937+21.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/B1937+21.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/B1953+29.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/B1953+29.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J0023+0923.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J0023+0923.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J0030+0451.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J0030+0451.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J0125-2327.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J0125-2327.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J0340+4130.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J0340+4130.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J0406+3039.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J0406+3039.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J0437-4715.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J0437-4715.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J0509+0856.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J0509+0856.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J0557+1551.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J0557+1551.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J0605+3757.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J0605+3757.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J0610-2100.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J0610-2100.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J0613-0200.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J0613-0200.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J0614-3329.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J0614-3329.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J0636+5128.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J0636+5128.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J0636-3044.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J0636-3044.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J0645+5158.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J0645+5158.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J0709+0458.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J0709+0458.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J0711-6830.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J0711-6830.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J0740+6620.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J0740+6620.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J0751+1807.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J0751+1807.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J0900-3144.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J0900-3144.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J0931-1902.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J0931-1902.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J0955-6150.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J0955-6150.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1012+5307.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1012+5307.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1012-4235.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1012-4235.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1017-7156.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1017-7156.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1022+1001.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1022+1001.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1024-0719.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1024-0719.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1036-8317.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1036-8317.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1045-4509.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1045-4509.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1101-6424.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1101-6424.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1103-5403.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1103-5403.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1125+7819.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1125+7819.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1125-5825.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1125-5825.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1125-6014.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1125-6014.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1216-6410.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1216-6410.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1312+0051.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1312+0051.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1327-0755.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1327-0755.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1421-4409.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1421-4409.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1431-5740.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1431-5740.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1435-6100.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1435-6100.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1446-4701.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1446-4701.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1453+1902.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1453+1902.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1455-3330.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1455-3330.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1525-5545.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1525-5545.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1543-5149.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1543-5149.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1545-4550.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1545-4550.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1547-5709.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1547-5709.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1600-3053.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1600-3053.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1603-7202.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1603-7202.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1614-2230.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1614-2230.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1629-6902.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1629-6902.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1630+3734.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1630+3734.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1640+2224.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1640+2224.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1643-1224.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1643-1224.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1652-4838.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1652-4838.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1653-2054.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1653-2054.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1658-5324.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1658-5324.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1705-1903.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1705-1903.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1708-3506.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1708-3506.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1713+0747.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1713+0747.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1719-1438.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1719-1438.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1721-2457.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1721-2457.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1730-2304.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1730-2304.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1732-5049.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1732-5049.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1737-0811.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1737-0811.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1738+0333.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1738+0333.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1741+1351.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1741+1351.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1744-1134.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1744-1134.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1745+1017.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1745+1017.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1747-4036.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1747-4036.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1751-2857.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1751-2857.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1756-2251.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1756-2251.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1757-5322.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1757-5322.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1801-1417.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1801-1417.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1802-2124.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1802-2124.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1804-2717.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1804-2717.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1811-2405.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1811-2405.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1824-2452A.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1824-2452A.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1825-0319.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1825-0319.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1832-0836.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1832-0836.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1843-1113.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1843-1113.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1853+1303.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1853+1303.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1902-5105.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1902-5105.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1903+0327.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1903+0327.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1903-7051.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1903-7051.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1909-3744.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1909-3744.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1910+1256.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1910+1256.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1911+1347.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1911+1347.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1918-0642.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1918-0642.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1923+2515.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1923+2515.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1933-6211.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1933-6211.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1944+0907.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1944+0907.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1946+3417.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1946+3417.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J1946-5403.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J1946-5403.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J2010-1323.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J2010-1323.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J2017+0603.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J2017+0603.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J2033+1734.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J2033+1734.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J2039-3616.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J2039-3616.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J2043+1711.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J2043+1711.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J2124-3358.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J2124-3358.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J2129-5721.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J2129-5721.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J2145-0750.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J2145-0750.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J2150-0326.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J2150-0326.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J2214+3000.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J2214+3000.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J2222-0137.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J2222-0137.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J2229+2643.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J2229+2643.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J2234+0611.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J2234+0611.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J2234+0944.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J2234+0944.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J2241-5236.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J2241-5236.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J2302+4442.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J2302+4442.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J2317+1439.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J2317+1439.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J2322+2057.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J2322+2057.feather.
# FeatherPulsar.read_feather: cannot find dmx in feather file ./data_products/J2322-2650.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file ./data_products/J2322-2650.feather.

# %%
# The _pdist attribute is used by enterprise to store the pulsar distance. Here, we back this up to allow us to vary it later.
for psr in psrs:
    psr._pdist = psr.pdist

# %%
# Set all residuals to zero for simplicity
for psr in psrs:
    psr.residuals = np.array(psr.toas) * 0.0

# %% [markdown]
# ### Construct psr signal model (in enterprise)
#
# - The below code block allows us to simulate any signal that we can build a model for in the pulsar data products
#
# Currently, I am only simulating:
# - White noise properties in each pulsar.
# - Achromatic (radio-frequency independent) time-correlated noise properties in each pulsar.
# - A global stochastic background signal (inc. Hellings-Downs correlations) in all pulsars.
# - A deterministic continuous wave signal in all pulsars, dependent on the position and distance of the pulsars.
#     - This signal does not currently evolve between the Earth and the pulsars, and can be considered monochromatic through time.
#     - The evolution will not be difficult to model in, but as the toy model stands this may be the best way to go first.
#     - (I do have a suspicion that evolution may actually make it easier to constrain the pulsar distances. But remains to be seen.)
#
#
# These simulations can be expanded to many, many more signals when we want to make this as realistic as possible.
#
# NB: The stochastic signals are power-law injections. This can be also be edited if we need to.

# %%
from enterprise.signals import selections
import enterprise.signals.parameter as parameter
from enterprise.signals import white_signals
from enterprise_extensions.blocks import common_red_noise_block
from enterprise.signals import gp_signals    
from enterprise.signals import utils
from enterprise_extensions import deterministic

tmin = [p.toas.min() for p in psrs]
tmax = [p.toas.max() for p in psrs]
Tspan = np.max(tmax) - np.min(tmin)

selection = selections.Selection(selections.by_backend)
efac = parameter.Constant(1)
equad = parameter.Constant(-8)
# ecorr = parameter.Constant(-8)

log10_A_red = parameter.Uniform(-18, -11)
gamma_red = parameter.Uniform(0, 7)
log10_A_gw = parameter.Uniform(-18,-11)('log10_A_gw')
gamma_gw = parameter.Uniform(0,7)('gamma_gw')

components = 30

tm = TimingModel(coefficients=False, name="linear_timing_model",
                use_svd=False, normed=True, prior_variance=1e-14)
models = []
for p in psrs:
    s = tm

    ef = white_signals.MeasurementNoise(efac=efac, selection=selection)
    s += ef

    eq = white_signals.TNEquadNoise(log10_tnequad=equad, selection=selection)
    s += eq

    # ec = gp_signals.EcorrBasisModel(log10_ecorr=ecorr,selection=selection)
    # s += ec

    pl = utils.powerlaw(log10_A=log10_A_red, gamma=gamma_red)
    rn = gp_signals.FourierBasisGP(spectrum=pl, components=components, Tspan=Tspan, name="rednoise")
    s += rn

    ## HD Correlated signal
    crn = common_red_noise_block(psd='powerlaw', prior='log-uniform',
                        components=components, orf='hd', name='gwb')


    cw = deterministic.cw_block_circ(amp_prior="log-uniform", dist_prior=None, skyloc=None, 
                                     log10_fgw=None, psrTerm=True, discoclone=True, name="cw")
    
    cw2 = deterministic.cw_block_circ(amp_prior="log-uniform", dist_prior=None, skyloc=None, 
                                     log10_fgw=None, psrTerm=True, discoclone=True, name="cw2")

    s += crn
    s += cw 

    s += cw2

    models.append(s(p))
    print(p.name)
pta = signal_base.PTA(models)

pta.set_default_params({})
# Out:
# Duplicate signal B1855+09_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, B1855+09_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, B1855+09_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal B1937+21_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, B1937+21_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, B1937+21_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal B1953+29_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, B1953+29_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, B1953+29_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J0023+0923_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J0023+0923_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J0023+0923_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J0030+0451_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J0030+0451_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J0030+0451_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J0125-2327_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J0125-2327_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J0125-2327_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J0340+4130_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J0340+4130_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J0340+4130_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J0406+3039_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J0406+3039_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J0406+3039_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J0437-4715_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J0437-4715_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J0437-4715_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J0509+0856_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J0509+0856_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J0509+0856_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J0557+1551_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J0557+1551_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J0557+1551_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J0605+3757_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J0605+3757_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J0605+3757_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J0610-2100_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J0610-2100_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J0610-2100_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J0613-0200_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J0613-0200_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J0613-0200_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J0614-3329_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J0614-3329_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J0614-3329_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J0636+5128_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J0636+5128_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J0636+5128_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J0636-3044_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J0636-3044_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J0636-3044_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J0645+5158_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J0645+5158_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J0645+5158_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J0709+0458_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J0709+0458_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J0709+0458_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J0711-6830_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J0711-6830_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J0711-6830_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J0740+6620_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J0740+6620_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J0740+6620_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J0751+1807_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J0751+1807_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J0751+1807_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J0900-3144_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J0900-3144_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J0900-3144_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J0931-1902_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J0931-1902_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J0931-1902_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J0955-6150_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J0955-6150_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J0955-6150_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1012+5307_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1012+5307_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1012+5307_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1012-4235_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1012-4235_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1012-4235_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1017-7156_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1017-7156_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1017-7156_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1022+1001_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1022+1001_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1022+1001_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1024-0719_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1024-0719_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1024-0719_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1036-8317_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1036-8317_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1036-8317_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1045-4509_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1045-4509_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1045-4509_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1101-6424_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1101-6424_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1101-6424_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1103-5403_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1103-5403_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1103-5403_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1125+7819_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1125+7819_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1125+7819_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1125-5825_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1125-5825_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1125-5825_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1125-6014_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1125-6014_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1125-6014_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1216-6410_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1216-6410_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1216-6410_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1312+0051_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1312+0051_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1312+0051_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1327-0755_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1327-0755_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1327-0755_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1421-4409_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1421-4409_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1421-4409_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1431-5740_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1431-5740_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1431-5740_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1435-6100_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1435-6100_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1435-6100_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1446-4701_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1446-4701_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1446-4701_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1453+1902_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1453+1902_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1453+1902_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1455-3330_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1455-3330_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1455-3330_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1525-5545_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1525-5545_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1525-5545_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1543-5149_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1543-5149_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1543-5149_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1545-4550_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1545-4550_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1545-4550_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1547-5709_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1547-5709_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1547-5709_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1600-3053_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1600-3053_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1600-3053_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1603-7202_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1603-7202_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1603-7202_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1614-2230_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1614-2230_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1614-2230_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1629-6902_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1629-6902_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1629-6902_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1630+3734_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1630+3734_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1630+3734_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1640+2224_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1640+2224_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1640+2224_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1643-1224_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1643-1224_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1643-1224_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1652-4838_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1652-4838_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1652-4838_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1653-2054_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1653-2054_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1653-2054_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1658-5324_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1658-5324_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1658-5324_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1705-1903_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1705-1903_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1705-1903_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1708-3506_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1708-3506_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1708-3506_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1713+0747_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1713+0747_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1713+0747_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1719-1438_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1719-1438_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1719-1438_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1721-2457_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1721-2457_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1721-2457_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1730-2304_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1730-2304_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1730-2304_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1732-5049_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1732-5049_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1732-5049_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1737-0811_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1737-0811_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1737-0811_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1738+0333_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1738+0333_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1738+0333_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1741+1351_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1741+1351_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1741+1351_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1744-1134_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1744-1134_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1744-1134_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1745+1017_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1745+1017_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1745+1017_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1747-4036_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1747-4036_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1747-4036_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1751-2857_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1751-2857_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1751-2857_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1756-2251_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1756-2251_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1756-2251_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1757-5322_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1757-5322_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1757-5322_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1801-1417_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1801-1417_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1801-1417_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1802-2124_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1802-2124_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1802-2124_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1804-2717_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1804-2717_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1804-2717_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1811-2405_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1811-2405_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1811-2405_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1824-2452A_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1824-2452A_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1824-2452A_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1825-0319_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1825-0319_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1825-0319_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1832-0836_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1832-0836_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1832-0836_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1843-1113_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1843-1113_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1843-1113_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1853+1303_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1853+1303_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1853+1303_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1902-5105_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1902-5105_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1902-5105_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1903+0327_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1903+0327_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1903+0327_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1903-7051_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1903-7051_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1903-7051_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1909-3744_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1909-3744_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1909-3744_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1910+1256_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1910+1256_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1910+1256_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1911+1347_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1911+1347_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1911+1347_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1918-0642_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1918-0642_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1918-0642_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1923+2515_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1923+2515_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1923+2515_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1933-6211_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1933-6211_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1933-6211_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1944+0907_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1944+0907_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1944+0907_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1946+3417_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1946+3417_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1946+3417_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J1946-5403_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J1946-5403_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J1946-5403_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J2010-1323_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J2010-1323_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J2010-1323_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J2017+0603_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J2017+0603_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J2017+0603_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J2033+1734_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J2033+1734_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J2033+1734_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J2039-3616_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J2039-3616_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J2039-3616_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J2043+1711_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J2043+1711_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J2043+1711_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J2124-3358_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J2124-3358_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J2124-3358_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J2129-5721_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J2129-5721_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J2129-5721_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J2145-0750_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J2145-0750_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J2145-0750_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J2150-0326_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J2150-0326_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J2150-0326_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J2214+3000_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J2214+3000_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J2214+3000_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J2222-0137_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J2222-0137_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J2222-0137_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J2229+2643_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J2229+2643_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J2229+2643_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J2234+0611_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J2234+0611_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J2234+0611_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J2234+0944_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J2234+0944_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J2234+0944_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J2241-5236_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J2241-5236_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J2241-5236_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J2302+4442_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J2302+4442_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J2302+4442_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J2317+1439_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J2317+1439_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J2317+1439_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J2322+2057_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J2322+2057_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J2322+2057_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
#
# Duplicate signal J2322-2650_cw from objects <Enterprise Signal object cw[cw2_log10_h0, cw2_log10_f0, cw2_ra, cw2_sindec, cw2_cosinc, cw2_psi, cw2_phi_earth, J2322-2650_cw_p_dist]> and <Enterprise Signal object cw[cw_log10_h0, cw_log10_f0, cw_ra, cw_sindec, cw_cosinc, cw_psi, cw_phi_earth, J2322-2650_cw_p_dist]>.
# This functionality was added in v1.1.0 and may cause post v1.1.0 functionality to break.
# This may not cause other errors but it is recommended that you use a custom name for one of the duplicate signals.
# B1855+09
# B1937+21
# B1953+29
# J0023+0923
# J0030+0451
# J0125-2327
# J0340+4130
# J0406+3039
# J0437-4715
# J0509+0856
# J0557+1551
# J0605+3757
# J0610-2100
# J0613-0200
# J0614-3329
# J0636+5128
# J0636-3044
# J0645+5158
# J0709+0458
# J0711-6830
# J0740+6620
# J0751+1807
# J0900-3144
# J0931-1902
# J0955-6150
# J1012+5307
# J1012-4235
# J1017-7156
# J1022+1001
# J1024-0719
# J1036-8317
# J1045-4509
# J1101-6424
# J1103-5403
# J1125+7819
# J1125-5825
# J1125-6014
# J1216-6410
# J1312+0051
# J1327-0755
# J1421-4409
# J1431-5740
# J1435-6100
# J1446-4701
# J1453+1902
# J1455-3330
# J1525-5545
# J1543-5149
# J1545-4550
# J1547-5709
# J1600-3053
# J1603-7202
# J1614-2230
# J1629-6902
# J1630+3734
# J1640+2224
# J1643-1224
# J1652-4838
# J1653-2054
# J1658-5324
# J1705-1903
# J1708-3506
# J1713+0747
# J1719-1438
# J1721-2457
# J1730-2304
# J1732-5049
# J1737-0811
# J1738+0333
# J1741+1351
# J1744-1134
# J1745+1017
# J1747-4036
# J1751-2857
# J1756-2251
# J1757-5322
# J1801-1417
# J1802-2124
# J1804-2717
# J1811-2405
# J1824-2452A
# J1825-0319
# J1832-0836
# J1843-1113
# J1853+1303
# J1902-5105
# J1903+0327
# J1903-7051
# J1909-3744
# J1910+1256
# J1911+1347
# J1918-0642
# J1923+2515
# J1933-6211
# J1944+0907
# J1946+3417
# J1946-5403
# J2010-1323
# J2017+0603
# J2033+1734
# J2039-3616
# J2043+1711
# J2124-3358
# J2129-5721
# J2145-0750
# J2150-0326
# J2214+3000
# J2222-0137
# J2229+2643
# J2234+0611
# J2234+0944
# J2241-5236
# J2302+4442
# J2317+1439
# J2322+2057
# J2322-2650

# %%
# Print out a summary of what's being modelled in the PTA.

print(pta.summary())
# Out:
# enterprise v3.4.4,  Python v3.12.11
# ==========================================================================================
#
# Signal Name                              Signal Class                   no. Parameters
# ==========================================================================================
# B1855+09_linear_timing_model             TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# B1855+09_measurement_noise               MeasurementNoise               0
#
# params:
# B1855+09_KAT_MKBF_efac:Constant=1
# __________________________________________________________________________________________
# B1855+09_tnequad                         TNEquadNoise                   0
#
# params:
# B1855+09_KAT_MKBF_log10_tnequad:Constant=-8
# __________________________________________________________________________________________
# B1855+09_rednoise                        FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (226, 60)
# N selected toas: 226
#
# params:
# B1855+09_rednoise_log10_A:Uniform(pmin=-18, pmax=-11)
# B1855+09_rednoise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# B1855+09_gwb                             BasisCommonGP                  2
#
# params:
# gwb_log10_A:Uniform(pmin=-18, pmax=-11)
# gwb_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# B1855+09_cw                              CWSignal                       8
#
# params:
# cw_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# B1855+09_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# B1855+09_cw                              CWSignal                       8
#
# params:
# cw2_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw2_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw2_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw2_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw2_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw2_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw2_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# B1855+09_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# B1937+21_linear_timing_model             TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# B1937+21_measurement_noise               MeasurementNoise               0
#
# params:
# B1937+21_KAT_MKBF_efac:Constant=1
# __________________________________________________________________________________________
# B1937+21_tnequad                         TNEquadNoise                   0
#
# params:
# B1937+21_KAT_MKBF_log10_tnequad:Constant=-8
# __________________________________________________________________________________________
# B1937+21_rednoise                        FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (574, 60)
# N selected toas: 574
#
# params:
# B1937+21_rednoise_log10_A:Uniform(pmin=-18, pmax=-11)
# B1937+21_rednoise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# B1937+21_gwb                             BasisCommonGP                  2
#
# params:
# gwb_log10_A:Uniform(pmin=-18, pmax=-11)
# gwb_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# B1937+21_cw                              CWSignal                       8
#
# params:
# cw_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# B1937+21_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# B1937+21_cw                              CWSignal                       8
#
# params:
# cw2_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw2_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw2_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw2_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw2_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw2_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw2_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# B1937+21_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# B1953+29_linear_timing_model             TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# B1953+29_measurement_noise               MeasurementNoise               0
#
# params:
# B1953+29_KAT_MKBF_efac:Constant=1
# __________________________________________________________________________________________
# B1953+29_tnequad                         TNEquadNoise                   0
#
# params:
# B1953+29_KAT_MKBF_log10_tnequad:Constant=-8
# __________________________________________________________________________________________
# B1953+29_rednoise                        FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (202, 60)
# N selected toas: 202
#
# params:
# B1953+29_rednoise_log10_A:Uniform(pmin=-18, pmax=-11)
# B1953+29_rednoise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# B1953+29_gwb                             BasisCommonGP                  2
#
# params:
# gwb_log10_A:Uniform(pmin=-18, pmax=-11)
# gwb_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# B1953+29_cw                              CWSignal                       8
#
# params:
# cw_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# B1953+29_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# B1953+29_cw                              CWSignal                       8
#
# params:
# cw2_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw2_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw2_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw2_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw2_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw2_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw2_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# B1953+29_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J0023+0923_linear_timing_model           TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J0023+0923_measurement_noise             MeasurementNoise               0
#
# params:
# J0023+0923_KAT_MKBF_efac:Constant=1
# __________________________________________________________________________________________
# J0023+0923_tnequad                       TNEquadNoise                   0
#
# params:
# J0023+0923_KAT_MKBF_log10_tnequad:Constant=-8
# __________________________________________________________________________________________
# J0023+0923_rednoise                      FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (155, 60)
# N selected toas: 155
#
# params:
# J0023+0923_rednoise_log10_A:Uniform(pmin=-18, pmax=-11)
# J0023+0923_rednoise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0023+0923_gwb                           BasisCommonGP                  2
#
# params:
# gwb_log10_A:Uniform(pmin=-18, pmax=-11)
# gwb_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0023+0923_cw                            CWSignal                       8
#
# params:
# cw_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J0023+0923_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J0023+0923_cw                            CWSignal                       8
#
# params:
# cw2_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw2_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw2_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw2_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw2_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw2_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw2_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J0023+0923_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J0030+0451_linear_timing_model           TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J0030+0451_measurement_noise             MeasurementNoise               0
#
# params:
# J0030+0451_KAT_MKBF_efac:Constant=1
# __________________________________________________________________________________________
# J0030+0451_tnequad                       TNEquadNoise                   0
#
# params:
# J0030+0451_KAT_MKBF_log10_tnequad:Constant=-8
# __________________________________________________________________________________________
# J0030+0451_rednoise                      FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (599, 60)
# N selected toas: 599
#
# params:
# J0030+0451_rednoise_log10_A:Uniform(pmin=-18, pmax=-11)
# J0030+0451_rednoise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0030+0451_gwb                           BasisCommonGP                  2
#
# params:
# gwb_log10_A:Uniform(pmin=-18, pmax=-11)
# gwb_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0030+0451_cw                            CWSignal                       8
#
# params:
# cw_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J0030+0451_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J0030+0451_cw                            CWSignal                       8
#
# params:
# cw2_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw2_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw2_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw2_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw2_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw2_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw2_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J0030+0451_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J0125-2327_linear_timing_model           TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J0125-2327_measurement_noise             MeasurementNoise               0
#
# params:
# J0125-2327_KAT_MKBF_efac:Constant=1
# __________________________________________________________________________________________
# J0125-2327_tnequad                       TNEquadNoise                   0
#
# params:
# J0125-2327_KAT_MKBF_log10_tnequad:Constant=-8
# __________________________________________________________________________________________
# J0125-2327_rednoise                      FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (188, 60)
# N selected toas: 188
#
# params:
# J0125-2327_rednoise_log10_A:Uniform(pmin=-18, pmax=-11)
# J0125-2327_rednoise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0125-2327_gwb                           BasisCommonGP                  2
#
# params:
# gwb_log10_A:Uniform(pmin=-18, pmax=-11)
# gwb_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0125-2327_cw                            CWSignal                       8
#
# params:
# cw_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J0125-2327_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J0125-2327_cw                            CWSignal                       8
#
# params:
# cw2_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw2_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw2_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw2_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw2_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw2_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw2_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J0125-2327_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J0340+4130_linear_timing_model           TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J0340+4130_measurement_noise             MeasurementNoise               0
#
# params:
# J0340+4130_KAT_MKBF_efac:Constant=1
# __________________________________________________________________________________________
# J0340+4130_tnequad                       TNEquadNoise                   0
#
# params:
# J0340+4130_KAT_MKBF_log10_tnequad:Constant=-8
# __________________________________________________________________________________________
# J0340+4130_rednoise                      FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (245, 60)
# N selected toas: 245
#
# params:
# J0340+4130_rednoise_log10_A:Uniform(pmin=-18, pmax=-11)
# J0340+4130_rednoise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0340+4130_gwb                           BasisCommonGP                  2
#
# params:
# gwb_log10_A:Uniform(pmin=-18, pmax=-11)
# gwb_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0340+4130_cw                            CWSignal                       8
#
# params:
# cw_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J0340+4130_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J0340+4130_cw                            CWSignal                       8
#
# params:
# cw2_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw2_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw2_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw2_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw2_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw2_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw2_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J0340+4130_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J0406+3039_linear_timing_model           TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J0406+3039_measurement_noise             MeasurementNoise               0
#
# params:
# J0406+3039_KAT_MKBF_efac:Constant=1
# __________________________________________________________________________________________
# J0406+3039_tnequad                       TNEquadNoise                   0
#
# params:
# J0406+3039_KAT_MKBF_log10_tnequad:Constant=-8
# __________________________________________________________________________________________
# J0406+3039_rednoise                      FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (198, 60)
# N selected toas: 198
#
# params:
# J0406+3039_rednoise_log10_A:Uniform(pmin=-18, pmax=-11)
# J0406+3039_rednoise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0406+3039_gwb                           BasisCommonGP                  2
#
# params:
# gwb_log10_A:Uniform(pmin=-18, pmax=-11)
# gwb_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0406+3039_cw                            CWSignal                       8
#
# params:
# cw_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J0406+3039_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J0406+3039_cw                            CWSignal                       8
#
# params:
# cw2_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw2_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw2_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw2_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw2_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw2_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw2_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J0406+3039_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J0437-4715_linear_timing_model           TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J0437-4715_measurement_noise             MeasurementNoise               0
#
# params:
# J0437-4715_KAT_MKBF_efac:Constant=1
# __________________________________________________________________________________________
# J0437-4715_tnequad                       TNEquadNoise                   0
#
# params:
# J0437-4715_KAT_MKBF_log10_tnequad:Constant=-8
# __________________________________________________________________________________________
# J0437-4715_rednoise                      FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (230, 60)
# N selected toas: 230
#
# params:
# J0437-4715_rednoise_log10_A:Uniform(pmin=-18, pmax=-11)
# J0437-4715_rednoise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0437-4715_gwb                           BasisCommonGP                  2
#
# params:
# gwb_log10_A:Uniform(pmin=-18, pmax=-11)
# gwb_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0437-4715_cw                            CWSignal                       8
#
# params:
# cw_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J0437-4715_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J0437-4715_cw                            CWSignal                       8
#
# params:
# cw2_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw2_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw2_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw2_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw2_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw2_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw2_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J0437-4715_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J0509+0856_linear_timing_model           TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J0509+0856_measurement_noise             MeasurementNoise               0
#
# params:
# J0509+0856_KAT_MKBF_efac:Constant=1
# __________________________________________________________________________________________
# J0509+0856_tnequad                       TNEquadNoise                   0
#
# params:
# J0509+0856_KAT_MKBF_log10_tnequad:Constant=-8
# __________________________________________________________________________________________
# J0509+0856_rednoise                      FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (198, 60)
# N selected toas: 198
#
# params:
# J0509+0856_rednoise_log10_A:Uniform(pmin=-18, pmax=-11)
# J0509+0856_rednoise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0509+0856_gwb                           BasisCommonGP                  2
#
# params:
# gwb_log10_A:Uniform(pmin=-18, pmax=-11)
# gwb_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0509+0856_cw                            CWSignal                       8
#
# params:
# cw_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J0509+0856_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J0509+0856_cw                            CWSignal                       8
#
# params:
# cw2_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw2_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw2_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw2_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw2_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw2_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw2_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J0509+0856_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J0557+1551_linear_timing_model           TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J0557+1551_measurement_noise             MeasurementNoise               0
#
# params:
# J0557+1551_KAT_MKBF_efac:Constant=1
# __________________________________________________________________________________________
# J0557+1551_tnequad                       TNEquadNoise                   0
#
# params:
# J0557+1551_KAT_MKBF_log10_tnequad:Constant=-8
# __________________________________________________________________________________________
# J0557+1551_rednoise                      FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (224, 60)
# N selected toas: 224
#
# params:
# J0557+1551_rednoise_log10_A:Uniform(pmin=-18, pmax=-11)
# J0557+1551_rednoise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0557+1551_gwb                           BasisCommonGP                  2
#
# params:
# gwb_log10_A:Uniform(pmin=-18, pmax=-11)
# gwb_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0557+1551_cw                            CWSignal                       8
#
# params:
# cw_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J0557+1551_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J0557+1551_cw                            CWSignal                       8
#
# params:
# cw2_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw2_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw2_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw2_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw2_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw2_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw2_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J0557+1551_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J0605+3757_linear_timing_model           TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J0605+3757_measurement_noise             MeasurementNoise               0
#
# params:
# J0605+3757_KAT_MKBF_efac:Constant=1
# __________________________________________________________________________________________
# J0605+3757_tnequad                       TNEquadNoise                   0
#
# params:
# J0605+3757_KAT_MKBF_log10_tnequad:Constant=-8
# __________________________________________________________________________________________
# J0605+3757_rednoise                      FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (193, 60)
# N selected toas: 193
#
# params:
# J0605+3757_rednoise_log10_A:Uniform(pmin=-18, pmax=-11)
# J0605+3757_rednoise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0605+3757_gwb                           BasisCommonGP                  2
#
# params:
# gwb_log10_A:Uniform(pmin=-18, pmax=-11)
# gwb_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0605+3757_cw                            CWSignal                       8
#
# params:
# cw_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J0605+3757_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J0605+3757_cw                            CWSignal                       8
#
# params:
# cw2_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw2_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw2_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw2_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw2_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw2_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw2_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J0605+3757_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J0610-2100_linear_timing_model           TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J0610-2100_measurement_noise             MeasurementNoise               0
#
# params:
# J0610-2100_KAT_MKBF_efac:Constant=1
# __________________________________________________________________________________________
# J0610-2100_tnequad                       TNEquadNoise                   0
#
# params:
# J0610-2100_KAT_MKBF_log10_tnequad:Constant=-8
# __________________________________________________________________________________________
# J0610-2100_rednoise                      FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (193, 60)
# N selected toas: 193
#
# params:
# J0610-2100_rednoise_log10_A:Uniform(pmin=-18, pmax=-11)
# J0610-2100_rednoise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0610-2100_gwb                           BasisCommonGP                  2
#
# params:
# gwb_log10_A:Uniform(pmin=-18, pmax=-11)
# gwb_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0610-2100_cw                            CWSignal                       8
#
# params:
# cw_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J0610-2100_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J0610-2100_cw                            CWSignal                       8
#
# params:
# cw2_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw2_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw2_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw2_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw2_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw2_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw2_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J0610-2100_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J0613-0200_linear_timing_model           TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J0613-0200_measurement_noise             MeasurementNoise               0
#
# params:
# J0613-0200_KAT_MKBF_efac:Constant=1
# __________________________________________________________________________________________
# J0613-0200_tnequad                       TNEquadNoise                   0
#
# params:
# J0613-0200_KAT_MKBF_log10_tnequad:Constant=-8
# __________________________________________________________________________________________
# J0613-0200_rednoise                      FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (391, 60)
# N selected toas: 391
#
# params:
# J0613-0200_rednoise_log10_A:Uniform(pmin=-18, pmax=-11)
# J0613-0200_rednoise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0613-0200_gwb                           BasisCommonGP                  2
#
# params:
# gwb_log10_A:Uniform(pmin=-18, pmax=-11)
# gwb_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0613-0200_cw                            CWSignal                       8
#
# params:
# cw_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J0613-0200_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J0613-0200_cw                            CWSignal                       8
#
# params:
# cw2_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw2_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw2_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw2_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw2_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# ...
# gwb_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J2241-5236_cw                            CWSignal                       8
#
# params:
# cw_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J2241-5236_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J2241-5236_cw                            CWSignal                       8
#
# params:
# cw2_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw2_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw2_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw2_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw2_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw2_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw2_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J2241-5236_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J2302+4442_linear_timing_model           TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J2302+4442_measurement_noise             MeasurementNoise               0
#
# params:
# J2302+4442_KAT_MKBF_efac:Constant=1
# __________________________________________________________________________________________
# J2302+4442_tnequad                       TNEquadNoise                   0
#
# params:
# J2302+4442_KAT_MKBF_log10_tnequad:Constant=-8
# __________________________________________________________________________________________
# J2302+4442_rednoise                      FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (259, 60)
# N selected toas: 259
#
# params:
# J2302+4442_rednoise_log10_A:Uniform(pmin=-18, pmax=-11)
# J2302+4442_rednoise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J2302+4442_gwb                           BasisCommonGP                  2
#
# params:
# gwb_log10_A:Uniform(pmin=-18, pmax=-11)
# gwb_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J2302+4442_cw                            CWSignal                       8
#
# params:
# cw_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J2302+4442_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J2302+4442_cw                            CWSignal                       8
#
# params:
# cw2_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw2_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw2_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw2_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw2_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw2_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw2_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J2302+4442_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J2317+1439_linear_timing_model           TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J2317+1439_measurement_noise             MeasurementNoise               0
#
# params:
# J2317+1439_KAT_MKBF_efac:Constant=1
# __________________________________________________________________________________________
# J2317+1439_tnequad                       TNEquadNoise                   0
#
# params:
# J2317+1439_KAT_MKBF_log10_tnequad:Constant=-8
# __________________________________________________________________________________________
# J2317+1439_rednoise                      FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (559, 60)
# N selected toas: 559
#
# params:
# J2317+1439_rednoise_log10_A:Uniform(pmin=-18, pmax=-11)
# J2317+1439_rednoise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J2317+1439_gwb                           BasisCommonGP                  2
#
# params:
# gwb_log10_A:Uniform(pmin=-18, pmax=-11)
# gwb_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J2317+1439_cw                            CWSignal                       8
#
# params:
# cw_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J2317+1439_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J2317+1439_cw                            CWSignal                       8
#
# params:
# cw2_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw2_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw2_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw2_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw2_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw2_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw2_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J2317+1439_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J2322+2057_linear_timing_model           TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J2322+2057_measurement_noise             MeasurementNoise               0
#
# params:
# J2322+2057_KAT_MKBF_efac:Constant=1
# __________________________________________________________________________________________
# J2322+2057_tnequad                       TNEquadNoise                   0
#
# params:
# J2322+2057_KAT_MKBF_log10_tnequad:Constant=-8
# __________________________________________________________________________________________
# J2322+2057_rednoise                      FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (245, 60)
# N selected toas: 245
#
# params:
# J2322+2057_rednoise_log10_A:Uniform(pmin=-18, pmax=-11)
# J2322+2057_rednoise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J2322+2057_gwb                           BasisCommonGP                  2
#
# params:
# gwb_log10_A:Uniform(pmin=-18, pmax=-11)
# gwb_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J2322+2057_cw                            CWSignal                       8
#
# params:
# cw_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J2322+2057_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J2322+2057_cw                            CWSignal                       8
#
# params:
# cw2_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw2_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw2_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw2_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw2_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw2_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw2_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J2322+2057_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J2322-2650_linear_timing_model           TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J2322-2650_measurement_noise             MeasurementNoise               0
#
# params:
# J2322-2650_KAT_MKBF_efac:Constant=1
# __________________________________________________________________________________________
# J2322-2650_tnequad                       TNEquadNoise                   0
#
# params:
# J2322-2650_KAT_MKBF_log10_tnequad:Constant=-8
# __________________________________________________________________________________________
# J2322-2650_rednoise                      FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (168, 60)
# N selected toas: 168
#
# params:
# J2322-2650_rednoise_log10_A:Uniform(pmin=-18, pmax=-11)
# J2322-2650_rednoise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J2322-2650_gwb                           BasisCommonGP                  2
#
# params:
# gwb_log10_A:Uniform(pmin=-18, pmax=-11)
# gwb_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J2322-2650_cw                            CWSignal                       8
#
# params:
# cw_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J2322-2650_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# J2322-2650_cw                            CWSignal                       8
#
# params:
# cw2_log10_h0:Uniform(pmin=-18.0, pmax=-11.0)
# cw2_log10_f0:Uniform(pmin=-9.0, pmax=-7.0)
# cw2_ra:Uniform(pmin=0.0, pmax=6.283185307179586)
# cw2_sindec:Uniform(pmin=-1.0, pmax=1.0)
# cw2_cosinc:Uniform(pmin=-1.0, pmax=1.0)
# cw2_psi:Uniform(pmin=0, pmax=3.141592653589793)
# cw2_phi_earth:Uniform(pmin=0.0, pmax=6.283185307179586)
# J2322-2650_cw_p_dist:Uniform(pmin=0.1, pmax=10)
# __________________________________________________________________________________________
# ==========================================================================================
# Total params: 2552
# Varying params: 2320
# Common params: 1856
# Fixed params: 232
# Number of pulsars: 116

# %% [markdown]
# #### Parameter value selection
#
# To define the parameters we want to simulate, it's easiest just to load in a dictionary describing them.
#
# - I'm including random value achromatic red noise from a "realistic" distribution. Currently it is extremely weak and undetectable (between -18 and -17) so that the rest can be tested. (tag: rednoise)
# - The pulsar distances are being injected at their logged values that have been manually set. (tag: _cw_p_dist)
# - The stochastic background is injected at a theoretical spectral index, but incredibly weakly (tag: gw)
# - The deterministic continuous wave signal is being injected at the bottom of the cell (tag: cw)
#
#
# For clarity, descriptions of the continuous wave parameters are:
# - cw_cosinc: cosine of Inclination of GW source (radians)
# - cw_log10_f0: log10 of frequency of signal
# - cw_log10_h0: log10 of GW strain
# - cw_phi_earth: phase of signal at Earth
# - cw_psi: Polarisation angle of GW source
# - cw_ra: RA of CW source
# - cw_sindec: sin(declination) of CW source

# %%
enterprise_params ={}
enterprise_params.update({p: np.random.uniform(-18,-15) for p in pta.param_names if 'rednoise_log10_A' in p})
enterprise_params.update({p: np.random.uniform(3,4) for p in pta.param_names if 'rednoise_gamma' in p})

for psr in psrs:
    enterprise_params.update({p: psr.pdist[0] for p in pta.param_names if psr.name+'_cw_p_dist' in p})

enterprise_params.update({'gw_gamma': 4.333, 'gw_log10_A': -14.5})
enterprise_params.update({'cw_cosinc': 0, 'cw_log10_f0': -8, 'cw_log10_h0': -13, 'cw_phi_earth':np.pi, 'cw_psi': np.pi/4.0, 'cw_ra': 0.458, 'cw_sindec': 0.43})
# second det source
enterprise_params.update({'cw2_cosinc': 0, 'cw2_log10_f0': -7.5, 'cw2_log10_h0': -13, 'cw2_phi_earth':np.pi, 'cw2_psi': np.pi/4.0, 'cw2_ra': 0.158, 'cw2_sindec': 0.13})

# %%
dec1, dec2 = np.arcsin(enterprise_params['cw_sindec']), np.arcsin(enterprise_params['cw2_sindec'])
ra1, ra2 = enterprise_params['cw_ra'], enterprise_params['cw2_ra']
ang_sep = np.arccos(np.sin(dec1)*np.sin(dec2) + np.cos(dec1)*np.cos(dec2)*np.cos(ra1-ra2))

# %%
ang_sep*180/np.pi
# Out:
# np.float64(24.344115911458157)

# %%
enterprise_params
# Out:
# {'B1855+09_rednoise_log10_A': -17.844093269852827,
#  'B1937+21_rednoise_log10_A': -17.707097691150125,
#  'B1953+29_rednoise_log10_A': -17.029873709721603,
#  'J0023+0923_rednoise_log10_A': -15.301133409164677,
#  'J0030+0451_rednoise_log10_A': -17.11255166022465,
#  'J0125-2327_rednoise_log10_A': -15.09905106744675,
#  'J0340+4130_rednoise_log10_A': -16.447399446077107,
#  'J0406+3039_rednoise_log10_A': -16.889406544992713,
#  'J0437-4715_rednoise_log10_A': -16.019534448663993,
#  'J0509+0856_rednoise_log10_A': -16.725493044610776,
#  'J0557+1551_rednoise_log10_A': -17.173441192506115,
#  'J0605+3757_rednoise_log10_A': -15.359002407247074,
#  'J0610-2100_rednoise_log10_A': -15.560569962049723,
#  'J0613-0200_rednoise_log10_A': -15.832675902558282,
#  'J0614-3329_rednoise_log10_A': -16.98867113925095,
#  'J0636+5128_rednoise_log10_A': -17.98581097787469,
#  'J0636-3044_rednoise_log10_A': -15.583268875635234,
#  'J0645+5158_rednoise_log10_A': -15.291299579337483,
#  'J0709+0458_rednoise_log10_A': -16.254372202381067,
#  'J0711-6830_rednoise_log10_A': -15.907204409525255,
#  'J0740+6620_rednoise_log10_A': -15.013238540777227,
#  'J0751+1807_rednoise_log10_A': -16.567626954340447,
#  'J0900-3144_rednoise_log10_A': -15.867160193980881,
#  'J0931-1902_rednoise_log10_A': -15.271676294245388,
#  'J0955-6150_rednoise_log10_A': -16.368812045565914,
#  'J1012+5307_rednoise_log10_A': -16.29463086631633,
#  'J1012-4235_rednoise_log10_A': -17.016034034538613,
#  'J1017-7156_rednoise_log10_A': -16.245642371572924,
#  'J1022+1001_rednoise_log10_A': -17.043252315422468,
#  'J1024-0719_rednoise_log10_A': -17.07717160168745,
#  'J1036-8317_rednoise_log10_A': -17.754667953086873,
#  'J1045-4509_rednoise_log10_A': -16.687661768825535,
#  'J1101-6424_rednoise_log10_A': -15.563629463590392,
#  'J1103-5403_rednoise_log10_A': -17.3262039448355,
#  'J1125+7819_rednoise_log10_A': -17.187963416350364,
#  'J1125-5825_rednoise_log10_A': -15.083074907766807,
#  'J1125-6014_rednoise_log10_A': -17.064971582577005,
#  'J1216-6410_rednoise_log10_A': -16.801153340570856,
#  'J1312+0051_rednoise_log10_A': -16.740037359371605,
#  'J1327-0755_rednoise_log10_A': -16.255253340687627,
#  'J1421-4409_rednoise_log10_A': -16.706152225640462,
#  'J1431-5740_rednoise_log10_A': -15.221822345182943,
#  'J1435-6100_rednoise_log10_A': -16.54990576983257,
#  'J1446-4701_rednoise_log10_A': -15.688192229007825,
#  'J1453+1902_rednoise_log10_A': -16.953966701243793,
#  'J1455-3330_rednoise_log10_A': -15.06094659038365,
#  'J1525-5545_rednoise_log10_A': -17.73446197622637,
#  'J1543-5149_rednoise_log10_A': -17.128180973528544,
#  'J1545-4550_rednoise_log10_A': -15.912126076116314,
#  'J1547-5709_rednoise_log10_A': -16.403427971223074,
#  'J1600-3053_rednoise_log10_A': -17.21171076799904,
#  'J1603-7202_rednoise_log10_A': -15.097911851919648,
#  'J1614-2230_rednoise_log10_A': -15.591355758989579,
#  'J1629-6902_rednoise_log10_A': -15.510588930290853,
#  'J1630+3734_rednoise_log10_A': -16.66946377511065,
#  'J1640+2224_rednoise_log10_A': -17.350199762643374,
#  'J1643-1224_rednoise_log10_A': -16.75744039198758,
#  'J1652-4838_rednoise_log10_A': -16.002252684724812,
#  'J1653-2054_rednoise_log10_A': -16.0870540243194,
#  'J1658-5324_rednoise_log10_A': -16.470216158813926,
#  'J1705-1903_rednoise_log10_A': -15.127370590296117,
#  'J1708-3506_rednoise_log10_A': -17.938430797263496,
#  'J1713+0747_rednoise_log10_A': -15.40451664919555,
#  'J1719-1438_rednoise_log10_A': -17.413799051126475,
#  'J1721-2457_rednoise_log10_A': -15.761591510046081,
#  'J1730-2304_rednoise_log10_A': -15.802936272166715,
#  'J1732-5049_rednoise_log10_A': -17.55571634098891,
#  'J1737-0811_rednoise_log10_A': -15.252085183869653,
#  'J1738+0333_rednoise_log10_A': -16.626587164548226,
#  'J1741+1351_rednoise_log10_A': -16.440609619390006,
#  'J1744-1134_rednoise_log10_A': -15.692776618738067,
#  'J1745+1017_rednoise_log10_A': -16.29218360910983,
#  'J1747-4036_rednoise_log10_A': -15.901315816706468,
#  'J1751-2857_rednoise_log10_A': -16.588507778157393,
#  'J1756-2251_rednoise_log10_A': -16.708998239938115,
#  'J1757-5322_rednoise_log10_A': -15.781702146504625,
#  'J1801-1417_rednoise_log10_A': -15.086687080090755,
#  'J1802-2124_rednoise_log10_A': -17.91118929394941,
#  'J1804-2717_rednoise_log10_A': -16.971397476926466,
#  'J1811-2405_rednoise_log10_A': -15.29022871592232,
#  'J1824-2452A_rednoise_log10_A': -17.344614600935028,
#  'J1825-0319_rednoise_log10_A': -17.688770262132973,
#  'J1832-0836_rednoise_log10_A': -16.612660651698825,
#  'J1843-1113_rednoise_log10_A': -15.328831916439324,
#  'J1853+1303_rednoise_log10_A': -16.60604164378085,
#  'J1902-5105_rednoise_log10_A': -16.56333684837709,
#  'J1903+0327_rednoise_log10_A': -17.901991390541774,
#  'J1903-7051_rednoise_log10_A': -17.285869475497865,
#  'J1909-3744_rednoise_log10_A': -15.574744701684065,
#  'J1910+1256_rednoise_log10_A': -17.745910407668262,
#  'J1911+1347_rednoise_log10_A': -17.22373754401808,
#  'J1918-0642_rednoise_log10_A': -15.941325448023013,
#  'J1923+2515_rednoise_log10_A': -17.14510799305737,
#  'J1933-6211_rednoise_log10_A': -17.73865366146039,
#  'J1944+0907_rednoise_log10_A': -16.381031041277495,
#  'J1946+3417_rednoise_log10_A': -17.986800114295693,
#  'J1946-5403_rednoise_log10_A': -16.843418164291823,
#  'J2010-1323_rednoise_log10_A': -17.42830257063724,
#  'J2017+0603_rednoise_log10_A': -17.176025630102473,
#  'J2033+1734_rednoise_log10_A': -15.040883381624504,
#  'J2039-3616_rednoise_log10_A': -15.771964474062976,
#  'J2043+1711_rednoise_log10_A': -16.940941484825185,
#  'J2124-3358_rednoise_log10_A': -15.47347112150645,
#  'J2129-5721_rednoise_log10_A': -17.133715305853524,
#  'J2145-0750_rednoise_log10_A': -17.328284776874565,
#  'J2150-0326_rednoise_log10_A': -16.393849778068446,
#  'J2214+3000_rednoise_log10_A': -15.691507792933532,
#  'J2222-0137_rednoise_log10_A': -16.511719310284587,
#  'J2229+2643_rednoise_log10_A': -15.992547291397873,
#  'J2234+0611_rednoise_log10_A': -17.24803309795335,
#  'J2234+0944_rednoise_log10_A': -17.058324175944243,
#  'J2241-5236_rednoise_log10_A': -16.63645769751631,
#  'J2302+4442_rednoise_log10_A': -16.792338089918537,
#  'J2317+1439_rednoise_log10_A': -16.513654052832724,
#  'J2322+2057_rednoise_log10_A': -15.398454498463611,
#  'J2322-2650_rednoise_log10_A': -16.06095014495067,
#  'B1855+09_rednoise_gamma': 3.2721791365813067,
#  'B1937+21_rednoise_gamma': 3.906091780410814,
#  'B1953+29_rednoise_gamma': 3.072782132281432,
#  'J0023+0923_rednoise_gamma': 3.1506727618297723,
#  'J0030+0451_rednoise_gamma': 3.19506467186759,
#  'J0125-2327_rednoise_gamma': 3.928404864450094,
#  'J0340+4130_rednoise_gamma': 3.2062685073177484,
#  'J0406+3039_rednoise_gamma': 3.6308205122812143,
#  'J0437-4715_rednoise_gamma': 3.9526861926696437,
#  'J0509+0856_rednoise_gamma': 3.936676234895252,
#  'J0557+1551_rednoise_gamma': 3.6291305060066907,
#  'J0605+3757_rednoise_gamma': 3.1065990415679225,
#  'J0610-2100_rednoise_gamma': 3.612869802487439,
#  'J0613-0200_rednoise_gamma': 3.8411357395587182,
#  'J0614-3329_rednoise_gamma': 3.5199097594191016,
#  'J0636+5128_rednoise_gamma': 3.7712942294141665,
#  'J0636-3044_rednoise_gamma': 3.363166992804136,
#  'J0645+5158_rednoise_gamma': 3.2184188000556953,
#  'J0709+0458_rednoise_gamma': 3.256635924087954,
#  'J0711-6830_rednoise_gamma': 3.6630726333467813,
#  'J0740+6620_rednoise_gamma': 3.5495600339332603,
#  'J0751+1807_rednoise_gamma': 3.8967398421151676,
#  'J0900-3144_rednoise_gamma': 3.743002905236364,
#  'J0931-1902_rednoise_gamma': 3.621600839380692,
#  'J0955-6150_rednoise_gamma': 3.944109732540811,
#  'J1012+5307_rednoise_gamma': 3.368557752502384,
#  'J1012-4235_rednoise_gamma': 3.7919872682359945,
#  'J1017-7156_rednoise_gamma': 3.195193871788209,
#  'J1022+1001_rednoise_gamma': 3.420421495440979,
#  'J1024-0719_rednoise_gamma': 3.504436371872547,
#  'J1036-8317_rednoise_gamma': 3.636937825586846,
#  'J1045-4509_rednoise_gamma': 3.8774309727058993,
#  'J1101-6424_rednoise_gamma': 3.303821937056708,
#  'J1103-5403_rednoise_gamma': 3.912499469729812,
#  'J1125+7819_rednoise_gamma': 3.8060263555618374,
#  'J1125-5825_rednoise_gamma': 3.055974802254563,
#  'J1125-6014_rednoise_gamma': 3.9293630760397655,
#  'J1216-6410_rednoise_gamma': 3.761666500132501,
#  'J1312+0051_rednoise_gamma': 3.9632007249819816,
#  'J1327-0755_rednoise_gamma': 3.170039810691237,
#  'J1421-4409_rednoise_gamma': 3.6108637460008994,
#  'J1431-5740_rednoise_gamma': 3.8479279979865666,
#  'J1435-6100_rednoise_gamma': 3.391059853607382,
#  'J1446-4701_rednoise_gamma': 3.7833181889216503,
#  'J1453+1902_rednoise_gamma': 3.5590502776292396,
#  'J1455-3330_rednoise_gamma': 3.813189240514056,
#  'J1525-5545_rednoise_gamma': 3.39092372318136,
#  'J1543-5149_rednoise_gamma': 3.4411288807356892,
#  'J1545-4550_rednoise_gamma': 3.768026152479565,
#  'J1547-5709_rednoise_gamma': 3.4012752353071094,
#  'J1600-3053_rednoise_gamma': 3.5080271930376012,
#  'J1603-7202_rednoise_gamma': 3.501211563897204,
#  'J1614-2230_rednoise_gamma': 3.4037605041189725,
#  'J1629-6902_rednoise_gamma': 3.4647523841332584,
#  'J1630+3734_rednoise_gamma': 3.1975126794975446,
#  'J1640+2224_rednoise_gamma': 3.5326479033529052,
#  'J1643-1224_rednoise_gamma': 3.342609188396467,
#  'J1652-4838_rednoise_gamma': 3.374005418328984,
#  'J1653-2054_rednoise_gamma': 3.0630950236552756,
#  'J1658-5324_rednoise_gamma': 3.04862884028009,
#  'J1705-1903_rednoise_gamma': 3.9016634386421423,
#  'J1708-3506_rednoise_gamma': 3.014901553282345,
#  'J1713+0747_rednoise_gamma': 3.942214672513111,
#  'J1719-1438_rednoise_gamma': 3.6755552819591344,
#  'J1721-2457_rednoise_gamma': 3.5375326356814156,
#  'J1730-2304_rednoise_gamma': 3.1508862726375995,
#  'J1732-5049_rednoise_gamma': 3.977040922265605,
#  'J1737-0811_rednoise_gamma': 3.35718331051232,
#  'J1738+0333_rednoise_gamma': 3.313092037144819,
#  'J1741+1351_rednoise_gamma': 3.6809563248619193,
#  'J1744-1134_rednoise_gamma': 3.751814459020797,
#  'J1745+1017_rednoise_gamma': 3.1910426019064104,
#  'J1747-4036_rednoise_gamma': 3.7786422917977935,
#  'J1751-2857_rednoise_gamma': 3.3075856826318533,
#  'J1756-2251_rednoise_gamma': 3.68552200163587,
#  'J1757-5322_rednoise_gamma': 3.1600036967662746,
#  'J1801-1417_rednoise_gamma': 3.4694172713010736,
#  'J1802-2124_rednoise_gamma': 3.756367379168017,
#  'J1804-2717_rednoise_gamma': 3.220271714260197,
#  'J1811-2405_rednoise_gamma': 3.70365099599883,
#  'J1824-2452A_rednoise_gamma': 3.4140241026275557,
#  'J1825-0319_rednoise_gamma': 3.0127530909911444,
#  'J1832-0836_rednoise_gamma': 3.5312378486120304,
#  'J1843-1113_rednoise_gamma': 3.816831018522119,
#  'J1853+1303_rednoise_gamma': 3.072057652858233,
#  'J1902-5105_rednoise_gamma': 3.5322778637870846,
#  'J1903+0327_rednoise_gamma': 3.2235364525786285,
#  'J1903-7051_rednoise_gamma': 3.773847855314162,
#  'J1909-3744_rednoise_gamma': 3.427277895215057,
#  'J1910+1256_rednoise_gamma': 3.613575548754338,
#  'J1911+1347_rednoise_gamma': 3.2151117961785562,
#  'J1918-0642_rednoise_gamma': 3.005967762173021,
#  'J1923+2515_rednoise_gamma': 3.9483392106397597,
#  'J1933-6211_rednoise_gamma': 3.1378637680715142,
#  'J1944+0907_rednoise_gamma': 3.824299814325582,
#  'J1946+3417_rednoise_gamma': 3.983016895441919,
#  'J1946-5403_rednoise_gamma': 3.9379112157001837,
#  'J2010-1323_rednoise_gamma': 3.8799366742761254,
#  'J2017+0603_rednoise_gamma': 3.732369884087037,
#  'J2033+1734_rednoise_gamma': 3.9466857423786514,
#  'J2039-3616_rednoise_gamma': 3.418949054958035,
#  'J2043+1711_rednoise_gamma': 3.450450044544467,
#  'J2124-3358_rednoise_gamma': 3.341434087841347,
#  'J2129-5721_rednoise_gamma': 3.195422380096664,
#  'J2145-0750_rednoise_gamma': 3.8940637375572082,
#  'J2150-0326_rednoise_gamma': 3.1998452690678136,
#  'J2214+3000_rednoise_gamma': 3.905044143143213,
#  'J2222-0137_rednoise_gamma': 3.7605521547497935,
#  'J2229+2643_rednoise_gamma': 3.928169936298047,
#  'J2234+0611_rednoise_gamma': 3.628463448531674,
#  'J2234+0944_rednoise_gamma': 3.2726411975651213,
#  'J2241-5236_rednoise_gamma': 3.2404819422484716,
#  'J2302+4442_rednoise_gamma': 3.44172625406144,
#  'J2317+1439_rednoise_gamma': 3.290973086132614,
#  'J2322+2057_rednoise_gamma': 3.5024908990615025,
#  'J2322-2650_rednoise_gamma': 3.608788146103545,
#  'B1855+09_cw_p_dist': 1.18,
#  'B1937+21_cw_p_dist': 3.1,
#  'B1953+29_cw_p_dist': 4.64,
#  'J0023+0923_cw_p_dist': 1.02,
#  'J0030+0451_cw_p_dist': 0.3296,
#  'J0125-2327_cw_p_dist': 0.873,
#  'J0340+4130_cw_p_dist': 1.71,
#  'J0406+3039_cw_p_dist': 1.72,
#  'J0437-4715_cw_p_dist': 0.1549,
#  'J0509+0856_cw_p_dist': 1.45,
#  'J0557+1551_cw_p_dist': 2.87,
#  'J0605+3757_cw_p_dist': 0.7,
#  'J0610-2100_cw_p_dist': 1.38,
#  'J0613-0200_cw_p_dist': 1.07,
#  'J0614-3329_cw_p_dist': 0.63,
#  'J0636+5128_cw_p_dist': 1.27,
#  'J0636-3044_cw_p_dist': 0.679,
#  'J0645+5158_cw_p_dist': 1.37,
#  'J0709+0458_cw_p_dist': 1.8,
#  'J0711-6830_cw_p_dist': 0.106,
#  'J0740+6620_cw_p_dist': 0.94,
#  'J0751+1807_cw_p_dist': 1.17,
#  'J0900-3144_cw_p_dist': 0.89,
#  'J0931-1902_cw_p_dist': 1.88,
#  'J0955-6150_cw_p_dist': 2.172,
#  'J1012+5307_cw_p_dist': 0.862,
#  'J1012-4235_cw_p_dist': 2.5,
#  'J1017-7156_cw_p_dist': 1.807,
#  'J1022+1001_cw_p_dist': 0.706,
#  'J1024-0719_cw_p_dist': 1.08,
#  'J1036-8317_cw_p_dist': 0.934,
#  'J1045-4509_cw_p_dist': 0.34,
#  'J1101-6424_cw_p_dist': 2.175,
#  'J1103-5403_cw_p_dist': 1.683,
#  'J1125+7819_cw_p_dist': 0.63,
#  'J1125-5825_cw_p_dist': 1.744,
#  'J1125-6014_cw_p_dist': 0.988,
#  'J1216-6410_cw_p_dist': 1.098,
#  'J1312+0051_cw_p_dist': 0.84,
#  'J1327-0755_cw_p_dist': 25.0,
#  'J1421-4409_cw_p_dist': 2.085,
#  'J1431-5740_cw_p_dist': 3.553,
#  'J1435-6100_cw_p_dist': 2.816,
#  'J1446-4701_cw_p_dist': 1.569,
#  'J1453+1902_cw_p_dist': 1.15,
#  'J1455-3330_cw_p_dist': 1.01,
#  'J1525-5545_cw_p_dist': 3.14,
#  'J1543-5149_cw_p_dist': 1.149,
#  'J1545-4550_cw_p_dist': 2.222,
#  'J1547-5709_cw_p_dist': 2.695,
#  'J1600-3053_cw_p_dist': 1.84,
#  'J1603-7202_cw_p_dist': 3.7,
#  'J1614-2230_cw_p_dist': 0.699,
#  'J1629-6902_cw_p_dist': 0.963,
#  'J1630+3734_cw_p_dist': 0.089,
#  'J1640+2224_cw_p_dist': 1.404,
#  'J1643-1224_cw_p_dist': 0.835,
#  'J1652-4838_cw_p_dist': 4.395,
#  'J1653-2054_cw_p_dist': 2.631,
#  'J1658-5324_cw_p_dist': 0.88,
#  'J1705-1903_cw_p_dist': 1.62,
#  'J1708-3506_cw_p_dist': 3.32,
#  'J1713+0747_cw_p_dist': 1.138,
#  'J1719-1438_cw_p_dist': 1.21,
#  'J1721-2457_cw_p_dist': 1.393,
#  'J1730-2304_cw_p_dist': 0.529,
#  'J1732-5049_cw_p_dist': 1.873,
#  'J1737-0811_cw_p_dist': 0.206,
#  'J1738+0333_cw_p_dist': 1.64,
#  'J1741+1351_cw_p_dist': 2.36,
#  'J1744-1134_cw_p_dist': 0.4141,
#  'J1745+1017_cw_p_dist': 1.27,
#  'J1747-4036_cw_p_dist': 3.5,
#  'J1751-2857_cw_p_dist': 1.11,
#  'J1756-2251_cw_p_dist': 0.73,
#  'J1757-5322_cw_p_dist': 0.945,
#  'J1801-1417_cw_p_dist': 1.0,
#  'J1802-2124_cw_p_dist': 2.96,
#  'J1804-2717_cw_p_dist': 0.8,
#  'J1811-2405_cw_p_dist': 1.79,
#  'J1824-2452A_cw_p_dist': 5.37,
#  'J1825-0319_cw_p_dist': 3.862,
#  'J1832-0836_cw_p_dist': 2.0,
#  'J1843-1113_cw_p_dist': 1.72,
#  'J1853+1303_cw_p_dist': 1.91,
#  'J1902-5105_cw_p_dist': 1.645,
#  'J1903+0327_cw_p_dist': 6.49,
#  'J1903-7051_cw_p_dist': 0.93,
#  'J1909-3744_cw_p_dist': 1.159,
#  'J1910+1256_cw_p_dist': 3.52,
#  'J1911+1347_cw_p_dist': 2.08,
#  'J1918-0642_cw_p_dist': 1.44,
#  'J1923+2515_cw_p_dist': 0.94,
#  'J1933-6211_cw_p_dist': 0.65,
#  'J1944+0907_cw_p_dist': 1.38,
#  'J1946+3417_cw_p_dist': 5.12,
#  'J1946-5403_cw_p_dist': 1.15,
#  'J2010-1323_cw_p_dist': 1.94,
#  'J2017+0603_cw_p_dist': 1.57,
#  'J2033+1734_cw_p_dist': 1.99,
#  'J2039-3616_cw_p_dist': 1.704,
#  'J2043+1711_cw_p_dist': 1.58,
#  'J2124-3358_cw_p_dist': 0.413,
#  'J2129-5721_cw_p_dist': 3.2,
#  'J2145-0750_cw_p_dist': 0.624,
#  'J2150-0326_cw_p_dist': 1.972,
#  'J2214+3000_cw_p_dist': 1.54,
#  'J2222-0137_cw_p_dist': 0.268,
#  'J2229+2643_cw_p_dist': 1.43,
#  'J2234+0611_cw_p_dist': 1.23,
#  'J2234+0944_cw_p_dist': 1.0,
#  'J2241-5236_cw_p_dist': 1.042,
#  'J2302+4442_cw_p_dist': 1.18,
#  'J2317+1439_cw_p_dist': 1.57,
#  'J2322+2057_cw_p_dist': 1.0,
#  'J2322-2650_cw_p_dist': 0.227,
#  'gw_gamma': 4.333,
#  'gw_log10_A': -14.5,
#  'cw_cosinc': 0,
#  'cw_log10_f0': -8,
#  'cw_log10_h0': -13,
#  'cw_phi_earth': 3.141592653589793,
#  'cw_psi': 0.7853981633974483,
#  'cw_ra': 0.458,
#  'cw_sindec': 0.43,
#  'cw2_cosinc': 0,
#  'cw2_log10_f0': -7.5,
#  'cw2_log10_h0': -13,
#  'cw2_phi_earth': 3.141592653589793,
#  'cw2_psi': 0.7853981633974483,
#  'cw2_ra': 0.158,
#  'cw2_sindec': 0.13}

# %%
# Based on the above parameters, simulate the new timing residuals

res = simulate(pta, enterprise_params, sparse_cholesky=True)

# %%
# Check Enterprise simulated residuals
plt.figure(figsize=(15,5))
for i, res_i in enumerate(res):
    plt.errorbar(psrs[i].toas, res_i, yerr=psrs[i].toaerrs, fmt='o')
    plt.xlabel('MJD')   
    plt.ylabel('Residuals (s)')
    plt.title("Example PTA with CW signal Injected")

# %% [markdown]
# ##### Now set up differentiable likelihood
#
# - First, we want to reload the original data products into the discovery software (https://github.com/nanograv/discovery/tree/main) so that an original data object can be created.
# - Then, overwrite the discovery pulsar residuals with the simulated residuals we created above

# %%
disco_psrs = [ds.Pulsar.read_feather(psrfile) for psrfile in sorted(glob.glob(feather_dir+'*.feather'))]

# %%
for i, dpsr in enumerate(disco_psrs):
    dpsr.residuals = np.array(res[i])

# %% [markdown]
# I am arbitrarily decreasing the level of white noise in the residuals for now. I want a relatively noiseless signal.

# %%
for dpsr in disco_psrs:
    wn_level = 1e-6
    dpsr.toaerrs = np.array(len(dpsr.toas) *[wn_level])

# %%
#Check the new data that the signal is consistent with the previous plot

plt.figure(figsize=(15,5))
for i, dpsr in enumerate(disco_psrs):
    plt.errorbar(dpsr.toas, dpsr.residuals, yerr=dpsr.toaerrs, fmt='o')
    plt.xlabel('MJD')   
    plt.ylabel('Residuals (s)')
    plt.title("Example PTA with CW signal Injected")

# %% [markdown]
# #### Set up signal model for continuous wave for use in differentiable lnL
#
# This is a simple model that includes a dependence on pulsar distances. This model has no evolution yet, but that will change.

# %%
# Custom function to use the p_dist rather than p_phase


def fpc_fast(pos, gwtheta, gwphi):
    x, y, z = pos

    sin_phi = jnp.sin(gwphi)
    cos_phi = jnp.cos(gwphi)
    sin_theta = jnp.sin(gwtheta)
    cos_theta = jnp.cos(gwtheta)

    m_dot_pos = sin_phi * x - cos_phi * y
    n_dot_pos = -cos_theta * cos_phi * x - cos_theta * sin_phi * y + sin_theta * z
    omhat_dot_pos = -sin_theta * cos_phi * x - sin_theta * sin_phi * y - cos_theta * z

    denom = 1.0 + omhat_dot_pos

    fplus = 0.5 * (m_dot_pos**2 - n_dot_pos**2) / denom
    fcross = (m_dot_pos * n_dot_pos) / denom

    return fplus, fcross
    
def cos2comp(f, df, A, f0, phi, t0):
    """Project signal A * cos(2pi f t + phi) onto Fourier basis
    cos(2pi k t/T), sin(2pi k t/T) for t in [t0, t0+T]."""

    T = 1.0 / df[0]

    Delta_omega = 2.0 * jnp.pi * (f0 - f[::2])
    Sigma_omega = 2.0 * jnp.pi * (f0 + f[::2])

    phase_Delta_start = phi + Delta_omega * t0
    phase_Delta_end   = phi + Delta_omega * (t0 + T)

    phase_Sigma_start = phi + Sigma_omega * t0
    phase_Sigma_end   = phi + Sigma_omega * (t0 + T)

    ck = (A / T) * (
        (jnp.sin(phase_Delta_end) - jnp.sin(phase_Delta_start)) / Delta_omega +
        (jnp.sin(phase_Sigma_end) - jnp.sin(phase_Sigma_start)) / Sigma_omega
    )

    sk = (A / T) * (
        (jnp.cos(phase_Delta_end) - jnp.cos(phase_Delta_start)) / Delta_omega -
        (jnp.cos(phase_Sigma_end) - jnp.cos(phase_Sigma_start)) / Sigma_omega
    )

    return jnp.stack((sk, ck), axis=1).reshape(-1)



def makefourier_binary_pdist(pulsarterm=True):
    def fourier_binary_pdist(f, df, mintoa, pos, log10_h0, log10_f0, ra, sindec, cosinc, psi, phi_earth, p_dist):
        h0 = 10**log10_h0
        f0 = 10**log10_f0

        pos = jnp.array(pos)
        
        dec, inc = jnp.arcsin(sindec), jnp.arccos(cosinc)

        # calculate antenna pattern
        fplus, fcross = fpc_fast(pos, 0.5 * jnp.pi - dec, ra)

        c = 2.99792458e8 
        omega_hat = jnp.array([ -jnp.cos(dec) * jnp.cos(ra), 
                                -jnp.cos(dec) * jnp.sin(ra),
                                -jnp.sin(dec)
                              ])

        # Convert pulsar distance from kpc to meters to match c [m/s]
        p_dist_m = p_dist * 3.0856775814913673e19  # 1 kpc in meters
        phi_psr = (p_dist_m / c) * 2.0 * jnp.pi * f0  * (1.0 + jnp.dot(omega_hat, pos))

        if pulsarterm:
            phi_avg = 0.5 * (phi_earth + phi_psr)
        else:
            phi_avg = phi_earth

        tref = 86400.0 * 51544.5  # MJD J2000 in seconds

        cphase = cos2comp(f, df, 1.0, f0, phi_avg - 2.0 * jnp.pi * f0 * tref, mintoa)
        sphase = cos2comp(f, df, 1.0, f0, phi_avg - 2.0 * jnp.pi * f0 * tref - 0.5 * jnp.pi, mintoa)

        if pulsarterm:
            phi_diff = 0.5 * (phi_earth - phi_psr)
            sin_diff = jnp.sin(phi_diff)

            delta_sin =  2.0 * cphase * sin_diff
            delta_cos = -2.0 * sphase * sin_diff
        else:
            delta_sin = sphase
            delta_cos = cphase

        At = -1.0 * (1.0 + jnp.cos(inc)**2) * delta_sin
        Bt =  2.0 * jnp.cos(inc) * delta_cos

        alpha = h0 / (2 * jnp.pi * f0)

        rplus  = alpha * (-At * jnp.cos(2 * psi) + Bt * jnp.sin(2 * psi))
        rcross = alpha * ( At * jnp.sin(2 * psi) + Bt * jnp.cos(2 * psi))

        res = -fplus * rplus - fcross * rcross

        return res

    if not pulsarterm:
        fourier_binary_pdist = functools.partial(fourier_binary, p_dist=jnp.nan)

    return fourier_binary_pdist

# %%
def makefourier_binary_pdist_twoD(pulsarterm=True):
    def fourier_binary_pdist_twoD(f, df, mintoa, pos, log10_h0, log10_f0, ra, sindec, cosinc, psi, phi_earth, 
                             log10_h0_2, log10_f0_2, ra_2, sindec_2, cosinc_2, psi_2, phi_earth_2, p_dist):
        
        h0 = 10**log10_h0
        f0 = 10**log10_f0

        h0_2 = 10**log10_h0_2
        f0_2 = 10**log10_f0_2

        pos = jnp.array(pos)
        
        dec, inc = jnp.arcsin(sindec), jnp.arccos(cosinc)
        dec_2, inc_2 = jnp.arcsin(sindec_2), jnp.arccos(cosinc_2)

        # calculate antenna pattern
        fplus, fcross = fpc_fast(pos, 0.5 * jnp.pi - dec, ra)
        fplus_2, fcross_2 = fpc_fast(pos, 0.5 * jnp.pi - dec_2, ra_2)

        c = 2.99792458e8 
        omega_hat = jnp.array([ -jnp.cos(dec) * jnp.cos(ra), 
                                -jnp.cos(dec) * jnp.sin(ra),
                                -jnp.sin(dec)
                              ])
        omega_hat_2 = jnp.array([ -jnp.cos(dec_2) * jnp.cos(ra_2), 
                                -jnp.cos(dec_2) * jnp.sin(ra_2),
                                -jnp.sin(dec_2)
                              ])

        # Convert pulsar distance from kpc to meters to match c [m/s]
        p_dist_m = p_dist * 3.0856775814913673e19  # 1 kpc in meters
        phi_psr = (p_dist_m / c) * 2.0 * jnp.pi * f0  * (1.0 + jnp.dot(omega_hat, pos))

        phi_psr_2 = (p_dist_m / c) * 2.0 * jnp.pi * f0_2  * (1.0 + jnp.dot(omega_hat_2, pos))


        if pulsarterm:
            phi_avg = 0.5 * (phi_earth + phi_psr)
            phi_avg_2 = 0.5 * (phi_earth_2 + phi_psr_2)
        else:
            phi_avg = phi_earth
            phi_avg_2 = phi_earth_2

        tref = 86400.0 * 51544.5  # MJD J2000 in seconds

        cphase = cos2comp(f, df, 1.0, f0, phi_avg - 2.0 * jnp.pi * f0 * tref, mintoa)
        sphase = cos2comp(f, df, 1.0, f0, phi_avg - 2.0 * jnp.pi * f0 * tref - 0.5 * jnp.pi, mintoa)

        cphase_2 = cos2comp(f, df, 1.0, f0_2, phi_avg_2 - 2.0 * jnp.pi * f0_2 * tref, mintoa)
        sphase_2 = cos2comp(f, df, 1.0, f0_2, phi_avg_2 - 2.0 * jnp.pi * f0_2 * tref - 0.5 * jnp.pi, mintoa)

        if pulsarterm:
            phi_diff = 0.5 * (phi_earth - phi_psr)
            sin_diff = jnp.sin(phi_diff)

            delta_sin =  2.0 * cphase * sin_diff
            delta_cos = -2.0 * sphase * sin_diff

            phi_diff_2 = 0.5 * (phi_earth_2 - phi_psr_2)
            sin_diff_2 = jnp.sin(phi_diff_2)

            delta_sin_2 =  2.0 * cphase_2 * sin_diff_2
            delta_cos_2 = -2.0 * sphase_2 * sin_diff_2
        else:
            delta_sin = sphase
            delta_cos = cphase

        At = -1.0 * (1.0 + jnp.cos(inc)**2) * delta_sin
        Bt =  2.0 * jnp.cos(inc) * delta_cos

        At_2 = -1.0 * (1.0 + jnp.cos(inc_2)**2) * delta_sin_2
        Bt_2 =  2.0 * jnp.cos(inc_2) * delta_cos_2

        alpha = h0 / (2 * jnp.pi * f0)

        alpha_2 = h0_2 / (2 * jnp.pi * f0_2)

        rplus  = alpha * (-At * jnp.cos(2 * psi) + Bt * jnp.sin(2 * psi))
        rcross = alpha * ( At * jnp.sin(2 * psi) + Bt * jnp.cos(2 * psi))


        rplus_2  = alpha_2 * (-At_2 * jnp.cos(2 * psi_2) + Bt_2 * jnp.sin(2 * psi_2))
        rcross_2 = alpha_2 * ( At_2 * jnp.sin(2 * psi_2) + Bt_2 * jnp.cos(2 * psi_2))

        res = -fplus * rplus - fcross * rcross
        res2 = -fplus_2 * rplus_2 - fcross_2 * rcross_2

        return res + res2

    if not pulsarterm:
        fourier_binary_pdist_twoD = functools.partial(fourier_binary, p_dist=jnp.nan)

    return fourier_binary_pdist_twoD

# %%
# For testing purposes, only use 10 pulsars

disco_psrs = disco_psrs[:10]

# %%
# This dictionary just fixes the white noise parameters to what was input in the model above.

noisedict = {}
for dpsr in disco_psrs:
    noisedict[dpsr.name+"_KAT_MKBF_efac"] = 1 # EFAC=1 means no EFAC
    noisedict[dpsr.name+"_KAT_MKBF_log10_ecorr"] = -8 # Bringing these down to effectively 0
    noisedict[dpsr.name+"_KAT_MKBF_log10_t2equad"] = -8

# %% [markdown]
# Below is the likelihood model of a pulsar timing array with intrinsic achromatic red noise, an uncorrelated stochastic background signal, and a deterministic continous wave signal.
#
# NB: This modelling code is extremely useful, but is also extremely in development. Because of this, we are slightly limited by what can be done to the model. But there a suitable number of trinks we can employ to get around most issues.

# %%
# Fourier based CW delay
fourdelay = makefourier_binary_pdist(pulsarterm=True)
cwcommon = ['cw_sindec', 'cw_cosinc', 'cw_log10_f0', 'cw_log10_h0', 'cw_phi_earth', 'cw_psi', 'cw_ra']

T = ds.getspan(disco_psrs)
fml = ds.ArrayLikelihood([ds.PulsarLikelihood([dpsr.residuals,
                                               ds.makenoise_measurement(dpsr, noisedict=noisedict),
                                               ds.makegp_timing(dpsr, variance=1e-14),
                                               ]) for dpsr in disco_psrs],

                          commongp = ds.makecommongp_fourier(disco_psrs, ds.powerlaw, 30, T, name='rednoise'),
                          globalgp = ds.makeglobalgp_fourier(disco_psrs, ds.powerlaw, ds.uncorrelated_orf, 14, T, means=fourdelay, common=cwcommon, name='gw', meansname='cw'))

# %%
# Fourier based CW delay
fourdelay = makefourier_binary_pdist_twoD(pulsarterm=True)
cwcommon = ['cw_sindec', 'cw_cosinc', 'cw_log10_f0', 'cw_log10_h0', 'cw_phi_earth', 'cw_psi', 'cw_ra', 'cw_sindec_2', 'cw_cosinc_2', 'cw_log10_f0_2', 'cw_log10_h0_2', 'cw_phi_earth_2', 'cw_psi_2', 'cw_ra_2']

T = ds.getspan(disco_psrs)
fml2 = ds.ArrayLikelihood([ds.PulsarLikelihood([dpsr.residuals,
                                               ds.makenoise_measurement(dpsr, noisedict=noisedict),
                                               ds.makegp_timing(dpsr, variance=1e-14),
                                               ]) for dpsr in disco_psrs],

                          commongp = ds.makecommongp_fourier(disco_psrs, ds.powerlaw, 30, T, name='rednoise'),
                          globalgp = ds.makeglobalgp_fourier(disco_psrs, ds.powerlaw, ds.hd_orf, 30, T, means=fourdelay, common=cwcommon, name='gw', meansname='cw'))

# %%
# The prior dictionary needs to be updated to include the pulsar distance priors for each pulsar.
ds.prior.priordict_standard.update({
    '(.*_)?cw_p_dist':     [0.1, 5]
})

# %%
ds.prior.priordict_standard
# Out:
# {'(.*_)?efac': [0.9, 1.1],
#  '(.*_)?t2equad': [-8.5, -5],
#  '(.*_)?tnequad': [-8.5, -5],
#  '(.*_)?log10_ecorr': [-8.5, -5],
#  '(.*_)?rednoise_log10_A.*': [-20, -11],
#  '(.*_)?rednoise_gamma.*': [0, 7],
#  '(.*_)?rednoise_log10_fb': [-9, -6],
#  '(.*_)?red_noise_log10_A.*': [-20, -11],
#  '(.*_)?red_noise_gamma.*': [0, 7],
#  '(.*_)?red_noise_log10_fb': [-9, -6],
#  'crn_log10_A.*': [-18, -11],
#  'crn_gamma.*': [0, 7],
#  'crn_log10_fb': [-9, -6],
#  'gw_(.*_)?log10_A': [-18, -11],
#  'gw_(.*_)?gamma': [0, 7],
#  'gw_log10_fb': [-9, -6],
#  '(.*_)?dmgp_log10_A': [-20, -11],
#  '(.*_)?dmgp_gamma': [0, 7],
#  '(.*_)?dmgp_alpha': [1, 3],
#  '(.*_)?chromgp_log10_A': [-20, -11],
#  '(.*_)?chromgp_gamma': [0, 7],
#  '(.*_)?chromgp_alpha': [1, 7],
#  '(.*_)?dm_gp_log10_A': [-20, -11],
#  '(.*_)?dm_gp_gamma': [0, 7],
#  '(.*_)?dm_gp_alpha': [1, 3],
#  '(.*_)?chrom_gp_log10_A': [-20, -11],
#  '(.*_)?chrom_gp_gamma': [0, 7],
#  '(.*_)?chrom_gp_alpha': [1, 3],
#  'crn_log10_rho': [-9, -4],
#  'gw_(.*_)?log10_rho': [-9, -4],
#  '(.*_)?red_noise_log10_rho\\(([0-9]*)\\)': [-9, -4],
#  '(.*_)?red_noise_crn_log10_rho\\(([0-9]*)\\)': [-9, -4],
#  'cw_ra': [0, 6.283185307179586],
#  'cw_dec': [-1.5707963267948966, 1.5707963267948966],
#  'cw_inc': [0, 3.141592653589793],
#  'cw_sindec': [-1.0, 1.0],
#  'cw_cosinc': [-1.0, 1.0],
#  'cw_psi': [0, 3.141592653589793],
#  'cw_log10_f0': [-9.0, -7.0],
#  'cw_log10_h0': [-18.0, -11.0],
#  'cw_phi_earth': [0.0, 6.283185307179586],
#  '(.*_)?cw_phi_psr': [0.0, 6.283185307179586],
#  '(.*_)?chrom1yr_log10_A': [-20, -5],
#  '(.*_)?chrom1yr_phase': [0, 6.283185307179586],
#  '(.*_)?chrom1yr_idx': [0, 14],
#  '(.*_)?chrom_bump_log10_A': [-10, -1],
#  '(.*_)?chrom_bump_idx': [0, 14],
#  '(.*_)?chrom_bump_sign_param': [-1, 1],
#  '(.*_)?sw_gp_log10_A': [-20, -11],
#  '(.*_)?sw_gp_gamma': [0, 7],
#  '(.*_)?cw_p_dist': [0.1, 5]}

# %%
# Check that the pulsars have distances associate with them

for dpsr in disco_psrs:
    print(dpsr.pdist)
# Out:
# [1.18, 0.12]
# [3.1, 0.2]
# [4.64, 0.93]
# [1.02, 0.11]
# [0.3296, 0.0036]
# [0.873, 0.1746]
# [1.71, 0.34]
# [1.72, 0.34]
# [0.1549, 0.001]
# [1.45, 0.29]

# %%
# To list the parameters in the likelihood model:

fml2.logL.params
# Out:
# ['B1855+09_cw_p_dist',
#  'B1855+09_rednoise_gamma',
#  'B1855+09_rednoise_log10_A',
#  'B1937+21_cw_p_dist',
#  'B1937+21_rednoise_gamma',
#  'B1937+21_rednoise_log10_A',
#  'B1953+29_cw_p_dist',
#  'B1953+29_rednoise_gamma',
#  'B1953+29_rednoise_log10_A',
#  'J0023+0923_cw_p_dist',
#  'J0023+0923_rednoise_gamma',
#  'J0023+0923_rednoise_log10_A',
#  'J0030+0451_cw_p_dist',
#  'J0030+0451_rednoise_gamma',
#  'J0030+0451_rednoise_log10_A',
#  'J0125-2327_cw_p_dist',
#  'J0125-2327_rednoise_gamma',
#  'J0125-2327_rednoise_log10_A',
#  'J0340+4130_cw_p_dist',
#  'J0340+4130_rednoise_gamma',
#  'J0340+4130_rednoise_log10_A',
#  'J0406+3039_cw_p_dist',
#  'J0406+3039_rednoise_gamma',
#  'J0406+3039_rednoise_log10_A',
#  'J0437-4715_cw_p_dist',
#  'J0437-4715_rednoise_gamma',
#  'J0437-4715_rednoise_log10_A',
#  'J0509+0856_cw_p_dist',
#  'J0509+0856_rednoise_gamma',
#  'J0509+0856_rednoise_log10_A',
#  'cw_cosinc',
#  'cw_cosinc_2',
#  'cw_log10_f0',
#  'cw_log10_f0_2',
#  'cw_log10_h0',
#  'cw_log10_h0_2',
#  'cw_phi_earth',
#  'cw_phi_earth_2',
#  'cw_psi',
#  'cw_psi_2',
#  'cw_ra',
#  'cw_ra_2',
#  'cw_sindec',
#  'cw_sindec_2',
#  'gw_gamma',
#  'gw_log10_A']

# %%
# Setting the lnL 

logl = fml2.logL

# %%
temp_dict = enterprise_params.copy()

# %%
for key in enterprise_params.keys():
    if 'cw2' in key:
        newkey = key.replace('cw2', 'cw')
        newkey = newkey+"_2"
        temp_dict[newkey] = enterprise_params[key]
        del temp_dict[key]

# %%
temp_dict
# Out:
# {'B1855+09_rednoise_log10_A': -17.844093269852827,
#  'B1937+21_rednoise_log10_A': -17.707097691150125,
#  'B1953+29_rednoise_log10_A': -17.029873709721603,
#  'J0023+0923_rednoise_log10_A': -15.301133409164677,
#  'J0030+0451_rednoise_log10_A': -17.11255166022465,
#  'J0125-2327_rednoise_log10_A': -15.09905106744675,
#  'J0340+4130_rednoise_log10_A': -16.447399446077107,
#  'J0406+3039_rednoise_log10_A': -16.889406544992713,
#  'J0437-4715_rednoise_log10_A': -16.019534448663993,
#  'J0509+0856_rednoise_log10_A': -16.725493044610776,
#  'J0557+1551_rednoise_log10_A': -17.173441192506115,
#  'J0605+3757_rednoise_log10_A': -15.359002407247074,
#  'J0610-2100_rednoise_log10_A': -15.560569962049723,
#  'J0613-0200_rednoise_log10_A': -15.832675902558282,
#  'J0614-3329_rednoise_log10_A': -16.98867113925095,
#  'J0636+5128_rednoise_log10_A': -17.98581097787469,
#  'J0636-3044_rednoise_log10_A': -15.583268875635234,
#  'J0645+5158_rednoise_log10_A': -15.291299579337483,
#  'J0709+0458_rednoise_log10_A': -16.254372202381067,
#  'J0711-6830_rednoise_log10_A': -15.907204409525255,
#  'J0740+6620_rednoise_log10_A': -15.013238540777227,
#  'J0751+1807_rednoise_log10_A': -16.567626954340447,
#  'J0900-3144_rednoise_log10_A': -15.867160193980881,
#  'J0931-1902_rednoise_log10_A': -15.271676294245388,
#  'J0955-6150_rednoise_log10_A': -16.368812045565914,
#  'J1012+5307_rednoise_log10_A': -16.29463086631633,
#  'J1012-4235_rednoise_log10_A': -17.016034034538613,
#  'J1017-7156_rednoise_log10_A': -16.245642371572924,
#  'J1022+1001_rednoise_log10_A': -17.043252315422468,
#  'J1024-0719_rednoise_log10_A': -17.07717160168745,
#  'J1036-8317_rednoise_log10_A': -17.754667953086873,
#  'J1045-4509_rednoise_log10_A': -16.687661768825535,
#  'J1101-6424_rednoise_log10_A': -15.563629463590392,
#  'J1103-5403_rednoise_log10_A': -17.3262039448355,
#  'J1125+7819_rednoise_log10_A': -17.187963416350364,
#  'J1125-5825_rednoise_log10_A': -15.083074907766807,
#  'J1125-6014_rednoise_log10_A': -17.064971582577005,
#  'J1216-6410_rednoise_log10_A': -16.801153340570856,
#  'J1312+0051_rednoise_log10_A': -16.740037359371605,
#  'J1327-0755_rednoise_log10_A': -16.255253340687627,
#  'J1421-4409_rednoise_log10_A': -16.706152225640462,
#  'J1431-5740_rednoise_log10_A': -15.221822345182943,
#  'J1435-6100_rednoise_log10_A': -16.54990576983257,
#  'J1446-4701_rednoise_log10_A': -15.688192229007825,
#  'J1453+1902_rednoise_log10_A': -16.953966701243793,
#  'J1455-3330_rednoise_log10_A': -15.06094659038365,
#  'J1525-5545_rednoise_log10_A': -17.73446197622637,
#  'J1543-5149_rednoise_log10_A': -17.128180973528544,
#  'J1545-4550_rednoise_log10_A': -15.912126076116314,
#  'J1547-5709_rednoise_log10_A': -16.403427971223074,
#  'J1600-3053_rednoise_log10_A': -17.21171076799904,
#  'J1603-7202_rednoise_log10_A': -15.097911851919648,
#  'J1614-2230_rednoise_log10_A': -15.591355758989579,
#  'J1629-6902_rednoise_log10_A': -15.510588930290853,
#  'J1630+3734_rednoise_log10_A': -16.66946377511065,
#  'J1640+2224_rednoise_log10_A': -17.350199762643374,
#  'J1643-1224_rednoise_log10_A': -16.75744039198758,
#  'J1652-4838_rednoise_log10_A': -16.002252684724812,
#  'J1653-2054_rednoise_log10_A': -16.0870540243194,
#  'J1658-5324_rednoise_log10_A': -16.470216158813926,
#  'J1705-1903_rednoise_log10_A': -15.127370590296117,
#  'J1708-3506_rednoise_log10_A': -17.938430797263496,
#  'J1713+0747_rednoise_log10_A': -15.40451664919555,
#  'J1719-1438_rednoise_log10_A': -17.413799051126475,
#  'J1721-2457_rednoise_log10_A': -15.761591510046081,
#  'J1730-2304_rednoise_log10_A': -15.802936272166715,
#  'J1732-5049_rednoise_log10_A': -17.55571634098891,
#  'J1737-0811_rednoise_log10_A': -15.252085183869653,
#  'J1738+0333_rednoise_log10_A': -16.626587164548226,
#  'J1741+1351_rednoise_log10_A': -16.440609619390006,
#  'J1744-1134_rednoise_log10_A': -15.692776618738067,
#  'J1745+1017_rednoise_log10_A': -16.29218360910983,
#  'J1747-4036_rednoise_log10_A': -15.901315816706468,
#  'J1751-2857_rednoise_log10_A': -16.588507778157393,
#  'J1756-2251_rednoise_log10_A': -16.708998239938115,
#  'J1757-5322_rednoise_log10_A': -15.781702146504625,
#  'J1801-1417_rednoise_log10_A': -15.086687080090755,
#  'J1802-2124_rednoise_log10_A': -17.91118929394941,
#  'J1804-2717_rednoise_log10_A': -16.971397476926466,
#  'J1811-2405_rednoise_log10_A': -15.29022871592232,
#  'J1824-2452A_rednoise_log10_A': -17.344614600935028,
#  'J1825-0319_rednoise_log10_A': -17.688770262132973,
#  'J1832-0836_rednoise_log10_A': -16.612660651698825,
#  'J1843-1113_rednoise_log10_A': -15.328831916439324,
#  'J1853+1303_rednoise_log10_A': -16.60604164378085,
#  'J1902-5105_rednoise_log10_A': -16.56333684837709,
#  'J1903+0327_rednoise_log10_A': -17.901991390541774,
#  'J1903-7051_rednoise_log10_A': -17.285869475497865,
#  'J1909-3744_rednoise_log10_A': -15.574744701684065,
#  'J1910+1256_rednoise_log10_A': -17.745910407668262,
#  'J1911+1347_rednoise_log10_A': -17.22373754401808,
#  'J1918-0642_rednoise_log10_A': -15.941325448023013,
#  'J1923+2515_rednoise_log10_A': -17.14510799305737,
#  'J1933-6211_rednoise_log10_A': -17.73865366146039,
#  'J1944+0907_rednoise_log10_A': -16.381031041277495,
#  'J1946+3417_rednoise_log10_A': -17.986800114295693,
#  'J1946-5403_rednoise_log10_A': -16.843418164291823,
#  'J2010-1323_rednoise_log10_A': -17.42830257063724,
#  'J2017+0603_rednoise_log10_A': -17.176025630102473,
#  'J2033+1734_rednoise_log10_A': -15.040883381624504,
#  'J2039-3616_rednoise_log10_A': -15.771964474062976,
#  'J2043+1711_rednoise_log10_A': -16.940941484825185,
#  'J2124-3358_rednoise_log10_A': -15.47347112150645,
#  'J2129-5721_rednoise_log10_A': -17.133715305853524,
#  'J2145-0750_rednoise_log10_A': -17.328284776874565,
#  'J2150-0326_rednoise_log10_A': -16.393849778068446,
#  'J2214+3000_rednoise_log10_A': -15.691507792933532,
#  'J2222-0137_rednoise_log10_A': -16.511719310284587,
#  'J2229+2643_rednoise_log10_A': -15.992547291397873,
#  'J2234+0611_rednoise_log10_A': -17.24803309795335,
#  'J2234+0944_rednoise_log10_A': -17.058324175944243,
#  'J2241-5236_rednoise_log10_A': -16.63645769751631,
#  'J2302+4442_rednoise_log10_A': -16.792338089918537,
#  'J2317+1439_rednoise_log10_A': -16.513654052832724,
#  'J2322+2057_rednoise_log10_A': -15.398454498463611,
#  'J2322-2650_rednoise_log10_A': -16.06095014495067,
#  'B1855+09_rednoise_gamma': 3.2721791365813067,
#  'B1937+21_rednoise_gamma': 3.906091780410814,
#  'B1953+29_rednoise_gamma': 3.072782132281432,
#  'J0023+0923_rednoise_gamma': 3.1506727618297723,
#  'J0030+0451_rednoise_gamma': 3.19506467186759,
#  'J0125-2327_rednoise_gamma': 3.928404864450094,
#  'J0340+4130_rednoise_gamma': 3.2062685073177484,
#  'J0406+3039_rednoise_gamma': 3.6308205122812143,
#  'J0437-4715_rednoise_gamma': 3.9526861926696437,
#  'J0509+0856_rednoise_gamma': 3.936676234895252,
#  'J0557+1551_rednoise_gamma': 3.6291305060066907,
#  'J0605+3757_rednoise_gamma': 3.1065990415679225,
#  'J0610-2100_rednoise_gamma': 3.612869802487439,
#  'J0613-0200_rednoise_gamma': 3.8411357395587182,
#  'J0614-3329_rednoise_gamma': 3.5199097594191016,
#  'J0636+5128_rednoise_gamma': 3.7712942294141665,
#  'J0636-3044_rednoise_gamma': 3.363166992804136,
#  'J0645+5158_rednoise_gamma': 3.2184188000556953,
#  'J0709+0458_rednoise_gamma': 3.256635924087954,
#  'J0711-6830_rednoise_gamma': 3.6630726333467813,
#  'J0740+6620_rednoise_gamma': 3.5495600339332603,
#  'J0751+1807_rednoise_gamma': 3.8967398421151676,
#  'J0900-3144_rednoise_gamma': 3.743002905236364,
#  'J0931-1902_rednoise_gamma': 3.621600839380692,
#  'J0955-6150_rednoise_gamma': 3.944109732540811,
#  'J1012+5307_rednoise_gamma': 3.368557752502384,
#  'J1012-4235_rednoise_gamma': 3.7919872682359945,
#  'J1017-7156_rednoise_gamma': 3.195193871788209,
#  'J1022+1001_rednoise_gamma': 3.420421495440979,
#  'J1024-0719_rednoise_gamma': 3.504436371872547,
#  'J1036-8317_rednoise_gamma': 3.636937825586846,
#  'J1045-4509_rednoise_gamma': 3.8774309727058993,
#  'J1101-6424_rednoise_gamma': 3.303821937056708,
#  'J1103-5403_rednoise_gamma': 3.912499469729812,
#  'J1125+7819_rednoise_gamma': 3.8060263555618374,
#  'J1125-5825_rednoise_gamma': 3.055974802254563,
#  'J1125-6014_rednoise_gamma': 3.9293630760397655,
#  'J1216-6410_rednoise_gamma': 3.761666500132501,
#  'J1312+0051_rednoise_gamma': 3.9632007249819816,
#  'J1327-0755_rednoise_gamma': 3.170039810691237,
#  'J1421-4409_rednoise_gamma': 3.6108637460008994,
#  'J1431-5740_rednoise_gamma': 3.8479279979865666,
#  'J1435-6100_rednoise_gamma': 3.391059853607382,
#  'J1446-4701_rednoise_gamma': 3.7833181889216503,
#  'J1453+1902_rednoise_gamma': 3.5590502776292396,
#  'J1455-3330_rednoise_gamma': 3.813189240514056,
#  'J1525-5545_rednoise_gamma': 3.39092372318136,
#  'J1543-5149_rednoise_gamma': 3.4411288807356892,
#  'J1545-4550_rednoise_gamma': 3.768026152479565,
#  'J1547-5709_rednoise_gamma': 3.4012752353071094,
#  'J1600-3053_rednoise_gamma': 3.5080271930376012,
#  'J1603-7202_rednoise_gamma': 3.501211563897204,
#  'J1614-2230_rednoise_gamma': 3.4037605041189725,
#  'J1629-6902_rednoise_gamma': 3.4647523841332584,
#  'J1630+3734_rednoise_gamma': 3.1975126794975446,
#  'J1640+2224_rednoise_gamma': 3.5326479033529052,
#  'J1643-1224_rednoise_gamma': 3.342609188396467,
#  'J1652-4838_rednoise_gamma': 3.374005418328984,
#  'J1653-2054_rednoise_gamma': 3.0630950236552756,
#  'J1658-5324_rednoise_gamma': 3.04862884028009,
#  'J1705-1903_rednoise_gamma': 3.9016634386421423,
#  'J1708-3506_rednoise_gamma': 3.014901553282345,
#  'J1713+0747_rednoise_gamma': 3.942214672513111,
#  'J1719-1438_rednoise_gamma': 3.6755552819591344,
#  'J1721-2457_rednoise_gamma': 3.5375326356814156,
#  'J1730-2304_rednoise_gamma': 3.1508862726375995,
#  'J1732-5049_rednoise_gamma': 3.977040922265605,
#  'J1737-0811_rednoise_gamma': 3.35718331051232,
#  'J1738+0333_rednoise_gamma': 3.313092037144819,
#  'J1741+1351_rednoise_gamma': 3.6809563248619193,
#  'J1744-1134_rednoise_gamma': 3.751814459020797,
#  'J1745+1017_rednoise_gamma': 3.1910426019064104,
#  'J1747-4036_rednoise_gamma': 3.7786422917977935,
#  'J1751-2857_rednoise_gamma': 3.3075856826318533,
#  'J1756-2251_rednoise_gamma': 3.68552200163587,
#  'J1757-5322_rednoise_gamma': 3.1600036967662746,
#  'J1801-1417_rednoise_gamma': 3.4694172713010736,
#  'J1802-2124_rednoise_gamma': 3.756367379168017,
#  'J1804-2717_rednoise_gamma': 3.220271714260197,
#  'J1811-2405_rednoise_gamma': 3.70365099599883,
#  'J1824-2452A_rednoise_gamma': 3.4140241026275557,
#  'J1825-0319_rednoise_gamma': 3.0127530909911444,
#  'J1832-0836_rednoise_gamma': 3.5312378486120304,
#  'J1843-1113_rednoise_gamma': 3.816831018522119,
#  'J1853+1303_rednoise_gamma': 3.072057652858233,
#  'J1902-5105_rednoise_gamma': 3.5322778637870846,
#  'J1903+0327_rednoise_gamma': 3.2235364525786285,
#  'J1903-7051_rednoise_gamma': 3.773847855314162,
#  'J1909-3744_rednoise_gamma': 3.427277895215057,
#  'J1910+1256_rednoise_gamma': 3.613575548754338,
#  'J1911+1347_rednoise_gamma': 3.2151117961785562,
#  'J1918-0642_rednoise_gamma': 3.005967762173021,
#  'J1923+2515_rednoise_gamma': 3.9483392106397597,
#  'J1933-6211_rednoise_gamma': 3.1378637680715142,
#  'J1944+0907_rednoise_gamma': 3.824299814325582,
#  'J1946+3417_rednoise_gamma': 3.983016895441919,
#  'J1946-5403_rednoise_gamma': 3.9379112157001837,
#  'J2010-1323_rednoise_gamma': 3.8799366742761254,
#  'J2017+0603_rednoise_gamma': 3.732369884087037,
#  'J2033+1734_rednoise_gamma': 3.9466857423786514,
#  'J2039-3616_rednoise_gamma': 3.418949054958035,
#  'J2043+1711_rednoise_gamma': 3.450450044544467,
#  'J2124-3358_rednoise_gamma': 3.341434087841347,
#  'J2129-5721_rednoise_gamma': 3.195422380096664,
#  'J2145-0750_rednoise_gamma': 3.8940637375572082,
#  'J2150-0326_rednoise_gamma': 3.1998452690678136,
#  'J2214+3000_rednoise_gamma': 3.905044143143213,
#  'J2222-0137_rednoise_gamma': 3.7605521547497935,
#  'J2229+2643_rednoise_gamma': 3.928169936298047,
#  'J2234+0611_rednoise_gamma': 3.628463448531674,
#  'J2234+0944_rednoise_gamma': 3.2726411975651213,
#  'J2241-5236_rednoise_gamma': 3.2404819422484716,
#  'J2302+4442_rednoise_gamma': 3.44172625406144,
#  'J2317+1439_rednoise_gamma': 3.290973086132614,
#  'J2322+2057_rednoise_gamma': 3.5024908990615025,
#  'J2322-2650_rednoise_gamma': 3.608788146103545,
#  'B1855+09_cw_p_dist': 1.18,
#  'B1937+21_cw_p_dist': 3.1,
#  'B1953+29_cw_p_dist': 4.64,
#  'J0023+0923_cw_p_dist': 1.02,
#  'J0030+0451_cw_p_dist': 0.3296,
#  'J0125-2327_cw_p_dist': 0.873,
#  'J0340+4130_cw_p_dist': 1.71,
#  'J0406+3039_cw_p_dist': 1.72,
#  'J0437-4715_cw_p_dist': 0.1549,
#  'J0509+0856_cw_p_dist': 1.45,
#  'J0557+1551_cw_p_dist': 2.87,
#  'J0605+3757_cw_p_dist': 0.7,
#  'J0610-2100_cw_p_dist': 1.38,
#  'J0613-0200_cw_p_dist': 1.07,
#  'J0614-3329_cw_p_dist': 0.63,
#  'J0636+5128_cw_p_dist': 1.27,
#  'J0636-3044_cw_p_dist': 0.679,
#  'J0645+5158_cw_p_dist': 1.37,
#  'J0709+0458_cw_p_dist': 1.8,
#  'J0711-6830_cw_p_dist': 0.106,
#  'J0740+6620_cw_p_dist': 0.94,
#  'J0751+1807_cw_p_dist': 1.17,
#  'J0900-3144_cw_p_dist': 0.89,
#  'J0931-1902_cw_p_dist': 1.88,
#  'J0955-6150_cw_p_dist': 2.172,
#  'J1012+5307_cw_p_dist': 0.862,
#  'J1012-4235_cw_p_dist': 2.5,
#  'J1017-7156_cw_p_dist': 1.807,
#  'J1022+1001_cw_p_dist': 0.706,
#  'J1024-0719_cw_p_dist': 1.08,
#  'J1036-8317_cw_p_dist': 0.934,
#  'J1045-4509_cw_p_dist': 0.34,
#  'J1101-6424_cw_p_dist': 2.175,
#  'J1103-5403_cw_p_dist': 1.683,
#  'J1125+7819_cw_p_dist': 0.63,
#  'J1125-5825_cw_p_dist': 1.744,
#  'J1125-6014_cw_p_dist': 0.988,
#  'J1216-6410_cw_p_dist': 1.098,
#  'J1312+0051_cw_p_dist': 0.84,
#  'J1327-0755_cw_p_dist': 25.0,
#  'J1421-4409_cw_p_dist': 2.085,
#  'J1431-5740_cw_p_dist': 3.553,
#  'J1435-6100_cw_p_dist': 2.816,
#  'J1446-4701_cw_p_dist': 1.569,
#  'J1453+1902_cw_p_dist': 1.15,
#  'J1455-3330_cw_p_dist': 1.01,
#  'J1525-5545_cw_p_dist': 3.14,
#  'J1543-5149_cw_p_dist': 1.149,
#  'J1545-4550_cw_p_dist': 2.222,
#  'J1547-5709_cw_p_dist': 2.695,
#  'J1600-3053_cw_p_dist': 1.84,
#  'J1603-7202_cw_p_dist': 3.7,
#  'J1614-2230_cw_p_dist': 0.699,
#  'J1629-6902_cw_p_dist': 0.963,
#  'J1630+3734_cw_p_dist': 0.089,
#  'J1640+2224_cw_p_dist': 1.404,
#  'J1643-1224_cw_p_dist': 0.835,
#  'J1652-4838_cw_p_dist': 4.395,
#  'J1653-2054_cw_p_dist': 2.631,
#  'J1658-5324_cw_p_dist': 0.88,
#  'J1705-1903_cw_p_dist': 1.62,
#  'J1708-3506_cw_p_dist': 3.32,
#  'J1713+0747_cw_p_dist': 1.138,
#  'J1719-1438_cw_p_dist': 1.21,
#  'J1721-2457_cw_p_dist': 1.393,
#  'J1730-2304_cw_p_dist': 0.529,
#  'J1732-5049_cw_p_dist': 1.873,
#  'J1737-0811_cw_p_dist': 0.206,
#  'J1738+0333_cw_p_dist': 1.64,
#  'J1741+1351_cw_p_dist': 2.36,
#  'J1744-1134_cw_p_dist': 0.4141,
#  'J1745+1017_cw_p_dist': 1.27,
#  'J1747-4036_cw_p_dist': 3.5,
#  'J1751-2857_cw_p_dist': 1.11,
#  'J1756-2251_cw_p_dist': 0.73,
#  'J1757-5322_cw_p_dist': 0.945,
#  'J1801-1417_cw_p_dist': 1.0,
#  'J1802-2124_cw_p_dist': 2.96,
#  'J1804-2717_cw_p_dist': 0.8,
#  'J1811-2405_cw_p_dist': 1.79,
#  'J1824-2452A_cw_p_dist': 5.37,
#  'J1825-0319_cw_p_dist': 3.862,
#  'J1832-0836_cw_p_dist': 2.0,
#  'J1843-1113_cw_p_dist': 1.72,
#  'J1853+1303_cw_p_dist': 1.91,
#  'J1902-5105_cw_p_dist': 1.645,
#  'J1903+0327_cw_p_dist': 6.49,
#  'J1903-7051_cw_p_dist': 0.93,
#  'J1909-3744_cw_p_dist': 1.159,
#  'J1910+1256_cw_p_dist': 3.52,
#  'J1911+1347_cw_p_dist': 2.08,
#  'J1918-0642_cw_p_dist': 1.44,
#  'J1923+2515_cw_p_dist': 0.94,
#  'J1933-6211_cw_p_dist': 0.65,
#  'J1944+0907_cw_p_dist': 1.38,
#  'J1946+3417_cw_p_dist': 5.12,
#  'J1946-5403_cw_p_dist': 1.15,
#  'J2010-1323_cw_p_dist': 1.94,
#  'J2017+0603_cw_p_dist': 1.57,
#  'J2033+1734_cw_p_dist': 1.99,
#  'J2039-3616_cw_p_dist': 1.704,
#  'J2043+1711_cw_p_dist': 1.58,
#  'J2124-3358_cw_p_dist': 0.413,
#  'J2129-5721_cw_p_dist': 3.2,
#  'J2145-0750_cw_p_dist': 0.624,
#  'J2150-0326_cw_p_dist': 1.972,
#  'J2214+3000_cw_p_dist': 1.54,
#  'J2222-0137_cw_p_dist': 0.268,
#  'J2229+2643_cw_p_dist': 1.43,
#  'J2234+0611_cw_p_dist': 1.23,
#  'J2234+0944_cw_p_dist': 1.0,
#  'J2241-5236_cw_p_dist': 1.042,
#  'J2302+4442_cw_p_dist': 1.18,
#  'J2317+1439_cw_p_dist': 1.57,
#  'J2322+2057_cw_p_dist': 1.0,
#  'J2322-2650_cw_p_dist': 0.227,
#  'gw_gamma': 4.333,
#  'gw_log10_A': -14.5,
#  'cw_cosinc': 0,
#  'cw_log10_f0': -8,
#  'cw_log10_h0': -13,
#  'cw_phi_earth': 3.141592653589793,
#  'cw_psi': 0.7853981633974483,
#  'cw_ra': 0.458,
#  'cw_sindec': 0.43,
#  'cw_cosinc_2': 0,
#  'cw_log10_f0_2': -7.5,
#  'cw_log10_h0_2': -13,
#  'cw_phi_earth_2': 3.141592653589793,
#  'cw_psi_2': 0.7853981633974483,
#  'cw_ra_2': 0.158,
#  'cw_sindec_2': 0.13}

# %%
#Need to sort dict so it remains in the same order as the logl.params (paranoia is healthy)
order_map = {key: i for i, key in enumerate(logl.params)}

sorted_items = sorted(temp_dict.items(), key=lambda item: order_map.get(item[0], float('inf')))
sorted_dict = dict(sorted_items)

# %%
sorted_dict
# Out:
# {'B1855+09_cw_p_dist': 1.18,
#  'B1855+09_rednoise_gamma': 3.2721791365813067,
#  'B1855+09_rednoise_log10_A': -17.844093269852827,
#  'B1937+21_cw_p_dist': 3.1,
#  'B1937+21_rednoise_gamma': 3.906091780410814,
#  'B1937+21_rednoise_log10_A': -17.707097691150125,
#  'B1953+29_cw_p_dist': 4.64,
#  'B1953+29_rednoise_gamma': 3.072782132281432,
#  'B1953+29_rednoise_log10_A': -17.029873709721603,
#  'J0023+0923_cw_p_dist': 1.02,
#  'J0023+0923_rednoise_gamma': 3.1506727618297723,
#  'J0023+0923_rednoise_log10_A': -15.301133409164677,
#  'J0030+0451_cw_p_dist': 0.3296,
#  'J0030+0451_rednoise_gamma': 3.19506467186759,
#  'J0030+0451_rednoise_log10_A': -17.11255166022465,
#  'J0125-2327_cw_p_dist': 0.873,
#  'J0125-2327_rednoise_gamma': 3.928404864450094,
#  'J0125-2327_rednoise_log10_A': -15.09905106744675,
#  'J0340+4130_cw_p_dist': 1.71,
#  'J0340+4130_rednoise_gamma': 3.2062685073177484,
#  'J0340+4130_rednoise_log10_A': -16.447399446077107,
#  'J0406+3039_cw_p_dist': 1.72,
#  'J0406+3039_rednoise_gamma': 3.6308205122812143,
#  'J0406+3039_rednoise_log10_A': -16.889406544992713,
#  'J0437-4715_cw_p_dist': 0.1549,
#  'J0437-4715_rednoise_gamma': 3.9526861926696437,
#  'J0437-4715_rednoise_log10_A': -16.019534448663993,
#  'J0509+0856_cw_p_dist': 1.45,
#  'J0509+0856_rednoise_gamma': 3.936676234895252,
#  'J0509+0856_rednoise_log10_A': -16.725493044610776,
#  'cw_cosinc': 0,
#  'cw_cosinc_2': 0,
#  'cw_log10_f0': -8,
#  'cw_log10_f0_2': -7.5,
#  'cw_log10_h0': -13,
#  'cw_log10_h0_2': -13,
#  'cw_phi_earth': 3.141592653589793,
#  'cw_phi_earth_2': 3.141592653589793,
#  'cw_psi': 0.7853981633974483,
#  'cw_psi_2': 0.7853981633974483,
#  'cw_ra': 0.458,
#  'cw_ra_2': 0.158,
#  'cw_sindec': 0.43,
#  'cw_sindec_2': 0.13,
#  'gw_gamma': 4.333,
#  'gw_log10_A': -14.5,
#  'J0557+1551_rednoise_log10_A': -17.173441192506115,
#  'J0605+3757_rednoise_log10_A': -15.359002407247074,
#  'J0610-2100_rednoise_log10_A': -15.560569962049723,
#  'J0613-0200_rednoise_log10_A': -15.832675902558282,
#  'J0614-3329_rednoise_log10_A': -16.98867113925095,
#  'J0636+5128_rednoise_log10_A': -17.98581097787469,
#  'J0636-3044_rednoise_log10_A': -15.583268875635234,
#  'J0645+5158_rednoise_log10_A': -15.291299579337483,
#  'J0709+0458_rednoise_log10_A': -16.254372202381067,
#  'J0711-6830_rednoise_log10_A': -15.907204409525255,
#  'J0740+6620_rednoise_log10_A': -15.013238540777227,
#  'J0751+1807_rednoise_log10_A': -16.567626954340447,
#  'J0900-3144_rednoise_log10_A': -15.867160193980881,
#  'J0931-1902_rednoise_log10_A': -15.271676294245388,
#  'J0955-6150_rednoise_log10_A': -16.368812045565914,
#  'J1012+5307_rednoise_log10_A': -16.29463086631633,
#  'J1012-4235_rednoise_log10_A': -17.016034034538613,
#  'J1017-7156_rednoise_log10_A': -16.245642371572924,
#  'J1022+1001_rednoise_log10_A': -17.043252315422468,
#  'J1024-0719_rednoise_log10_A': -17.07717160168745,
#  'J1036-8317_rednoise_log10_A': -17.754667953086873,
#  'J1045-4509_rednoise_log10_A': -16.687661768825535,
#  'J1101-6424_rednoise_log10_A': -15.563629463590392,
#  'J1103-5403_rednoise_log10_A': -17.3262039448355,
#  'J1125+7819_rednoise_log10_A': -17.187963416350364,
#  'J1125-5825_rednoise_log10_A': -15.083074907766807,
#  'J1125-6014_rednoise_log10_A': -17.064971582577005,
#  'J1216-6410_rednoise_log10_A': -16.801153340570856,
#  'J1312+0051_rednoise_log10_A': -16.740037359371605,
#  'J1327-0755_rednoise_log10_A': -16.255253340687627,
#  'J1421-4409_rednoise_log10_A': -16.706152225640462,
#  'J1431-5740_rednoise_log10_A': -15.221822345182943,
#  'J1435-6100_rednoise_log10_A': -16.54990576983257,
#  'J1446-4701_rednoise_log10_A': -15.688192229007825,
#  'J1453+1902_rednoise_log10_A': -16.953966701243793,
#  'J1455-3330_rednoise_log10_A': -15.06094659038365,
#  'J1525-5545_rednoise_log10_A': -17.73446197622637,
#  'J1543-5149_rednoise_log10_A': -17.128180973528544,
#  'J1545-4550_rednoise_log10_A': -15.912126076116314,
#  'J1547-5709_rednoise_log10_A': -16.403427971223074,
#  'J1600-3053_rednoise_log10_A': -17.21171076799904,
#  'J1603-7202_rednoise_log10_A': -15.097911851919648,
#  'J1614-2230_rednoise_log10_A': -15.591355758989579,
#  'J1629-6902_rednoise_log10_A': -15.510588930290853,
#  'J1630+3734_rednoise_log10_A': -16.66946377511065,
#  'J1640+2224_rednoise_log10_A': -17.350199762643374,
#  'J1643-1224_rednoise_log10_A': -16.75744039198758,
#  'J1652-4838_rednoise_log10_A': -16.002252684724812,
#  'J1653-2054_rednoise_log10_A': -16.0870540243194,
#  'J1658-5324_rednoise_log10_A': -16.470216158813926,
#  'J1705-1903_rednoise_log10_A': -15.127370590296117,
#  'J1708-3506_rednoise_log10_A': -17.938430797263496,
#  'J1713+0747_rednoise_log10_A': -15.40451664919555,
#  'J1719-1438_rednoise_log10_A': -17.413799051126475,
#  'J1721-2457_rednoise_log10_A': -15.761591510046081,
#  'J1730-2304_rednoise_log10_A': -15.802936272166715,
#  'J1732-5049_rednoise_log10_A': -17.55571634098891,
#  'J1737-0811_rednoise_log10_A': -15.252085183869653,
#  'J1738+0333_rednoise_log10_A': -16.626587164548226,
#  'J1741+1351_rednoise_log10_A': -16.440609619390006,
#  'J1744-1134_rednoise_log10_A': -15.692776618738067,
#  'J1745+1017_rednoise_log10_A': -16.29218360910983,
#  'J1747-4036_rednoise_log10_A': -15.901315816706468,
#  'J1751-2857_rednoise_log10_A': -16.588507778157393,
#  'J1756-2251_rednoise_log10_A': -16.708998239938115,
#  'J1757-5322_rednoise_log10_A': -15.781702146504625,
#  'J1801-1417_rednoise_log10_A': -15.086687080090755,
#  'J1802-2124_rednoise_log10_A': -17.91118929394941,
#  'J1804-2717_rednoise_log10_A': -16.971397476926466,
#  'J1811-2405_rednoise_log10_A': -15.29022871592232,
#  'J1824-2452A_rednoise_log10_A': -17.344614600935028,
#  'J1825-0319_rednoise_log10_A': -17.688770262132973,
#  'J1832-0836_rednoise_log10_A': -16.612660651698825,
#  'J1843-1113_rednoise_log10_A': -15.328831916439324,
#  'J1853+1303_rednoise_log10_A': -16.60604164378085,
#  'J1902-5105_rednoise_log10_A': -16.56333684837709,
#  'J1903+0327_rednoise_log10_A': -17.901991390541774,
#  'J1903-7051_rednoise_log10_A': -17.285869475497865,
#  'J1909-3744_rednoise_log10_A': -15.574744701684065,
#  'J1910+1256_rednoise_log10_A': -17.745910407668262,
#  'J1911+1347_rednoise_log10_A': -17.22373754401808,
#  'J1918-0642_rednoise_log10_A': -15.941325448023013,
#  'J1923+2515_rednoise_log10_A': -17.14510799305737,
#  'J1933-6211_rednoise_log10_A': -17.73865366146039,
#  'J1944+0907_rednoise_log10_A': -16.381031041277495,
#  'J1946+3417_rednoise_log10_A': -17.986800114295693,
#  'J1946-5403_rednoise_log10_A': -16.843418164291823,
#  'J2010-1323_rednoise_log10_A': -17.42830257063724,
#  'J2017+0603_rednoise_log10_A': -17.176025630102473,
#  'J2033+1734_rednoise_log10_A': -15.040883381624504,
#  'J2039-3616_rednoise_log10_A': -15.771964474062976,
#  'J2043+1711_rednoise_log10_A': -16.940941484825185,
#  'J2124-3358_rednoise_log10_A': -15.47347112150645,
#  'J2129-5721_rednoise_log10_A': -17.133715305853524,
#  'J2145-0750_rednoise_log10_A': -17.328284776874565,
#  'J2150-0326_rednoise_log10_A': -16.393849778068446,
#  'J2214+3000_rednoise_log10_A': -15.691507792933532,
#  'J2222-0137_rednoise_log10_A': -16.511719310284587,
#  'J2229+2643_rednoise_log10_A': -15.992547291397873,
#  'J2234+0611_rednoise_log10_A': -17.24803309795335,
#  'J2234+0944_rednoise_log10_A': -17.058324175944243,
#  'J2241-5236_rednoise_log10_A': -16.63645769751631,
#  'J2302+4442_rednoise_log10_A': -16.792338089918537,
#  'J2317+1439_rednoise_log10_A': -16.513654052832724,
#  'J2322+2057_rednoise_log10_A': -15.398454498463611,
#  'J2322-2650_rednoise_log10_A': -16.06095014495067,
#  'J0557+1551_rednoise_gamma': 3.6291305060066907,
#  'J0605+3757_rednoise_gamma': 3.1065990415679225,
#  'J0610-2100_rednoise_gamma': 3.612869802487439,
#  'J0613-0200_rednoise_gamma': 3.8411357395587182,
#  'J0614-3329_rednoise_gamma': 3.5199097594191016,
#  'J0636+5128_rednoise_gamma': 3.7712942294141665,
#  'J0636-3044_rednoise_gamma': 3.363166992804136,
#  'J0645+5158_rednoise_gamma': 3.2184188000556953,
#  'J0709+0458_rednoise_gamma': 3.256635924087954,
#  'J0711-6830_rednoise_gamma': 3.6630726333467813,
#  'J0740+6620_rednoise_gamma': 3.5495600339332603,
#  'J0751+1807_rednoise_gamma': 3.8967398421151676,
#  'J0900-3144_rednoise_gamma': 3.743002905236364,
#  'J0931-1902_rednoise_gamma': 3.621600839380692,
#  'J0955-6150_rednoise_gamma': 3.944109732540811,
#  'J1012+5307_rednoise_gamma': 3.368557752502384,
#  'J1012-4235_rednoise_gamma': 3.7919872682359945,
#  'J1017-7156_rednoise_gamma': 3.195193871788209,
#  'J1022+1001_rednoise_gamma': 3.420421495440979,
#  'J1024-0719_rednoise_gamma': 3.504436371872547,
#  'J1036-8317_rednoise_gamma': 3.636937825586846,
#  'J1045-4509_rednoise_gamma': 3.8774309727058993,
#  'J1101-6424_rednoise_gamma': 3.303821937056708,
#  'J1103-5403_rednoise_gamma': 3.912499469729812,
#  'J1125+7819_rednoise_gamma': 3.8060263555618374,
#  'J1125-5825_rednoise_gamma': 3.055974802254563,
#  'J1125-6014_rednoise_gamma': 3.9293630760397655,
#  'J1216-6410_rednoise_gamma': 3.761666500132501,
#  'J1312+0051_rednoise_gamma': 3.9632007249819816,
#  'J1327-0755_rednoise_gamma': 3.170039810691237,
#  'J1421-4409_rednoise_gamma': 3.6108637460008994,
#  'J1431-5740_rednoise_gamma': 3.8479279979865666,
#  'J1435-6100_rednoise_gamma': 3.391059853607382,
#  'J1446-4701_rednoise_gamma': 3.7833181889216503,
#  'J1453+1902_rednoise_gamma': 3.5590502776292396,
#  'J1455-3330_rednoise_gamma': 3.813189240514056,
#  'J1525-5545_rednoise_gamma': 3.39092372318136,
#  'J1543-5149_rednoise_gamma': 3.4411288807356892,
#  'J1545-4550_rednoise_gamma': 3.768026152479565,
#  'J1547-5709_rednoise_gamma': 3.4012752353071094,
#  'J1600-3053_rednoise_gamma': 3.5080271930376012,
#  'J1603-7202_rednoise_gamma': 3.501211563897204,
#  'J1614-2230_rednoise_gamma': 3.4037605041189725,
#  'J1629-6902_rednoise_gamma': 3.4647523841332584,
#  'J1630+3734_rednoise_gamma': 3.1975126794975446,
#  'J1640+2224_rednoise_gamma': 3.5326479033529052,
#  'J1643-1224_rednoise_gamma': 3.342609188396467,
#  'J1652-4838_rednoise_gamma': 3.374005418328984,
#  'J1653-2054_rednoise_gamma': 3.0630950236552756,
#  'J1658-5324_rednoise_gamma': 3.04862884028009,
#  'J1705-1903_rednoise_gamma': 3.9016634386421423,
#  'J1708-3506_rednoise_gamma': 3.014901553282345,
#  'J1713+0747_rednoise_gamma': 3.942214672513111,
#  'J1719-1438_rednoise_gamma': 3.6755552819591344,
#  'J1721-2457_rednoise_gamma': 3.5375326356814156,
#  'J1730-2304_rednoise_gamma': 3.1508862726375995,
#  'J1732-5049_rednoise_gamma': 3.977040922265605,
#  'J1737-0811_rednoise_gamma': 3.35718331051232,
#  'J1738+0333_rednoise_gamma': 3.313092037144819,
#  'J1741+1351_rednoise_gamma': 3.6809563248619193,
#  'J1744-1134_rednoise_gamma': 3.751814459020797,
#  'J1745+1017_rednoise_gamma': 3.1910426019064104,
#  'J1747-4036_rednoise_gamma': 3.7786422917977935,
#  'J1751-2857_rednoise_gamma': 3.3075856826318533,
#  'J1756-2251_rednoise_gamma': 3.68552200163587,
#  'J1757-5322_rednoise_gamma': 3.1600036967662746,
#  'J1801-1417_rednoise_gamma': 3.4694172713010736,
#  'J1802-2124_rednoise_gamma': 3.756367379168017,
#  'J1804-2717_rednoise_gamma': 3.220271714260197,
#  'J1811-2405_rednoise_gamma': 3.70365099599883,
#  'J1824-2452A_rednoise_gamma': 3.4140241026275557,
#  'J1825-0319_rednoise_gamma': 3.0127530909911444,
#  'J1832-0836_rednoise_gamma': 3.5312378486120304,
#  'J1843-1113_rednoise_gamma': 3.816831018522119,
#  'J1853+1303_rednoise_gamma': 3.072057652858233,
#  'J1902-5105_rednoise_gamma': 3.5322778637870846,
#  'J1903+0327_rednoise_gamma': 3.2235364525786285,
#  'J1903-7051_rednoise_gamma': 3.773847855314162,
#  'J1909-3744_rednoise_gamma': 3.427277895215057,
#  'J1910+1256_rednoise_gamma': 3.613575548754338,
#  'J1911+1347_rednoise_gamma': 3.2151117961785562,
#  'J1918-0642_rednoise_gamma': 3.005967762173021,
#  'J1923+2515_rednoise_gamma': 3.9483392106397597,
#  'J1933-6211_rednoise_gamma': 3.1378637680715142,
#  'J1944+0907_rednoise_gamma': 3.824299814325582,
#  'J1946+3417_rednoise_gamma': 3.983016895441919,
#  'J1946-5403_rednoise_gamma': 3.9379112157001837,
#  'J2010-1323_rednoise_gamma': 3.8799366742761254,
#  'J2017+0603_rednoise_gamma': 3.732369884087037,
#  'J2033+1734_rednoise_gamma': 3.9466857423786514,
#  'J2039-3616_rednoise_gamma': 3.418949054958035,
#  'J2043+1711_rednoise_gamma': 3.450450044544467,
#  'J2124-3358_rednoise_gamma': 3.341434087841347,
#  'J2129-5721_rednoise_gamma': 3.195422380096664,
#  'J2145-0750_rednoise_gamma': 3.8940637375572082,
#  'J2150-0326_rednoise_gamma': 3.1998452690678136,
#  'J2214+3000_rednoise_gamma': 3.905044143143213,
#  'J2222-0137_rednoise_gamma': 3.7605521547497935,
#  'J2229+2643_rednoise_gamma': 3.928169936298047,
#  'J2234+0611_rednoise_gamma': 3.628463448531674,
#  'J2234+0944_rednoise_gamma': 3.2726411975651213,
#  'J2241-5236_rednoise_gamma': 3.2404819422484716,
#  'J2302+4442_rednoise_gamma': 3.44172625406144,
#  'J2317+1439_rednoise_gamma': 3.290973086132614,
#  'J2322+2057_rednoise_gamma': 3.5024908990615025,
#  'J2322-2650_rednoise_gamma': 3.608788146103545,
#  'J0557+1551_cw_p_dist': 2.87,
#  'J0605+3757_cw_p_dist': 0.7,
#  'J0610-2100_cw_p_dist': 1.38,
#  'J0613-0200_cw_p_dist': 1.07,
#  'J0614-3329_cw_p_dist': 0.63,
#  'J0636+5128_cw_p_dist': 1.27,
#  'J0636-3044_cw_p_dist': 0.679,
#  'J0645+5158_cw_p_dist': 1.37,
#  'J0709+0458_cw_p_dist': 1.8,
#  'J0711-6830_cw_p_dist': 0.106,
#  'J0740+6620_cw_p_dist': 0.94,
#  'J0751+1807_cw_p_dist': 1.17,
#  'J0900-3144_cw_p_dist': 0.89,
#  'J0931-1902_cw_p_dist': 1.88,
#  'J0955-6150_cw_p_dist': 2.172,
#  'J1012+5307_cw_p_dist': 0.862,
#  'J1012-4235_cw_p_dist': 2.5,
#  'J1017-7156_cw_p_dist': 1.807,
#  'J1022+1001_cw_p_dist': 0.706,
#  'J1024-0719_cw_p_dist': 1.08,
#  'J1036-8317_cw_p_dist': 0.934,
#  'J1045-4509_cw_p_dist': 0.34,
#  'J1101-6424_cw_p_dist': 2.175,
#  'J1103-5403_cw_p_dist': 1.683,
#  'J1125+7819_cw_p_dist': 0.63,
#  'J1125-5825_cw_p_dist': 1.744,
#  'J1125-6014_cw_p_dist': 0.988,
#  'J1216-6410_cw_p_dist': 1.098,
#  'J1312+0051_cw_p_dist': 0.84,
#  'J1327-0755_cw_p_dist': 25.0,
#  'J1421-4409_cw_p_dist': 2.085,
#  'J1431-5740_cw_p_dist': 3.553,
#  'J1435-6100_cw_p_dist': 2.816,
#  'J1446-4701_cw_p_dist': 1.569,
#  'J1453+1902_cw_p_dist': 1.15,
#  'J1455-3330_cw_p_dist': 1.01,
#  'J1525-5545_cw_p_dist': 3.14,
#  'J1543-5149_cw_p_dist': 1.149,
#  'J1545-4550_cw_p_dist': 2.222,
#  'J1547-5709_cw_p_dist': 2.695,
#  'J1600-3053_cw_p_dist': 1.84,
#  'J1603-7202_cw_p_dist': 3.7,
#  'J1614-2230_cw_p_dist': 0.699,
#  'J1629-6902_cw_p_dist': 0.963,
#  'J1630+3734_cw_p_dist': 0.089,
#  'J1640+2224_cw_p_dist': 1.404,
#  'J1643-1224_cw_p_dist': 0.835,
#  'J1652-4838_cw_p_dist': 4.395,
#  'J1653-2054_cw_p_dist': 2.631,
#  'J1658-5324_cw_p_dist': 0.88,
#  'J1705-1903_cw_p_dist': 1.62,
#  'J1708-3506_cw_p_dist': 3.32,
#  'J1713+0747_cw_p_dist': 1.138,
#  'J1719-1438_cw_p_dist': 1.21,
#  'J1721-2457_cw_p_dist': 1.393,
#  'J1730-2304_cw_p_dist': 0.529,
#  'J1732-5049_cw_p_dist': 1.873,
#  'J1737-0811_cw_p_dist': 0.206,
#  'J1738+0333_cw_p_dist': 1.64,
#  'J1741+1351_cw_p_dist': 2.36,
#  'J1744-1134_cw_p_dist': 0.4141,
#  'J1745+1017_cw_p_dist': 1.27,
#  'J1747-4036_cw_p_dist': 3.5,
#  'J1751-2857_cw_p_dist': 1.11,
#  'J1756-2251_cw_p_dist': 0.73,
#  'J1757-5322_cw_p_dist': 0.945,
#  'J1801-1417_cw_p_dist': 1.0,
#  'J1802-2124_cw_p_dist': 2.96,
#  'J1804-2717_cw_p_dist': 0.8,
#  'J1811-2405_cw_p_dist': 1.79,
#  'J1824-2452A_cw_p_dist': 5.37,
#  'J1825-0319_cw_p_dist': 3.862,
#  'J1832-0836_cw_p_dist': 2.0,
#  'J1843-1113_cw_p_dist': 1.72,
#  'J1853+1303_cw_p_dist': 1.91,
#  'J1902-5105_cw_p_dist': 1.645,
#  'J1903+0327_cw_p_dist': 6.49,
#  'J1903-7051_cw_p_dist': 0.93,
#  'J1909-3744_cw_p_dist': 1.159,
#  'J1910+1256_cw_p_dist': 3.52,
#  'J1911+1347_cw_p_dist': 2.08,
#  'J1918-0642_cw_p_dist': 1.44,
#  'J1923+2515_cw_p_dist': 0.94,
#  'J1933-6211_cw_p_dist': 0.65,
#  'J1944+0907_cw_p_dist': 1.38,
#  'J1946+3417_cw_p_dist': 5.12,
#  'J1946-5403_cw_p_dist': 1.15,
#  'J2010-1323_cw_p_dist': 1.94,
#  'J2017+0603_cw_p_dist': 1.57,
#  'J2033+1734_cw_p_dist': 1.99,
#  'J2039-3616_cw_p_dist': 1.704,
#  'J2043+1711_cw_p_dist': 1.58,
#  'J2124-3358_cw_p_dist': 0.413,
#  'J2129-5721_cw_p_dist': 3.2,
#  'J2145-0750_cw_p_dist': 0.624,
#  'J2150-0326_cw_p_dist': 1.972,
#  'J2214+3000_cw_p_dist': 1.54,
#  'J2222-0137_cw_p_dist': 0.268,
#  'J2229+2643_cw_p_dist': 1.43,
#  'J2234+0611_cw_p_dist': 1.23,
#  'J2234+0944_cw_p_dist': 1.0,
#  'J2241-5236_cw_p_dist': 1.042,
#  'J2302+4442_cw_p_dist': 1.18,
#  'J2317+1439_cw_p_dist': 1.57,
#  'J2322+2057_cw_p_dist': 1.0,
#  'J2322-2650_cw_p_dist': 0.227}

# %%
logl.params
# Out:
# ['B1855+09_cw_p_dist',
#  'B1855+09_rednoise_gamma',
#  'B1855+09_rednoise_log10_A',
#  'B1937+21_cw_p_dist',
#  'B1937+21_rednoise_gamma',
#  'B1937+21_rednoise_log10_A',
#  'B1953+29_cw_p_dist',
#  'B1953+29_rednoise_gamma',
#  'B1953+29_rednoise_log10_A',
#  'J0023+0923_cw_p_dist',
#  'J0023+0923_rednoise_gamma',
#  'J0023+0923_rednoise_log10_A',
#  'J0030+0451_cw_p_dist',
#  'J0030+0451_rednoise_gamma',
#  'J0030+0451_rednoise_log10_A',
#  'J0125-2327_cw_p_dist',
#  'J0125-2327_rednoise_gamma',
#  'J0125-2327_rednoise_log10_A',
#  'J0340+4130_cw_p_dist',
#  'J0340+4130_rednoise_gamma',
#  'J0340+4130_rednoise_log10_A',
#  'J0406+3039_cw_p_dist',
#  'J0406+3039_rednoise_gamma',
#  'J0406+3039_rednoise_log10_A',
#  'J0437-4715_cw_p_dist',
#  'J0437-4715_rednoise_gamma',
#  'J0437-4715_rednoise_log10_A',
#  'J0509+0856_cw_p_dist',
#  'J0509+0856_rednoise_gamma',
#  'J0509+0856_rednoise_log10_A',
#  'cw_cosinc',
#  'cw_cosinc_2',
#  'cw_log10_f0',
#  'cw_log10_f0_2',
#  'cw_log10_h0',
#  'cw_log10_h0_2',
#  'cw_phi_earth',
#  'cw_phi_earth_2',
#  'cw_psi',
#  'cw_psi_2',
#  'cw_ra',
#  'cw_ra_2',
#  'cw_sindec',
#  'cw_sindec_2',
#  'gw_gamma',
#  'gw_log10_A']

# %% [markdown]
# Slightly unresolved jit issue means that I have to use this wrapper below as a workaround to get the lnL to quickly evaluate

# %%
param_keys = list(sorted_dict.keys())

# Define the wrapper
def logl_wrapped(x_array):
    # Convert array -> dict
    params = {k: v for k, v in zip(param_keys, x_array)}
    return logl(params)

# %%
param_keys
# Out:
# ['B1855+09_cw_p_dist',
#  'B1855+09_rednoise_gamma',
#  'B1855+09_rednoise_log10_A',
#  'B1937+21_cw_p_dist',
#  'B1937+21_rednoise_gamma',
#  'B1937+21_rednoise_log10_A',
#  'B1953+29_cw_p_dist',
#  'B1953+29_rednoise_gamma',
#  'B1953+29_rednoise_log10_A',
#  'J0023+0923_cw_p_dist',
#  'J0023+0923_rednoise_gamma',
#  'J0023+0923_rednoise_log10_A',
#  'J0030+0451_cw_p_dist',
#  'J0030+0451_rednoise_gamma',
#  'J0030+0451_rednoise_log10_A',
#  'J0125-2327_cw_p_dist',
#  'J0125-2327_rednoise_gamma',
#  'J0125-2327_rednoise_log10_A',
#  'J0340+4130_cw_p_dist',
#  'J0340+4130_rednoise_gamma',
#  'J0340+4130_rednoise_log10_A',
#  'J0406+3039_cw_p_dist',
#  'J0406+3039_rednoise_gamma',
#  'J0406+3039_rednoise_log10_A',
#  'J0437-4715_cw_p_dist',
#  'J0437-4715_rednoise_gamma',
#  'J0437-4715_rednoise_log10_A',
#  'J0509+0856_cw_p_dist',
#  'J0509+0856_rednoise_gamma',
#  'J0509+0856_rednoise_log10_A',
#  'cw_cosinc',
#  'cw_cosinc_2',
#  'cw_log10_f0',
#  'cw_log10_f0_2',
#  'cw_log10_h0',
#  'cw_log10_h0_2',
#  'cw_phi_earth',
#  'cw_phi_earth_2',
#  'cw_psi',
#  'cw_psi_2',
#  'cw_ra',
#  'cw_ra_2',
#  'cw_sindec',
#  'cw_sindec_2',
#  'gw_gamma',
#  'gw_log10_A',
#  'J0557+1551_rednoise_log10_A',
#  'J0605+3757_rednoise_log10_A',
#  'J0610-2100_rednoise_log10_A',
#  'J0613-0200_rednoise_log10_A',
#  'J0614-3329_rednoise_log10_A',
#  'J0636+5128_rednoise_log10_A',
#  'J0636-3044_rednoise_log10_A',
#  'J0645+5158_rednoise_log10_A',
#  'J0709+0458_rednoise_log10_A',
#  'J0711-6830_rednoise_log10_A',
#  'J0740+6620_rednoise_log10_A',
#  'J0751+1807_rednoise_log10_A',
#  'J0900-3144_rednoise_log10_A',
#  'J0931-1902_rednoise_log10_A',
#  'J0955-6150_rednoise_log10_A',
#  'J1012+5307_rednoise_log10_A',
#  'J1012-4235_rednoise_log10_A',
#  'J1017-7156_rednoise_log10_A',
#  'J1022+1001_rednoise_log10_A',
#  'J1024-0719_rednoise_log10_A',
#  'J1036-8317_rednoise_log10_A',
#  'J1045-4509_rednoise_log10_A',
#  'J1101-6424_rednoise_log10_A',
#  'J1103-5403_rednoise_log10_A',
#  'J1125+7819_rednoise_log10_A',
#  'J1125-5825_rednoise_log10_A',
#  'J1125-6014_rednoise_log10_A',
#  'J1216-6410_rednoise_log10_A',
#  'J1312+0051_rednoise_log10_A',
#  'J1327-0755_rednoise_log10_A',
#  'J1421-4409_rednoise_log10_A',
#  'J1431-5740_rednoise_log10_A',
#  'J1435-6100_rednoise_log10_A',
#  'J1446-4701_rednoise_log10_A',
#  'J1453+1902_rednoise_log10_A',
#  'J1455-3330_rednoise_log10_A',
#  'J1525-5545_rednoise_log10_A',
#  'J1543-5149_rednoise_log10_A',
#  'J1545-4550_rednoise_log10_A',
#  'J1547-5709_rednoise_log10_A',
#  'J1600-3053_rednoise_log10_A',
#  'J1603-7202_rednoise_log10_A',
#  'J1614-2230_rednoise_log10_A',
#  'J1629-6902_rednoise_log10_A',
#  'J1630+3734_rednoise_log10_A',
#  'J1640+2224_rednoise_log10_A',
#  'J1643-1224_rednoise_log10_A',
#  'J1652-4838_rednoise_log10_A',
#  'J1653-2054_rednoise_log10_A',
#  'J1658-5324_rednoise_log10_A',
#  'J1705-1903_rednoise_log10_A',
#  'J1708-3506_rednoise_log10_A',
#  'J1713+0747_rednoise_log10_A',
#  'J1719-1438_rednoise_log10_A',
#  'J1721-2457_rednoise_log10_A',
#  'J1730-2304_rednoise_log10_A',
#  'J1732-5049_rednoise_log10_A',
#  'J1737-0811_rednoise_log10_A',
#  'J1738+0333_rednoise_log10_A',
#  'J1741+1351_rednoise_log10_A',
#  'J1744-1134_rednoise_log10_A',
#  'J1745+1017_rednoise_log10_A',
#  'J1747-4036_rednoise_log10_A',
#  'J1751-2857_rednoise_log10_A',
#  'J1756-2251_rednoise_log10_A',
#  'J1757-5322_rednoise_log10_A',
#  'J1801-1417_rednoise_log10_A',
#  'J1802-2124_rednoise_log10_A',
#  'J1804-2717_rednoise_log10_A',
#  'J1811-2405_rednoise_log10_A',
#  'J1824-2452A_rednoise_log10_A',
#  'J1825-0319_rednoise_log10_A',
#  'J1832-0836_rednoise_log10_A',
#  'J1843-1113_rednoise_log10_A',
#  'J1853+1303_rednoise_log10_A',
#  'J1902-5105_rednoise_log10_A',
#  'J1903+0327_rednoise_log10_A',
#  'J1903-7051_rednoise_log10_A',
#  'J1909-3744_rednoise_log10_A',
#  'J1910+1256_rednoise_log10_A',
#  'J1911+1347_rednoise_log10_A',
#  'J1918-0642_rednoise_log10_A',
#  'J1923+2515_rednoise_log10_A',
#  'J1933-6211_rednoise_log10_A',
#  'J1944+0907_rednoise_log10_A',
#  'J1946+3417_rednoise_log10_A',
#  'J1946-5403_rednoise_log10_A',
#  'J2010-1323_rednoise_log10_A',
#  'J2017+0603_rednoise_log10_A',
#  'J2033+1734_rednoise_log10_A',
#  'J2039-3616_rednoise_log10_A',
#  'J2043+1711_rednoise_log10_A',
#  'J2124-3358_rednoise_log10_A',
#  'J2129-5721_rednoise_log10_A',
#  'J2145-0750_rednoise_log10_A',
#  'J2150-0326_rednoise_log10_A',
#  'J2214+3000_rednoise_log10_A',
#  'J2222-0137_rednoise_log10_A',
#  'J2229+2643_rednoise_log10_A',
#  'J2234+0611_rednoise_log10_A',
#  'J2234+0944_rednoise_log10_A',
#  'J2241-5236_rednoise_log10_A',
#  'J2302+4442_rednoise_log10_A',
#  'J2317+1439_rednoise_log10_A',
#  'J2322+2057_rednoise_log10_A',
#  'J2322-2650_rednoise_log10_A',
#  'J0557+1551_rednoise_gamma',
#  'J0605+3757_rednoise_gamma',
#  'J0610-2100_rednoise_gamma',
#  'J0613-0200_rednoise_gamma',
#  'J0614-3329_rednoise_gamma',
#  'J0636+5128_rednoise_gamma',
#  'J0636-3044_rednoise_gamma',
#  'J0645+5158_rednoise_gamma',
#  'J0709+0458_rednoise_gamma',
#  'J0711-6830_rednoise_gamma',
#  'J0740+6620_rednoise_gamma',
#  'J0751+1807_rednoise_gamma',
#  'J0900-3144_rednoise_gamma',
#  'J0931-1902_rednoise_gamma',
#  'J0955-6150_rednoise_gamma',
#  'J1012+5307_rednoise_gamma',
#  'J1012-4235_rednoise_gamma',
#  'J1017-7156_rednoise_gamma',
#  'J1022+1001_rednoise_gamma',
#  'J1024-0719_rednoise_gamma',
#  'J1036-8317_rednoise_gamma',
#  'J1045-4509_rednoise_gamma',
#  'J1101-6424_rednoise_gamma',
#  'J1103-5403_rednoise_gamma',
#  'J1125+7819_rednoise_gamma',
#  'J1125-5825_rednoise_gamma',
#  'J1125-6014_rednoise_gamma',
#  'J1216-6410_rednoise_gamma',
#  'J1312+0051_rednoise_gamma',
#  'J1327-0755_rednoise_gamma',
#  'J1421-4409_rednoise_gamma',
#  'J1431-5740_rednoise_gamma',
#  'J1435-6100_rednoise_gamma',
#  'J1446-4701_rednoise_gamma',
#  'J1453+1902_rednoise_gamma',
#  'J1455-3330_rednoise_gamma',
#  'J1525-5545_rednoise_gamma',
#  'J1543-5149_rednoise_gamma',
#  'J1545-4550_rednoise_gamma',
#  'J1547-5709_rednoise_gamma',
#  'J1600-3053_rednoise_gamma',
#  'J1603-7202_rednoise_gamma',
#  'J1614-2230_rednoise_gamma',
#  'J1629-6902_rednoise_gamma',
#  'J1630+3734_rednoise_gamma',
#  'J1640+2224_rednoise_gamma',
#  'J1643-1224_rednoise_gamma',
#  'J1652-4838_rednoise_gamma',
#  'J1653-2054_rednoise_gamma',
#  'J1658-5324_rednoise_gamma',
#  'J1705-1903_rednoise_gamma',
#  'J1708-3506_rednoise_gamma',
#  'J1713+0747_rednoise_gamma',
#  'J1719-1438_rednoise_gamma',
#  'J1721-2457_rednoise_gamma',
#  'J1730-2304_rednoise_gamma',
#  'J1732-5049_rednoise_gamma',
#  'J1737-0811_rednoise_gamma',
#  'J1738+0333_rednoise_gamma',
#  'J1741+1351_rednoise_gamma',
#  'J1744-1134_rednoise_gamma',
#  'J1745+1017_rednoise_gamma',
#  'J1747-4036_rednoise_gamma',
#  'J1751-2857_rednoise_gamma',
#  'J1756-2251_rednoise_gamma',
#  'J1757-5322_rednoise_gamma',
#  'J1801-1417_rednoise_gamma',
#  'J1802-2124_rednoise_gamma',
#  'J1804-2717_rednoise_gamma',
#  'J1811-2405_rednoise_gamma',
#  'J1824-2452A_rednoise_gamma',
#  'J1825-0319_rednoise_gamma',
#  'J1832-0836_rednoise_gamma',
#  'J1843-1113_rednoise_gamma',
#  'J1853+1303_rednoise_gamma',
#  'J1902-5105_rednoise_gamma',
#  'J1903+0327_rednoise_gamma',
#  'J1903-7051_rednoise_gamma',
#  'J1909-3744_rednoise_gamma',
#  'J1910+1256_rednoise_gamma',
#  'J1911+1347_rednoise_gamma',
#  'J1918-0642_rednoise_gamma',
#  'J1923+2515_rednoise_gamma',
#  'J1933-6211_rednoise_gamma',
#  'J1944+0907_rednoise_gamma',
#  'J1946+3417_rednoise_gamma',
#  'J1946-5403_rednoise_gamma',
#  'J2010-1323_rednoise_gamma',
#  'J2017+0603_rednoise_gamma',
#  'J2033+1734_rednoise_gamma',
#  'J2039-3616_rednoise_gamma',
#  'J2043+1711_rednoise_gamma',
#  'J2124-3358_rednoise_gamma',
#  'J2129-5721_rednoise_gamma',
#  'J2145-0750_rednoise_gamma',
#  'J2150-0326_rednoise_gamma',
#  'J2214+3000_rednoise_gamma',
#  'J2222-0137_rednoise_gamma',
#  'J2229+2643_rednoise_gamma',
#  'J2234+0611_rednoise_gamma',
#  'J2234+0944_rednoise_gamma',
#  'J2241-5236_rednoise_gamma',
#  'J2302+4442_rednoise_gamma',
#  'J2317+1439_rednoise_gamma',
#  'J2322+2057_rednoise_gamma',
#  'J2322-2650_rednoise_gamma',
#  'J0557+1551_cw_p_dist',
#  'J0605+3757_cw_p_dist',
#  'J0610-2100_cw_p_dist',
#  'J0613-0200_cw_p_dist',
#  'J0614-3329_cw_p_dist',
#  'J0636+5128_cw_p_dist',
#  'J0636-3044_cw_p_dist',
#  'J0645+5158_cw_p_dist',
#  'J0709+0458_cw_p_dist',
#  'J0711-6830_cw_p_dist',
#  'J0740+6620_cw_p_dist',
#  'J0751+1807_cw_p_dist',
#  'J0900-3144_cw_p_dist',
#  'J0931-1902_cw_p_dist',
#  'J0955-6150_cw_p_dist',
#  'J1012+5307_cw_p_dist',
#  'J1012-4235_cw_p_dist',
#  'J1017-7156_cw_p_dist',
#  'J1022+1001_cw_p_dist',
#  'J1024-0719_cw_p_dist',
#  'J1036-8317_cw_p_dist',
#  'J1045-4509_cw_p_dist',
#  'J1101-6424_cw_p_dist',
#  'J1103-5403_cw_p_dist',
#  'J1125+7819_cw_p_dist',
#  'J1125-5825_cw_p_dist',
#  'J1125-6014_cw_p_dist',
#  'J1216-6410_cw_p_dist',
#  'J1312+0051_cw_p_dist',
#  'J1327-0755_cw_p_dist',
#  'J1421-4409_cw_p_dist',
#  'J1431-5740_cw_p_dist',
#  'J1435-6100_cw_p_dist',
#  'J1446-4701_cw_p_dist',
#  'J1453+1902_cw_p_dist',
#  'J1455-3330_cw_p_dist',
#  'J1525-5545_cw_p_dist',
#  'J1543-5149_cw_p_dist',
#  'J1545-4550_cw_p_dist',
#  'J1547-5709_cw_p_dist',
#  'J1600-3053_cw_p_dist',
#  'J1603-7202_cw_p_dist',
#  'J1614-2230_cw_p_dist',
#  'J1629-6902_cw_p_dist',
#  'J1630+3734_cw_p_dist',
#  'J1640+2224_cw_p_dist',
#  'J1643-1224_cw_p_dist',
#  'J1652-4838_cw_p_dist',
#  'J1653-2054_cw_p_dist',
#  'J1658-5324_cw_p_dist',
#  'J1705-1903_cw_p_dist',
#  'J1708-3506_cw_p_dist',
#  'J1713+0747_cw_p_dist',
#  'J1719-1438_cw_p_dist',
#  'J1721-2457_cw_p_dist',
#  'J1730-2304_cw_p_dist',
#  'J1732-5049_cw_p_dist',
#  'J1737-0811_cw_p_dist',
#  'J1738+0333_cw_p_dist',
#  'J1741+1351_cw_p_dist',
#  'J1744-1134_cw_p_dist',
#  'J1745+1017_cw_p_dist',
#  'J1747-4036_cw_p_dist',
#  'J1751-2857_cw_p_dist',
#  'J1756-2251_cw_p_dist',
#  'J1757-5322_cw_p_dist',
#  'J1801-1417_cw_p_dist',
#  'J1802-2124_cw_p_dist',
#  'J1804-2717_cw_p_dist',
#  'J1811-2405_cw_p_dist',
#  'J1824-2452A_cw_p_dist',
#  'J1825-0319_cw_p_dist',
#  'J1832-0836_cw_p_dist',
#  'J1843-1113_cw_p_dist',
#  'J1853+1303_cw_p_dist',
#  'J1902-5105_cw_p_dist',
#  'J1903+0327_cw_p_dist',
#  'J1903-7051_cw_p_dist',
#  'J1909-3744_cw_p_dist',
#  'J1910+1256_cw_p_dist',
#  'J1911+1347_cw_p_dist',
#  'J1918-0642_cw_p_dist',
#  'J1923+2515_cw_p_dist',
#  'J1933-6211_cw_p_dist',
#  'J1944+0907_cw_p_dist',
#  'J1946+3417_cw_p_dist',
#  'J1946-5403_cw_p_dist',
#  'J2010-1323_cw_p_dist',
#  'J2017+0603_cw_p_dist',
#  'J2033+1734_cw_p_dist',
#  'J2039-3616_cw_p_dist',
#  'J2043+1711_cw_p_dist',
#  'J2124-3358_cw_p_dist',
#  'J2129-5721_cw_p_dist',
#  'J2145-0750_cw_p_dist',
#  'J2150-0326_cw_p_dist',
#  'J2214+3000_cw_p_dist',
#  'J2222-0137_cw_p_dist',
#  'J2229+2643_cw_p_dist',
#  'J2234+0611_cw_p_dist',
#  'J2234+0944_cw_p_dist',
#  'J2241-5236_cw_p_dist',
#  'J2302+4442_cw_p_dist',
#  'J2317+1439_cw_p_dist',
#  'J2322+2057_cw_p_dist',
#  'J2322-2650_cw_p_dist']

# %% [markdown]
# jit and test the likelihood against the unjitted version

# %%
logl_fn = jax.jit(logl_wrapped)

# %%
# Jitted
x0 = jnp.array(list(sorted_dict.values()), dtype=jnp.float64)
logl_fn(x0)
# Out:
# Array(37713.79350435, dtype=float64)

# %%
#Unjitted
logl(sorted_dict)
# Out:
# Array(37713.79350435, dtype=float64)

# %% [markdown]
# #### pulsar distance testing
#
# Here I'm iterating around the pulsar distances for 3 of the 10 puslars in the array.
#
# All other parameters sit at their true (injected) values and then I'm just shaking the values of the three pular distances below

# %%
print(enterprise_params['J0437-4715_cw_p_dist'])
print(enterprise_params['J0030+0451_cw_p_dist'])
print(enterprise_params['J0125-2327_cw_p_dist'])
# Out:
# 0.1549
# 0.3296
# 0.873

# %%
from tqdm import tqdm

distance1 = np.linspace(0.01, 5, 50)
distance2 = np.linspace(0.01, 1, 1000)
distance3 = np.linspace(0.01, 5, 50)
logls = []
temp_dict = sorted_dict.copy()

order_map = {key: i for i, key in enumerate(logl.params)}

sorted_items = sorted(temp_dict.items(), key=lambda item: order_map.get(item[0], float('inf')))
sorted_dict = dict(sorted_items)

# for d1 in tqdm(distance1, desc="Distance 1 Loop"):
#     sorted_dict['J0437-4715_cw_p_dist'] = d1
for d2 in distance2:
    sorted_dict['J0030+0451_cw_p_dist'] = d2
    x0 = jnp.array(list(sorted_dict.values()), dtype=jnp.float64)
    logls.append(logl_fn(x0))
        # for d3 in distance3:
        #     sorted_dict['J0125-2327_cw_p_dist'] = d3
            # x0 = jnp.array(list(sorted_dict.values()), dtype=jnp.float64)
            # logls.append(logl_fn(x0))
            #logls.append(logl(temp_dict))

# %%
sorted_dict
# Out:
# {'B1855+09_cw_p_dist': 1.18,
#  'B1855+09_rednoise_gamma': 3.2721791365813067,
#  'B1855+09_rednoise_log10_A': -17.844093269852827,
#  'B1937+21_cw_p_dist': 3.1,
#  'B1937+21_rednoise_gamma': 3.906091780410814,
#  'B1937+21_rednoise_log10_A': -17.707097691150125,
#  'B1953+29_cw_p_dist': 4.64,
#  'B1953+29_rednoise_gamma': 3.072782132281432,
#  'B1953+29_rednoise_log10_A': -17.029873709721603,
#  'J0023+0923_cw_p_dist': 1.02,
#  'J0023+0923_rednoise_gamma': 3.1506727618297723,
#  'J0023+0923_rednoise_log10_A': -15.301133409164677,
#  'J0030+0451_cw_p_dist': np.float64(1.0),
#  'J0030+0451_rednoise_gamma': 3.19506467186759,
#  'J0030+0451_rednoise_log10_A': -17.11255166022465,
#  'J0125-2327_cw_p_dist': 0.873,
#  'J0125-2327_rednoise_gamma': 3.928404864450094,
#  'J0125-2327_rednoise_log10_A': -15.09905106744675,
#  'J0340+4130_cw_p_dist': 1.71,
#  'J0340+4130_rednoise_gamma': 3.2062685073177484,
#  'J0340+4130_rednoise_log10_A': -16.447399446077107,
#  'J0406+3039_cw_p_dist': 1.72,
#  'J0406+3039_rednoise_gamma': 3.6308205122812143,
#  'J0406+3039_rednoise_log10_A': -16.889406544992713,
#  'J0437-4715_cw_p_dist': 0.1549,
#  'J0437-4715_rednoise_gamma': 3.9526861926696437,
#  'J0437-4715_rednoise_log10_A': -16.019534448663993,
#  'J0509+0856_cw_p_dist': 1.45,
#  'J0509+0856_rednoise_gamma': 3.936676234895252,
#  'J0509+0856_rednoise_log10_A': -16.725493044610776,
#  'cw_cosinc': 0,
#  'cw_cosinc_2': 0,
#  'cw_log10_f0': -8,
#  'cw_log10_f0_2': -7.5,
#  'cw_log10_h0': -13,
#  'cw_log10_h0_2': -13,
#  'cw_phi_earth': 3.141592653589793,
#  'cw_phi_earth_2': 3.141592653589793,
#  'cw_psi': 0.7853981633974483,
#  'cw_psi_2': 0.7853981633974483,
#  'cw_ra': 0.458,
#  'cw_ra_2': 0.158,
#  'cw_sindec': 0.43,
#  'cw_sindec_2': 0.13,
#  'gw_gamma': 4.333,
#  'gw_log10_A': -14.5,
#  'J0557+1551_rednoise_log10_A': -17.173441192506115,
#  'J0605+3757_rednoise_log10_A': -15.359002407247074,
#  'J0610-2100_rednoise_log10_A': -15.560569962049723,
#  'J0613-0200_rednoise_log10_A': -15.832675902558282,
#  'J0614-3329_rednoise_log10_A': -16.98867113925095,
#  'J0636+5128_rednoise_log10_A': -17.98581097787469,
#  'J0636-3044_rednoise_log10_A': -15.583268875635234,
#  'J0645+5158_rednoise_log10_A': -15.291299579337483,
#  'J0709+0458_rednoise_log10_A': -16.254372202381067,
#  'J0711-6830_rednoise_log10_A': -15.907204409525255,
#  'J0740+6620_rednoise_log10_A': -15.013238540777227,
#  'J0751+1807_rednoise_log10_A': -16.567626954340447,
#  'J0900-3144_rednoise_log10_A': -15.867160193980881,
#  'J0931-1902_rednoise_log10_A': -15.271676294245388,
#  'J0955-6150_rednoise_log10_A': -16.368812045565914,
#  'J1012+5307_rednoise_log10_A': -16.29463086631633,
#  'J1012-4235_rednoise_log10_A': -17.016034034538613,
#  'J1017-7156_rednoise_log10_A': -16.245642371572924,
#  'J1022+1001_rednoise_log10_A': -17.043252315422468,
#  'J1024-0719_rednoise_log10_A': -17.07717160168745,
#  'J1036-8317_rednoise_log10_A': -17.754667953086873,
#  'J1045-4509_rednoise_log10_A': -16.687661768825535,
#  'J1101-6424_rednoise_log10_A': -15.563629463590392,
#  'J1103-5403_rednoise_log10_A': -17.3262039448355,
#  'J1125+7819_rednoise_log10_A': -17.187963416350364,
#  'J1125-5825_rednoise_log10_A': -15.083074907766807,
#  'J1125-6014_rednoise_log10_A': -17.064971582577005,
#  'J1216-6410_rednoise_log10_A': -16.801153340570856,
#  'J1312+0051_rednoise_log10_A': -16.740037359371605,
#  'J1327-0755_rednoise_log10_A': -16.255253340687627,
#  'J1421-4409_rednoise_log10_A': -16.706152225640462,
#  'J1431-5740_rednoise_log10_A': -15.221822345182943,
#  'J1435-6100_rednoise_log10_A': -16.54990576983257,
#  'J1446-4701_rednoise_log10_A': -15.688192229007825,
#  'J1453+1902_rednoise_log10_A': -16.953966701243793,
#  'J1455-3330_rednoise_log10_A': -15.06094659038365,
#  'J1525-5545_rednoise_log10_A': -17.73446197622637,
#  'J1543-5149_rednoise_log10_A': -17.128180973528544,
#  'J1545-4550_rednoise_log10_A': -15.912126076116314,
#  'J1547-5709_rednoise_log10_A': -16.403427971223074,
#  'J1600-3053_rednoise_log10_A': -17.21171076799904,
#  'J1603-7202_rednoise_log10_A': -15.097911851919648,
#  'J1614-2230_rednoise_log10_A': -15.591355758989579,
#  'J1629-6902_rednoise_log10_A': -15.510588930290853,
#  'J1630+3734_rednoise_log10_A': -16.66946377511065,
#  'J1640+2224_rednoise_log10_A': -17.350199762643374,
#  'J1643-1224_rednoise_log10_A': -16.75744039198758,
#  'J1652-4838_rednoise_log10_A': -16.002252684724812,
#  'J1653-2054_rednoise_log10_A': -16.0870540243194,
#  'J1658-5324_rednoise_log10_A': -16.470216158813926,
#  'J1705-1903_rednoise_log10_A': -15.127370590296117,
#  'J1708-3506_rednoise_log10_A': -17.938430797263496,
#  'J1713+0747_rednoise_log10_A': -15.40451664919555,
#  'J1719-1438_rednoise_log10_A': -17.413799051126475,
#  'J1721-2457_rednoise_log10_A': -15.761591510046081,
#  'J1730-2304_rednoise_log10_A': -15.802936272166715,
#  'J1732-5049_rednoise_log10_A': -17.55571634098891,
#  'J1737-0811_rednoise_log10_A': -15.252085183869653,
#  'J1738+0333_rednoise_log10_A': -16.626587164548226,
#  'J1741+1351_rednoise_log10_A': -16.440609619390006,
#  'J1744-1134_rednoise_log10_A': -15.692776618738067,
#  'J1745+1017_rednoise_log10_A': -16.29218360910983,
#  'J1747-4036_rednoise_log10_A': -15.901315816706468,
#  'J1751-2857_rednoise_log10_A': -16.588507778157393,
#  'J1756-2251_rednoise_log10_A': -16.708998239938115,
#  'J1757-5322_rednoise_log10_A': -15.781702146504625,
#  'J1801-1417_rednoise_log10_A': -15.086687080090755,
#  'J1802-2124_rednoise_log10_A': -17.91118929394941,
#  'J1804-2717_rednoise_log10_A': -16.971397476926466,
#  'J1811-2405_rednoise_log10_A': -15.29022871592232,
#  'J1824-2452A_rednoise_log10_A': -17.344614600935028,
#  'J1825-0319_rednoise_log10_A': -17.688770262132973,
#  'J1832-0836_rednoise_log10_A': -16.612660651698825,
#  'J1843-1113_rednoise_log10_A': -15.328831916439324,
#  'J1853+1303_rednoise_log10_A': -16.60604164378085,
#  'J1902-5105_rednoise_log10_A': -16.56333684837709,
#  'J1903+0327_rednoise_log10_A': -17.901991390541774,
#  'J1903-7051_rednoise_log10_A': -17.285869475497865,
#  'J1909-3744_rednoise_log10_A': -15.574744701684065,
#  'J1910+1256_rednoise_log10_A': -17.745910407668262,
#  'J1911+1347_rednoise_log10_A': -17.22373754401808,
#  'J1918-0642_rednoise_log10_A': -15.941325448023013,
#  'J1923+2515_rednoise_log10_A': -17.14510799305737,
#  'J1933-6211_rednoise_log10_A': -17.73865366146039,
#  'J1944+0907_rednoise_log10_A': -16.381031041277495,
#  'J1946+3417_rednoise_log10_A': -17.986800114295693,
#  'J1946-5403_rednoise_log10_A': -16.843418164291823,
#  'J2010-1323_rednoise_log10_A': -17.42830257063724,
#  'J2017+0603_rednoise_log10_A': -17.176025630102473,
#  'J2033+1734_rednoise_log10_A': -15.040883381624504,
#  'J2039-3616_rednoise_log10_A': -15.771964474062976,
#  'J2043+1711_rednoise_log10_A': -16.940941484825185,
#  'J2124-3358_rednoise_log10_A': -15.47347112150645,
#  'J2129-5721_rednoise_log10_A': -17.133715305853524,
#  'J2145-0750_rednoise_log10_A': -17.328284776874565,
#  'J2150-0326_rednoise_log10_A': -16.393849778068446,
#  'J2214+3000_rednoise_log10_A': -15.691507792933532,
#  'J2222-0137_rednoise_log10_A': -16.511719310284587,
#  'J2229+2643_rednoise_log10_A': -15.992547291397873,
#  'J2234+0611_rednoise_log10_A': -17.24803309795335,
#  'J2234+0944_rednoise_log10_A': -17.058324175944243,
#  'J2241-5236_rednoise_log10_A': -16.63645769751631,
#  'J2302+4442_rednoise_log10_A': -16.792338089918537,
#  'J2317+1439_rednoise_log10_A': -16.513654052832724,
#  'J2322+2057_rednoise_log10_A': -15.398454498463611,
#  'J2322-2650_rednoise_log10_A': -16.06095014495067,
#  'J0557+1551_rednoise_gamma': 3.6291305060066907,
#  'J0605+3757_rednoise_gamma': 3.1065990415679225,
#  'J0610-2100_rednoise_gamma': 3.612869802487439,
#  'J0613-0200_rednoise_gamma': 3.8411357395587182,
#  'J0614-3329_rednoise_gamma': 3.5199097594191016,
#  'J0636+5128_rednoise_gamma': 3.7712942294141665,
#  'J0636-3044_rednoise_gamma': 3.363166992804136,
#  'J0645+5158_rednoise_gamma': 3.2184188000556953,
#  'J0709+0458_rednoise_gamma': 3.256635924087954,
#  'J0711-6830_rednoise_gamma': 3.6630726333467813,
#  'J0740+6620_rednoise_gamma': 3.5495600339332603,
#  'J0751+1807_rednoise_gamma': 3.8967398421151676,
#  'J0900-3144_rednoise_gamma': 3.743002905236364,
#  'J0931-1902_rednoise_gamma': 3.621600839380692,
#  'J0955-6150_rednoise_gamma': 3.944109732540811,
#  'J1012+5307_rednoise_gamma': 3.368557752502384,
#  'J1012-4235_rednoise_gamma': 3.7919872682359945,
#  'J1017-7156_rednoise_gamma': 3.195193871788209,
#  'J1022+1001_rednoise_gamma': 3.420421495440979,
#  'J1024-0719_rednoise_gamma': 3.504436371872547,
#  'J1036-8317_rednoise_gamma': 3.636937825586846,
#  'J1045-4509_rednoise_gamma': 3.8774309727058993,
#  'J1101-6424_rednoise_gamma': 3.303821937056708,
#  'J1103-5403_rednoise_gamma': 3.912499469729812,
#  'J1125+7819_rednoise_gamma': 3.8060263555618374,
#  'J1125-5825_rednoise_gamma': 3.055974802254563,
#  'J1125-6014_rednoise_gamma': 3.9293630760397655,
#  'J1216-6410_rednoise_gamma': 3.761666500132501,
#  'J1312+0051_rednoise_gamma': 3.9632007249819816,
#  'J1327-0755_rednoise_gamma': 3.170039810691237,
#  'J1421-4409_rednoise_gamma': 3.6108637460008994,
#  'J1431-5740_rednoise_gamma': 3.8479279979865666,
#  'J1435-6100_rednoise_gamma': 3.391059853607382,
#  'J1446-4701_rednoise_gamma': 3.7833181889216503,
#  'J1453+1902_rednoise_gamma': 3.5590502776292396,
#  'J1455-3330_rednoise_gamma': 3.813189240514056,
#  'J1525-5545_rednoise_gamma': 3.39092372318136,
#  'J1543-5149_rednoise_gamma': 3.4411288807356892,
#  'J1545-4550_rednoise_gamma': 3.768026152479565,
#  'J1547-5709_rednoise_gamma': 3.4012752353071094,
#  'J1600-3053_rednoise_gamma': 3.5080271930376012,
#  'J1603-7202_rednoise_gamma': 3.501211563897204,
#  'J1614-2230_rednoise_gamma': 3.4037605041189725,
#  'J1629-6902_rednoise_gamma': 3.4647523841332584,
#  'J1630+3734_rednoise_gamma': 3.1975126794975446,
#  'J1640+2224_rednoise_gamma': 3.5326479033529052,
#  'J1643-1224_rednoise_gamma': 3.342609188396467,
#  'J1652-4838_rednoise_gamma': 3.374005418328984,
#  'J1653-2054_rednoise_gamma': 3.0630950236552756,
#  'J1658-5324_rednoise_gamma': 3.04862884028009,
#  'J1705-1903_rednoise_gamma': 3.9016634386421423,
#  'J1708-3506_rednoise_gamma': 3.014901553282345,
#  'J1713+0747_rednoise_gamma': 3.942214672513111,
#  'J1719-1438_rednoise_gamma': 3.6755552819591344,
#  'J1721-2457_rednoise_gamma': 3.5375326356814156,
#  'J1730-2304_rednoise_gamma': 3.1508862726375995,
#  'J1732-5049_rednoise_gamma': 3.977040922265605,
#  'J1737-0811_rednoise_gamma': 3.35718331051232,
#  'J1738+0333_rednoise_gamma': 3.313092037144819,
#  'J1741+1351_rednoise_gamma': 3.6809563248619193,
#  'J1744-1134_rednoise_gamma': 3.751814459020797,
#  'J1745+1017_rednoise_gamma': 3.1910426019064104,
#  'J1747-4036_rednoise_gamma': 3.7786422917977935,
#  'J1751-2857_rednoise_gamma': 3.3075856826318533,
#  'J1756-2251_rednoise_gamma': 3.68552200163587,
#  'J1757-5322_rednoise_gamma': 3.1600036967662746,
#  'J1801-1417_rednoise_gamma': 3.4694172713010736,
#  'J1802-2124_rednoise_gamma': 3.756367379168017,
#  'J1804-2717_rednoise_gamma': 3.220271714260197,
#  'J1811-2405_rednoise_gamma': 3.70365099599883,
#  'J1824-2452A_rednoise_gamma': 3.4140241026275557,
#  'J1825-0319_rednoise_gamma': 3.0127530909911444,
#  'J1832-0836_rednoise_gamma': 3.5312378486120304,
#  'J1843-1113_rednoise_gamma': 3.816831018522119,
#  'J1853+1303_rednoise_gamma': 3.072057652858233,
#  'J1902-5105_rednoise_gamma': 3.5322778637870846,
#  'J1903+0327_rednoise_gamma': 3.2235364525786285,
#  'J1903-7051_rednoise_gamma': 3.773847855314162,
#  'J1909-3744_rednoise_gamma': 3.427277895215057,
#  'J1910+1256_rednoise_gamma': 3.613575548754338,
#  'J1911+1347_rednoise_gamma': 3.2151117961785562,
#  'J1918-0642_rednoise_gamma': 3.005967762173021,
#  'J1923+2515_rednoise_gamma': 3.9483392106397597,
#  'J1933-6211_rednoise_gamma': 3.1378637680715142,
#  'J1944+0907_rednoise_gamma': 3.824299814325582,
#  'J1946+3417_rednoise_gamma': 3.983016895441919,
#  'J1946-5403_rednoise_gamma': 3.9379112157001837,
#  'J2010-1323_rednoise_gamma': 3.8799366742761254,
#  'J2017+0603_rednoise_gamma': 3.732369884087037,
#  'J2033+1734_rednoise_gamma': 3.9466857423786514,
#  'J2039-3616_rednoise_gamma': 3.418949054958035,
#  'J2043+1711_rednoise_gamma': 3.450450044544467,
#  'J2124-3358_rednoise_gamma': 3.341434087841347,
#  'J2129-5721_rednoise_gamma': 3.195422380096664,
#  'J2145-0750_rednoise_gamma': 3.8940637375572082,
#  'J2150-0326_rednoise_gamma': 3.1998452690678136,
#  'J2214+3000_rednoise_gamma': 3.905044143143213,
#  'J2222-0137_rednoise_gamma': 3.7605521547497935,
#  'J2229+2643_rednoise_gamma': 3.928169936298047,
#  'J2234+0611_rednoise_gamma': 3.628463448531674,
#  'J2234+0944_rednoise_gamma': 3.2726411975651213,
#  'J2241-5236_rednoise_gamma': 3.2404819422484716,
#  'J2302+4442_rednoise_gamma': 3.44172625406144,
#  'J2317+1439_rednoise_gamma': 3.290973086132614,
#  'J2322+2057_rednoise_gamma': 3.5024908990615025,
#  'J2322-2650_rednoise_gamma': 3.608788146103545,
#  'J0557+1551_cw_p_dist': 2.87,
#  'J0605+3757_cw_p_dist': 0.7,
#  'J0610-2100_cw_p_dist': 1.38,
#  'J0613-0200_cw_p_dist': 1.07,
#  'J0614-3329_cw_p_dist': 0.63,
#  'J0636+5128_cw_p_dist': 1.27,
#  'J0636-3044_cw_p_dist': 0.679,
#  'J0645+5158_cw_p_dist': 1.37,
#  'J0709+0458_cw_p_dist': 1.8,
#  'J0711-6830_cw_p_dist': 0.106,
#  'J0740+6620_cw_p_dist': 0.94,
#  'J0751+1807_cw_p_dist': 1.17,
#  'J0900-3144_cw_p_dist': 0.89,
#  'J0931-1902_cw_p_dist': 1.88,
#  'J0955-6150_cw_p_dist': 2.172,
#  'J1012+5307_cw_p_dist': 0.862,
#  'J1012-4235_cw_p_dist': 2.5,
#  'J1017-7156_cw_p_dist': 1.807,
#  'J1022+1001_cw_p_dist': 0.706,
#  'J1024-0719_cw_p_dist': 1.08,
#  'J1036-8317_cw_p_dist': 0.934,
#  'J1045-4509_cw_p_dist': 0.34,
#  'J1101-6424_cw_p_dist': 2.175,
#  'J1103-5403_cw_p_dist': 1.683,
#  'J1125+7819_cw_p_dist': 0.63,
#  'J1125-5825_cw_p_dist': 1.744,
#  'J1125-6014_cw_p_dist': 0.988,
#  'J1216-6410_cw_p_dist': 1.098,
#  'J1312+0051_cw_p_dist': 0.84,
#  'J1327-0755_cw_p_dist': 25.0,
#  'J1421-4409_cw_p_dist': 2.085,
#  'J1431-5740_cw_p_dist': 3.553,
#  'J1435-6100_cw_p_dist': 2.816,
#  'J1446-4701_cw_p_dist': 1.569,
#  'J1453+1902_cw_p_dist': 1.15,
#  'J1455-3330_cw_p_dist': 1.01,
#  'J1525-5545_cw_p_dist': 3.14,
#  'J1543-5149_cw_p_dist': 1.149,
#  'J1545-4550_cw_p_dist': 2.222,
#  'J1547-5709_cw_p_dist': 2.695,
#  'J1600-3053_cw_p_dist': 1.84,
#  'J1603-7202_cw_p_dist': 3.7,
#  'J1614-2230_cw_p_dist': 0.699,
#  'J1629-6902_cw_p_dist': 0.963,
#  'J1630+3734_cw_p_dist': 0.089,
#  'J1640+2224_cw_p_dist': 1.404,
#  'J1643-1224_cw_p_dist': 0.835,
#  'J1652-4838_cw_p_dist': 4.395,
#  'J1653-2054_cw_p_dist': 2.631,
#  'J1658-5324_cw_p_dist': 0.88,
#  'J1705-1903_cw_p_dist': 1.62,
#  'J1708-3506_cw_p_dist': 3.32,
#  'J1713+0747_cw_p_dist': 1.138,
#  'J1719-1438_cw_p_dist': 1.21,
#  'J1721-2457_cw_p_dist': 1.393,
#  'J1730-2304_cw_p_dist': 0.529,
#  'J1732-5049_cw_p_dist': 1.873,
#  'J1737-0811_cw_p_dist': 0.206,
#  'J1738+0333_cw_p_dist': 1.64,
#  'J1741+1351_cw_p_dist': 2.36,
#  'J1744-1134_cw_p_dist': 0.4141,
#  'J1745+1017_cw_p_dist': 1.27,
#  'J1747-4036_cw_p_dist': 3.5,
#  'J1751-2857_cw_p_dist': 1.11,
#  'J1756-2251_cw_p_dist': 0.73,
#  'J1757-5322_cw_p_dist': 0.945,
#  'J1801-1417_cw_p_dist': 1.0,
#  'J1802-2124_cw_p_dist': 2.96,
#  'J1804-2717_cw_p_dist': 0.8,
#  'J1811-2405_cw_p_dist': 1.79,
#  'J1824-2452A_cw_p_dist': 5.37,
#  'J1825-0319_cw_p_dist': 3.862,
#  'J1832-0836_cw_p_dist': 2.0,
#  'J1843-1113_cw_p_dist': 1.72,
#  'J1853+1303_cw_p_dist': 1.91,
#  'J1902-5105_cw_p_dist': 1.645,
#  'J1903+0327_cw_p_dist': 6.49,
#  'J1903-7051_cw_p_dist': 0.93,
#  'J1909-3744_cw_p_dist': 1.159,
#  'J1910+1256_cw_p_dist': 3.52,
#  'J1911+1347_cw_p_dist': 2.08,
#  'J1918-0642_cw_p_dist': 1.44,
#  'J1923+2515_cw_p_dist': 0.94,
#  'J1933-6211_cw_p_dist': 0.65,
#  'J1944+0907_cw_p_dist': 1.38,
#  'J1946+3417_cw_p_dist': 5.12,
#  'J1946-5403_cw_p_dist': 1.15,
#  'J2010-1323_cw_p_dist': 1.94,
#  'J2017+0603_cw_p_dist': 1.57,
#  'J2033+1734_cw_p_dist': 1.99,
#  'J2039-3616_cw_p_dist': 1.704,
#  'J2043+1711_cw_p_dist': 1.58,
#  'J2124-3358_cw_p_dist': 0.413,
#  'J2129-5721_cw_p_dist': 3.2,
#  'J2145-0750_cw_p_dist': 0.624,
#  'J2150-0326_cw_p_dist': 1.972,
#  'J2214+3000_cw_p_dist': 1.54,
#  'J2222-0137_cw_p_dist': 0.268,
#  'J2229+2643_cw_p_dist': 1.43,
#  'J2234+0611_cw_p_dist': 1.23,
#  'J2234+0944_cw_p_dist': 1.0,
#  'J2241-5236_cw_p_dist': 1.042,
#  'J2302+4442_cw_p_dist': 1.18,
#  'J2317+1439_cw_p_dist': 1.57,
#  'J2322+2057_cw_p_dist': 1.0,
#  'J2322-2650_cw_p_dist': 0.227}

# %%
logl_fn(x0)
# Out:
# Array(37011.93817876, dtype=float64)

# %%
plt.plot(distance2,logls)
plt.ylabel("lnL")
plt.xlabel("Distance 2 (kpc)")
plt.axvline(enterprise_params['J0030+0451_cw_p_dist'], color='r', linestyle='--', label='Injected Distance')
#plt.xlim(0.05, 0.7)
plt.ylim(37600, 37800)
# Out:
# (37600.0, 37800.0)

# %%
# Normal for loop was taking ages. Attempt at vectorization.

# Alter gridsteps to change the coarseness of the grid. 
# The distances are surrounding the true values to understand the oscillations

from tqdm import tqdm

gridsteps = 100

distance1 = jnp.linspace(0.01, 0.2, gridsteps)
distance2 = jnp.linspace(0.25, 0.4, gridsteps)
distance3 = jnp.linspace(0.8, 1, gridsteps)

# Precompute everything that’s constant
order_map = {key: i for i, key in enumerate(logl.params)}
sorted_items = sorted(temp_dict.items(), key=lambda item: order_map.get(item[0], float('inf')))
base_params = jnp.array(list(dict(sorted_items).values()), dtype=jnp.float64)

# Get indices of the 3 pulsar-distance parameters in the array
i1 = order_map['J0437-4715_cw_p_dist']
i2 = order_map['J0030+0451_cw_p_dist']
i3 = order_map['J0125-2327_cw_p_dist']

# Make a full 3D meshgrid of parameter values
D1, D2, D3 = jnp.meshgrid(distance1, distance2, distance3, indexing='ij')
npts = D1.size*2

# Flatten for vectorized evaluation
D1f, D2f, D3f = D1.ravel(), D2.ravel(), D3.ravel()

def make_params(d1, d2, d3):
    """Return parameter vector with given distances."""
    vec = base_params.at[i1].set(d1)
    vec = vec.at[i2].set(d2)
    vec = vec.at[i3].set(d3)
    return vec

# Vectorize logl_fn over all (d1, d2, d3)
@jax.jit
@jax.vmap
def eval_logl(d1, d2, d3):
    return logl_fn(make_params(d1, d2, d3))

logls = []

for i in tqdm(range(0, npts, 4096)):
    sl = slice(i, i + 4096)
    logls_chunk = eval_logl(D1f[sl], D2f[sl], D3f[sl])
    logls.append(logls_chunk)

logls = jnp.concatenate(logls)
# Out:
#   0%|          | 0/489 [00:00<?, ?it/s]
# 2025-10-23 17:01:56.987920: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3425] Can't reduce memory use below 17.96GiB (19286978723 bytes) by rematerialization; only reduced to 22.03GiB (23652455128 bytes), down from 22.03GiB (23652455128 bytes) originally
# 2025-10-23 17:02:07.903820: W external/xla/xla/stream_executor/cuda/cuda_command_buffer.cc:740] Retry CUDA graph instantiation after OOM error
# E1023 17:02:07.909787  244206 pjrt_stream_executor_client.cc:2939] Execution of replica 0 failed: RESOURCE_EXHAUSTED: Underlying backend ran out of memory trying to instantiate command buffer with 20 (total of 0 alive graphs in the process). You can try to (a) Give more memory to the driver by reducing XLA_CLIENT_MEM_FRACTION (b) Disable command buffers with 'XLA_FLAGS=--xla_gpu_enable_command_buffer=' (empty set). Original error: Failed to instantiate CUDA graph: CUDA_ERROR_OUT_OF_MEMORY: out of memory
#   0%|          | 0/489 [00:12<?, ?it/s]
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
# Cell In[47], line 48
#      46 for i in tqdm(range(0, npts, 4096)):
#      47     sl = slice(i, i + 4096)
# ---> 48     logls_chunk = eval_logl(D1f[sl], D2f[sl], D3f[sl])
#      49     logls.append(logls_chunk)
#      51 logls = jnp.concatenate(logls)
#
#     [... skipping hidden 5 frame]
#
# File ~/miniforge3/envs/discotech/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:1305, in ExecuteReplicated.__call__(self, *args)
#    1303   self._handle_token_bufs(result_token_bufs, sharded_runtime_token)
#    1304 else:
# -> 1305   results = self.xla_executable.execute_sharded(input_bufs)
#    1307 if dispatch.needs_check_special():
#    1308   out_arrays = results.disassemble_into_single_device_arrays()
#
# XlaRuntimeError: RESOURCE_EXHAUSTED: Underlying backend ran out of memory trying to instantiate command buffer with 20 (total of 0 alive graphs in the process). You can try to (a) Give more memory to the driver by reducing XLA_CLIENT_MEM_FRACTION (b) Disable command buffers with 'XLA_FLAGS=--xla_gpu_enable_command_buffer=' (empty set). Original error: Failed to instantiate CUDA graph: CUDA_ERROR_OUT_OF_MEMORY: out of memory

# %%
logls
# Out:
# Array([37647.83175862, 37648.13162657, 37646.96945458, ...,
#        37649.1175421 , 37649.65888172, 37649.16895444], dtype=float64)
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Plot the lnL oscillations as it steps through iteration of the grid

plt.plot(logls, ls="", marker=".")
plt.ylabel("Log Likelihood")
plt.xlabel("Grid Point Index")
# Out:
# Text(0.5, 0, 'Grid Point Index')
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Above isn't that intuitive except that it appears to have clear flanged oscillations as the signal phase wraps.
#
# Below we look at a 3D representation instead

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Flatten everything
D1f = D1.ravel()
D2f = D2.ravel()
D3f = D3.ravel()
LNLf = logls.ravel()

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

p = ax.scatter(D1f, D2f, D3f, c=LNLf, cmap='viridis', s=8)
fig.colorbar(p, ax=ax, label='Log-likelihood')

ax.set_xlabel("Distance 1 (kpc)")
ax.set_ylabel("Distance 2 (kpc)")
ax.set_zlabel("Distance 3 (kpc)")
ax.set_title("3D Log-likelihood Landscape")

plt.show()
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# The scale of the oscillation is much more obvious.
#
# But it's more useful to actually understand the structure of the oscillation "given" one of the changing parameters I think.
#
# So let's take a slice of one of the pular distances which is the closest to its true value.

# %%
idx = jnp.searchsorted(distance2, enterprise_params['J0030+0451_cw_p_dist'])

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Use meshgrid for the 2D plane
D1, D3 = jnp.meshgrid(distance1, distance3, indexing='ij')

# Plot the surface
surf = ax.plot_surface(D1, D3, logls.reshape(len(distance1), len(distance2), len(distance3))[:, idx, :],
                       cmap='viridis', linewidth=0, antialiased=False)

ax.plot(enterprise_params['J0437-4715_cw_p_dist'], enterprise_params['J0125-2327_cw_p_dist'], 
         marker='x', color='red', markersize=10, label='Injected Value')

ax.set_xlabel("Distance 1 (kpc)")
ax.set_ylabel("Distance 3(kpc)")
ax.set_zlabel("Log-likelihood")
ax.set_title(f"Log-likelihood surface (Distance 2 = {distance2[idx]:.2f} kpc)")
fig.colorbar(surf, ax=ax, shrink=0.5, aspect=10)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[252], line 10
#       7 D1, D3 = jnp.meshgrid(distance1, distance3, indexing='ij')
#       9 # Plot the surface
# ---> 10 surf = ax.plot_surface(D1, D3, logls.reshape(len(distance1), len(distance2), len(distance3))[:, idx, :],
#      11                        cmap='viridis', linewidth=0, antialiased=False)
#      13 ax.plot(enterprise_params['J0437-4715_cw_p_dist'], enterprise_params['J0125-2327_cw_p_dist'],
#      14          marker='x', color='red', markersize=10, label='Injected Value')
#      16 ax.set_xlabel("Distance 1 (kpc)")
#
# AttributeError: 'list' object has no attribute 'reshape'
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
plt.figure(figsize=(10, 8))
plt.contourf(D1, D3, logls.reshape(len(distance1), len(distance2), len(distance3))[:, idx, :], levels=20, cmap='viridis')
plt.plot(enterprise_params['J0437-4715_cw_p_dist'], enterprise_params['J0125-2327_cw_p_dist'], marker='x', color='red', markersize=10, label='Injected Value')
plt.colorbar(label='Log-Likelihood')
plt.xlabel("Distance 1 variation (kpc)")
plt.ylabel("Distance 2 variation (kpc)")
# Out:
# Text(0, 0.5, 'Distance 2 variation (kpc)')
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# This is much more intuitive! Looks exactly like we thought it would!
#
# It shows the rapid oscillation of the lnL, and especially that the pulsar distance is in a lnL peak across these extreme oscillations.

# %% [markdown]
# #### Hessian check
#
# Next we want to try and look at the hessian.

# %%
# Grab the injected values as a truth check
truths = {}
truths.update({p: sorted_dict[p] for p in logl.params })
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Reorder the dictionary again out of absolute paranoia
order_map = {key: i for i, key in enumerate(logl.params)}
sorted_items = sorted(truths.items(), key=lambda item: order_map.get(item[0], float('inf')))
sorted_dict = dict(sorted_items)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# sorted_dict now holds the true injected values that we want to test the Hessian on

# %%
# Grab a jnp vector array out of the sorted dict and define jitted functions

x0 = jnp.array(list(sorted_dict.values()), dtype=jnp.float64)
logl_fn = jax.jit(logl_wrapped)
grad_fn = jax.jit(jax.grad(logl_fn))
hess_fn = jax.jit(jax.hessian(logl_fn))
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Try the lnL again to be safe
print("logl_fn: {}".format(logl_fn(x0)))
# Out:
# logl_fn: 37645.15663396609
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Calc and check the gradient
G = grad_fn(x0)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
G
# Out:
# Array([ 7.77316013e+02, -5.50748285e-01, -5.16305472e-01, -8.55963113e+02,
#        -9.72618152e-03, -3.90104127e-02,  8.48936069e+03,  1.56706737e-02,
#         4.35354399e-02,  9.67152637e+01, -2.32727277e-05, -5.04598903e-05,
#         3.91052315e+03,  1.55324036e-03,  4.37056438e-03, -2.99450029e+01,
#        -2.27609541e-04, -8.00255025e-04,  3.58772990e+03, -1.47816791e-01,
#        -2.84527276e-01, -7.99478192e+02, -1.59357128e-05, -4.15636812e-05,
#        -9.75004668e+01, -1.14113207e-05, -3.04115120e-05,  2.92339280e+02,
#        -3.03937001e-01, -5.64075396e-01, -1.10583120e+01, -5.86232501e+00,
#         9.92987488e+04,  8.79620243e+03, -1.85315139e+01, -1.49438192e+01,
#        -6.33468272e+00, -5.07317530e+00, -3.36042186e+00, -9.84066077e+00,
#         4.39757222e+04, -2.70087165e+03, -1.52048570e+04, -4.54568638e+03,
#        -2.13631253e+01, -2.08467381e+01], dtype=float64)
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Calc and check the Hessian
H = hess_fn(x0)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
H
# Out:
# Array([[ 9.14001952e+07,  9.03778703e+01,  1.74386696e+02, ...,
#         -6.37406388e+06,  4.18267150e+02,  1.08976196e+03],
#        [ 9.03778703e+01, -1.70464149e+00, -2.27143576e+00, ...,
#         -9.47931578e+00, -7.79081962e-01, -2.04951714e+00],
#        [ 1.74386696e+02, -2.27143576e+00, -2.30354145e+00, ...,
#         -2.08363359e+01, -2.05251409e+00, -5.06367937e+00],
#        ...,
#        [-6.37406388e+06, -9.47931578e+00, -2.08363359e+01, ...,
#         -1.00101994e+09,  1.71386471e+03,  3.80444255e+03],
#        [ 4.18267150e+02, -7.79081962e-01, -2.05251409e+00, ...,
#          1.71386471e+03, -3.41270144e+01, -6.02541698e+01],
#        [ 1.08976196e+03, -2.04951714e+00, -5.06367937e+00, ...,
#          3.80444255e+03, -6.02541698e+01, -9.89698326e+01]],      dtype=float64)
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Check out the condition number of the Hessian
jnp.linalg.cond(H)
# Out:
# Array(5.3604881e+15, dtype=float64)
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# That's not good! But otherwise the lnL evaluation looks like it's working well.
